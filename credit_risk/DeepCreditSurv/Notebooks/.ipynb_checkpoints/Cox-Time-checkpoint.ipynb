# %%
import os
import pandas as pd
path = "D:\DeepCreditSurv"
os.chdir(path)

# %%
from DeepCreditSurv.models import Cox_Time

# %%
ct_m1 =Cox_Time.Cox_Time(dataset='M1',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M1\WideFormatMortgageAfterRemovingNull.csv")
best_lr = ct_m1.find_lr()
print(best_lr)
# Out:
# D:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass copy=True, with_mean=True, with_std=True as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# 0.0613590727341321

# %%
cis_m1 = ct_m1.build_model(lr=0.01)
print(cis_m1)
# Out:
# 0:	[0s / 0s],		train_loss: 0.3202,	val_loss: 0.2325
# 1:	[0s / 0s],		train_loss: 0.2292,	val_loss: 0.1958
# 2:	[0s / 1s],		train_loss: 0.2106,	val_loss: 0.2000
# 3:	[0s / 1s],		train_loss: 0.1984,	val_loss: 0.1836
# 4:	[0s / 1s],		train_loss: 0.1919,	val_loss: 0.1819
# 5:	[0s / 2s],		train_loss: 0.1805,	val_loss: 0.1920
# 6:	[0s / 2s],		train_loss: 0.1841,	val_loss: 0.1816
# 7:	[0s / 2s],		train_loss: 0.1834,	val_loss: 0.1873
# 8:	[0s / 3s],		train_loss: 0.1839,	val_loss: 0.1870
# 9:	[0s / 3s],		train_loss: 0.1844,	val_loss: 0.1707
# 10:	[0s / 3s],		train_loss: 0.1761,	val_loss: 0.1752
# 11:	[0s / 4s],		train_loss: 0.1818,	val_loss: 0.1766
# 12:	[0s / 4s],		train_loss: 0.1705,	val_loss: 0.1790
# 13:	[0s / 4s],		train_loss: 0.1739,	val_loss: 0.1679
# 14:	[0s / 5s],		train_loss: 0.1686,	val_loss: 0.1694
# 15:	[0s / 5s],		train_loss: 0.1634,	val_loss: 0.1586
# 16:	[0s / 5s],		train_loss: 0.1657,	val_loss: 0.1696
# 17:	[0s / 6s],		train_loss: 0.1746,	val_loss: 0.1636
# ...

# %%
ct_m2 = Cox_Time.Cox_Time(dataset='M2',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M2")
best_lr = ct_m2.find_lr()
print(best_lr)
# Out:
# Index(['t.act.12m_0', 't.act.12m_1', 't.act.12m_2', 't.act.12m_3',
#        't.act.12m_4', 't.act.12m_5', 't.act.12m_6', 't.act.12m_7',
#        't.act.12m_8', 't.act.12m_9', 't.act.12m_10', 't.act.12m_11',
#        't.act.12m_12', 't.del.30d.12m_0', 't.del.30d.12m_1', 't.del.30d.12m_2',
#        't.del.30d.12m_3', 't.del.30d.12m_4', 't.del.30d.12m_5',
#        't.del.30d.12m_6', 't.del.30d.12m_7', 't.del.30d.12m_8',
#        't.del.30d.12m_9', 't.del.30d.12m_10', 't.del.30d.12m_11',
#        't.del.30d.12m_12', 't.del.60d.12m_0', 't.del.60d.12m_1',
#        't.del.60d.12m_2', 't.del.60d.12m_3', 't.del.60d.12m_4',
#        't.del.60d.12m_5', 't.del.60d.12m_6', 't.del.60d.12m_7',
#        't.del.60d.12m_8', 't.del.60d.12m_9', 't.del.60d.12m_10',
#        't.del.60d.12m_11', 't.del.60d.12m_12'],
#       dtype='object')
# ...

# %%
cis_m2 = ct_m2.build_model(lr=0.001)
print(cis_m2)
# Out:
# 0:	[0s / 0s],		train_loss: 0.7861,	val_loss: 0.6806
# 1:	[0s / 0s],		train_loss: 0.6825,	val_loss: 0.6044
# 2:	[0s / 0s],		train_loss: 0.5591,	val_loss: 0.5450
# 3:	[0s / 0s],		train_loss: 0.4039,	val_loss: 0.4816
# 4:	[0s / 0s],		train_loss: 0.2494,	val_loss: 0.4351
# 5:	[0s / 0s],		train_loss: 0.2760,	val_loss: 0.3711
# 6:	[0s / 0s],		train_loss: 0.1719,	val_loss: 0.3269
# 7:	[0s / 0s],		train_loss: 0.1529,	val_loss: 0.2905
# 8:	[0s / 0s],		train_loss: 0.1200,	val_loss: 0.2631
# 9:	[0s / 0s],		train_loss: 0.0862,	val_loss: 0.2352
# 10:	[0s / 0s],		train_loss: 0.0697,	val_loss: 0.2235
# 11:	[0s / 0s],		train_loss: 0.0488,	val_loss: 0.1788
# 12:	[0s / 0s],		train_loss: 0.0813,	val_loss: 0.1474
# 13:	[0s / 0s],		train_loss: 0.0286,	val_loss: 0.1683
# 14:	[0s / 0s],		train_loss: 0.1029,	val_loss: 0.1377
# 15:	[0s / 0s],		train_loss: 0.0385,	val_loss: 0.1618
# 16:	[0s / 0s],		train_loss: 0.0507,	val_loss: 0.1224
# 17:	[0s / 0s],		train_loss: 0.1086,	val_loss: 0.1159
# ...

# %%
ct_ppdai = Cox_Time.Cox_Time(dataset='ppdai',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\ppdai")
best_lr = ct_ppdai.find_lr()
print(best_lr)
# Out:
# Index(['IsFirstTime', 'PhoneVerified', 'RegistrationVerified', 'VideoVerified',
#        'DegreeVerified', 'CreditVerified', 'TaobaoVerified', 'Gender_0',
#        'Gender_1', 'BorrowerRating_A', 'BorrowerRating_B', 'BorrowerRating_C',
#        'BorrowerRating_D', 'BorrowerRating_E', 'BorrowerRating_F',
#        'LoanType_APPexpress', 'LoanType_E-commerce', 'LoanType_Normal',
#        'LoanType_Others', 'LoanPeriod_1', 'LoanPeriod_2', 'LoanPeriod_3',
#        'LoanPeriod_4', 'LoanPeriod_5', 'LoanPeriod_6', 'LoanPeriod_7',
#        'LoanPeriod_8', 'LoanPeriod_9', 'LoanPeriod_10', 'LoanPeriod_11',
#        'LoanPeriod_12', 'LoanPeriod_15', 'LoanPeriod_17', 'LoanPeriod_18',
#        'LoanPeriod_20', 'LoanPeriod_21', 'LoanPeriod_24'],
#       dtype='object')
# ...

# %%
cis_ppdai = ct_ppdai.build_model(lr=0.001)
print(cis_ppdai)
# Out:
# 0:	[0s / 0s],		train_loss: 0.6028,	val_loss: 0.4833
# 1:	[0s / 0s],		train_loss: 0.5123,	val_loss: 0.4268
# 2:	[0s / 1s],		train_loss: 0.4662,	val_loss: 0.3940
# 3:	[0s / 1s],		train_loss: 0.4377,	val_loss: 0.3773
# 4:	[0s / 1s],		train_loss: 0.4057,	val_loss: 0.3473
# 5:	[0s / 2s],		train_loss: 0.3874,	val_loss: 0.3482
# 6:	[0s / 2s],		train_loss: 0.3767,	val_loss: 0.3444
# 7:	[0s / 3s],		train_loss: 0.3656,	val_loss: 0.3243
# 8:	[0s / 3s],		train_loss: 0.3529,	val_loss: 0.3193
# 9:	[0s / 3s],		train_loss: 0.3400,	val_loss: 0.3168
# 10:	[0s / 4s],		train_loss: 0.3341,	val_loss: 0.3026
# 11:	[0s / 4s],		train_loss: 0.3345,	val_loss: 0.2974
# 12:	[0s / 5s],		train_loss: 0.3227,	val_loss: 0.2928
# 13:	[0s / 5s],		train_loss: 0.3246,	val_loss: 0.2913
# 14:	[0s / 5s],		train_loss: 0.3149,	val_loss: 0.2941
# 15:	[0s / 6s],		train_loss: 0.2959,	val_loss: 0.2860
# 16:	[0s / 6s],		train_loss: 0.3086,	val_loss: 0.2877
# 17:	[0s / 7s],		train_loss: 0.2886,	val_loss: 0.2709
# ...

# %%
ct_lc = Cox_Time.Cox_Time(dataset='LC',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\LendingClub\XYZCorp_LendingData.txt")
best_lr = ct_lc.find_lr()
print(best_lr)
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
# ...

# %%
cis_lc= ct_lc.build_model(lr=0.01)
print(cis_lc)
# Out:
# 0:	[0s / 0s],		train_loss: 0.1064,	val_loss: 0.0635
# 1:	[0s / 0s],		train_loss: 0.0480,	val_loss: 0.0522
# 2:	[0s / 1s],		train_loss: 0.0486,	val_loss: 0.0527
# 3:	[0s / 1s],		train_loss: 0.0400,	val_loss: 0.0473
# 4:	[0s / 2s],		train_loss: 0.0459,	val_loss: 0.0384
# 5:	[0s / 2s],		train_loss: 0.0491,	val_loss: 0.0447
# 6:	[0s / 2s],		train_loss: 0.0442,	val_loss: 0.0363
# 7:	[0s / 3s],		train_loss: 0.0389,	val_loss: 0.0478
# 8:	[0s / 3s],		train_loss: 0.0437,	val_loss: 0.0400
# 9:	[0s / 4s],		train_loss: 0.0365,	val_loss: 0.0441
# 10:	[0s / 4s],		train_loss: 0.0312,	val_loss: 0.0525
# 11:	[0s / 4s],		train_loss: 0.0365,	val_loss: 0.0399
# 12:	[0s / 5s],		train_loss: 0.0291,	val_loss: 0.0359
# 13:	[0s / 5s],		train_loss: 0.0294,	val_loss: 0.0408
# 14:	[0s / 6s],		train_loss: 0.0303,	val_loss: 0.0337
# 15:	[0s / 6s],		train_loss: 0.0247,	val_loss: 0.0341
# 16:	[0s / 6s],		train_loss: 0.0303,	val_loss: 0.0362
# 17:	[0s / 7s],		train_loss: 0.0296,	val_loss: 0.0302
# ...
