# %%
import os
import pandas as pd
path = "D:\DeepCreditSurv"
os.chdir(path)

# %%
import DeepCreditSurv.models.GBST.gbst_class as gbst

# %%
gbst_m1 = gbst.gbst(dataset='M1',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M1\WideFormatMortgageAfterRemovingNull.csv")

# %%
cf_m1 = gbst_m1.build_model_grid_cv()
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ......max_depth=3, n_estimators=40;, score=0.984 total time=  41.9s
# [CV 2/5] END ......max_depth=3, n_estimators=40;, score=0.981 total time=  42.3s
# [CV 3/5] END ......max_depth=3, n_estimators=40;, score=0.981 total time=  42.1s
# [CV 4/5] END ......max_depth=3, n_estimators=40;, score=0.981 total time=  42.6s
# [CV 5/5] END ......max_depth=3, n_estimators=40;, score=0.981 total time=  42.3s
# [CV 1/5] END ......max_depth=3, n_estimators=50;, score=0.985 total time=  52.4s
# [CV 2/5] END ......max_depth=3, n_estimators=50;, score=0.982 total time=  52.1s
# [CV 3/5] END ......max_depth=3, n_estimators=50;, score=0.982 total time=  54.5s
# [CV 4/5] END ......max_depth=3, n_estimators=50;, score=0.983 total time=  53.3s
# [CV 5/5] END ......max_depth=3, n_estimators=50;, score=0.983 total time=  53.3s
# [CV 1/5] END ......max_depth=3, n_estimators=60;, score=0.985 total time= 1.1min
# ...

# %%
params = {'max_depth': 4, 'n_estimators': 120}
hazard_m1 = gbst_m1.build_model(params=params)
# Out:
# D:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\gbst-1.0.0-py3.8.egg\gbst\core.py:732: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn("Use subset (sliced data) of np.ndarray is not recommended " +
# [0]	validation_0-auc:0.97863	validation_1-auc:0.97529
# [1]	validation_0-auc:0.97968	validation_1-auc:0.97631
# [2]	validation_0-auc:0.97976	validation_1-auc:0.97660
# [3]	validation_0-auc:0.98049	validation_1-auc:0.97739
# [4]	validation_0-auc:0.98083	validation_1-auc:0.97777
# [5]	validation_0-auc:0.98138	validation_1-auc:0.97833
# [6]	validation_0-auc:0.98156	validation_1-auc:0.97847
# [7]	validation_0-auc:0.98173	validation_1-auc:0.97859
# [8]	validation_0-auc:0.98188	validation_1-auc:0.97877
# [9]	validation_0-auc:0.98200	validation_1-auc:0.97881
# [10]	validation_0-auc:0.98225	validation_1-auc:0.97911
# [11]	validation_0-auc:0.98233	validation_1-auc:0.97923
# ...

# %%
gbst_m2 = gbst.gbst(dataset='M2',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M2")

# %%
cf_m2 = gbst_m2.build_model_grid_cv()
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time= 1.9min
# [CV 2/5] END ......max_depth=3, n_estimators=40;, score=0.991 total time= 1.9min
# [CV 3/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time= 2.0min
# [CV 4/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time= 1.9min
# [CV 5/5] END ......max_depth=3, n_estimators=40;, score=0.991 total time= 2.0min
# [CV 1/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time= 2.4min
# [CV 2/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time= 2.4min
# [CV 3/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time= 2.4min
# [CV 4/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time= 2.5min
# [CV 5/5] END ......max_depth=3, n_estimators=50;, score=0.993 total time= 2.4min
# [CV 1/5] END ......max_depth=3, n_estimators=60;, score=0.994 total time= 2.9min
# ...

# %%
params = {'max_depth': 4, 'n_estimators': 130}
hazard_m2 = gbst_m2.build_model(params=params)
# Out:
# D:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\gbst-1.0.0-py3.8.egg\gbst\core.py:732: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn("Use subset (sliced data) of np.ndarray is not recommended " +
# [0]	validation_0-auc:0.98325	validation_1-auc:0.98329
# [1]	validation_0-auc:0.98461	validation_1-auc:0.98451
# [2]	validation_0-auc:0.98534	validation_1-auc:0.98521
# [3]	validation_0-auc:0.98576	validation_1-auc:0.98556
# [4]	validation_0-auc:0.98612	validation_1-auc:0.98588
# [5]	validation_0-auc:0.98647	validation_1-auc:0.98626
# [6]	validation_0-auc:0.98665	validation_1-auc:0.98642
# [7]	validation_0-auc:0.98687	validation_1-auc:0.98662
# [8]	validation_0-auc:0.98701	validation_1-auc:0.98676
# [9]	validation_0-auc:0.98706	validation_1-auc:0.98681
# [10]	validation_0-auc:0.98706	validation_1-auc:0.98680
# [11]	validation_0-auc:0.98641	validation_1-auc:0.98608
# ...

# %%
gbst_ppdai = gbst.gbst(dataset='ppdai',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\ppdai")

# %%
cf_ppdai = gbst_ppdai.build_model_grid_cv()
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time=  18.9s
# [CV 2/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time=  18.5s
# [CV 3/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time=  19.3s
# [CV 4/5] END ......max_depth=3, n_estimators=40;, score=0.991 total time=  19.5s
# [CV 5/5] END ......max_depth=3, n_estimators=40;, score=0.990 total time=  19.2s
# [CV 1/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time=  23.8s
# [CV 2/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time=  23.5s
# [CV 3/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time=  24.3s
# [CV 4/5] END ......max_depth=3, n_estimators=50;, score=0.993 total time=  23.5s
# [CV 5/5] END ......max_depth=3, n_estimators=50;, score=0.992 total time=  23.7s
# [CV 1/5] END ......max_depth=3, n_estimators=60;, score=0.993 total time=  29.0s
# ...

# %%
params = {'max_depth': 4, 'n_estimators': 130}
hazard_ppdai = gbst_ppdai.build_model(params=params)
# Out:
# D:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\gbst-1.0.0-py3.8.egg\gbst\core.py:732: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn("Use subset (sliced data) of np.ndarray is not recommended " +
# [0]	validation_0-auc:0.96856	validation_1-auc:0.96749
# [1]	validation_0-auc:0.97411	validation_1-auc:0.97332
# [2]	validation_0-auc:0.97525	validation_1-auc:0.97444
# [3]	validation_0-auc:0.97611	validation_1-auc:0.97539
# [4]	validation_0-auc:0.97660	validation_1-auc:0.97578
# [5]	validation_0-auc:0.97770	validation_1-auc:0.97689
# [6]	validation_0-auc:0.97846	validation_1-auc:0.97755
# [7]	validation_0-auc:0.97921	validation_1-auc:0.97843
# [8]	validation_0-auc:0.97952	validation_1-auc:0.97885
# [9]	validation_0-auc:0.97993	validation_1-auc:0.97926
# [10]	validation_0-auc:0.97996	validation_1-auc:0.97934
# [11]	validation_0-auc:0.97997	validation_1-auc:0.97931
# ...

# %%
gbst_lc = gbst.gbst(dataset='LC',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\LendingClub\XYZCorp_LendingData.txt")
# Out:
# Columns with less than 90% of the data included:
# ['all_util', 'annual_inc_joint', 'desc', 'dti_joint', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'mths_since_last_delinq', 'mths_since_last_major_derog', 'mths_since_last_record', 'mths_since_rcnt_il', 'next_pymnt_d', 'open_acc_6m', 'open_il_12m', 'open_il_24m', 'open_il_6m', 'open_rv_12m', 'open_rv_24m', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']

# %%
cf_lc = gbst_lc.build_model_grid_cv()

# %%
params = {'max_depth': 4, 'n_estimators': 130}
hazard_lc = gbst_lc.build_model(params=params)
# Out:
# D:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\gbst-1.0.0-py3.8.egg\gbst\core.py:732: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn("Use subset (sliced data) of np.ndarray is not recommended " +
# [0]	validation_0-auc:0.96571	validation_1-auc:0.96601
# [1]	validation_0-auc:0.96992	validation_1-auc:0.96998
# [2]	validation_0-auc:0.97342	validation_1-auc:0.97337
# [3]	validation_0-auc:0.97487	validation_1-auc:0.97493
# [4]	validation_0-auc:0.97665	validation_1-auc:0.97669
# [5]	validation_0-auc:0.97732	validation_1-auc:0.97739
# [6]	validation_0-auc:0.97798	validation_1-auc:0.97811
# [7]	validation_0-auc:0.97868	validation_1-auc:0.97889
# [8]	validation_0-auc:0.97917	validation_1-auc:0.97950
# [9]	validation_0-auc:0.97966	validation_1-auc:0.98000
# [10]	validation_0-auc:0.97971	validation_1-auc:0.98012
# [11]	validation_0-auc:0.97988	validation_1-auc:0.98035
# ...
