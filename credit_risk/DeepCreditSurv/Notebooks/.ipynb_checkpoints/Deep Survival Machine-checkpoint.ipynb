# %%
import os
import pandas as pd
path = "D:\DeepCreditSurv"
os.chdir(path)

# %%
import DeepCreditSurv.models.DeepSurvivalMachines.dsm_dcs as dsm

# %%
model_m1 = dsm.DSM(dataset='M1',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M1\WideFormatMortgageAfterRemovingNull.csv")

# %%
model_m1, cis_m1, brs_m1 = model_m1.build_model()
# Out:
# ...
#  14%|███████████▎                                                                     | 14/100 [00:14<01:31,  1.06s/it]
# For 0.25 quantile,
# TD Concordance Index: 0.8375291441537417
# ROC AUC  0.8953003786321407
#
# For 0.5 quantile,
# TD Concordance Index: 0.82830167343061
# ROC AUC  0.9331239406856257
#
# For 0.75 quantile,
# TD Concordance Index: 0.8196958897214758
# ROC AUC  0.9698797580697404

# %%
model_m2 = dsm.DSM(dataset='M2',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M2")

# %%
model_m2, cis_m2, brs_m2 = model_m2.build_model()
# Out:
# ...
#  33%|██████████████████████████▋                                                      | 33/100 [01:04<02:10,  1.95s/it]
# For 0.25 quantile,
# TD Concordance Index: 0.9883742469748348
# ROC AUC  0.9937491698500736
#
# For 0.5 quantile,
# TD Concordance Index: 0.9764582086287367
# ROC AUC  0.9992209552435718
#
# For 0.75 quantile,
# TD Concordance Index: 0.9742456067217666
# ROC AUC  0.9954384379051627

# %%
model_ppdai = dsm.DSM(dataset='ppdai',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\ppdai")

# %%
model_ppdai, cis_ppdai, brs_ppdai = model_ppdai.build_model()
# Out:
# ...
#  87%|██████████████████████████████████████████████████████████████████████▍          | 87/100 [02:47<00:24,  1.92s/it]
# For 0.25 quantile,
# TD Concordance Index: 0.9104286733559762
# ROC AUC  0.9880891291173782
#
# For 0.5 quantile,
# TD Concordance Index: 0.8248266667215075
# ROC AUC  0.9889699144319585
#
# For 0.75 quantile,
# TD Concordance Index: 0.7995139553679727
# ROC AUC  0.9855903914862568

# %%
model_lc = dsm.DSM(dataset='LC',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\LendingClub\XYZCorp_LendingData.txt")
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
# ...

# %%
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
model_lc, cis_lc, brs_lc = model_lc.build_model()
