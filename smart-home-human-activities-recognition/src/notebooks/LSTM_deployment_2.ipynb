# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import tensorflow as tf

from xgboost import XGBClassifier
from tensorflow.keras import layers, optimizers, models
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier

base = "../data/Deployment_2/"

# %% [markdown]
# ## 1. Data loading

# %%
data = pd.read_csv(base + "dataset_2_preprocessing_with_mean_value.csv")
df_train = data.copy()

# %% [markdown]
# ## 2. Data processing

# %%
df_train = df_train.fillna(0)
df_train["Time"] = df_train["Hour"]*60 + df_train["Minute"]

df_train_without_ignore = df_train[df_train["Label"]!=10]
df_train_without_ignore = df_train_without_ignore.reset_index(drop=True)

# %%
df_train_without_ignore.head()
# Out:
#              TimeID  Hour  Minute        Date  Label         Name  sensor1  \
# 0  2013-04-14-20-15    20      15  2013-04-14    2.0  Watching TV      0.0
# 1  2013-04-14-20-16    20      16  2013-04-14    2.0  Watching TV      0.0
# 2  2013-04-14-20-17    20      17  2013-04-14    2.0  Watching TV    208.0
# 3  2013-04-14-20-18    20      18  2013-04-14    2.0  Watching TV      0.0
# 4  2013-04-14-20-19    20      19  2013-04-14    2.0  Watching TV      0.0
#
#    sensor2  sensor3     sensor4  ...  sensor21  sensor22  sensor24   sensor30  \
# 0      0.0      0.0  194.000000  ...       0.0       0.0       0.0   5.000000
# 1      0.0      0.0  194.666667  ...       0.0       0.0       0.0  68.333333
# 2      0.0      0.0  195.000000  ...       0.0       0.0       0.0  68.086957
# 3      0.0      0.0  196.000000  ...       0.0       0.0       0.0  68.000000
# 4      0.0      0.0  197.833333  ...       0.0       0.0       0.0  67.913043
#
#     sensor31  sensor32  sensor40  sensor41  sensor42  Time
# 0  12.304348  0.000000       0.0  1.478261       0.0  1215
# 1  12.250000  0.000000       0.0  1.416667       0.0  1216
# 2  11.956522  0.000000       0.0  1.391304       0.0  1217
# 3  12.043478  2.260870       0.0  1.478261       0.0  1218
# 4  11.833333  5.916667       0.0  1.478261       0.0  1219
#
# [5 rows x 23 columns]

# %%
# df_freq = pd.DataFrame(df_train["Date"].value_counts()).reset_index().sort_values(by="index")
# df_freq = df_freq.rename(columns={"index":"Date", "Date":"Count"})
# df_freq_1_hour = df_freq[df_freq["Count"]>60]
# df_freq_2_hour = df_freq[df_freq["Count"]>120]
# df_freq_1_hour

# %% [markdown]
# #### Filling "Ignore" by using the best action prediction model from part 1

# %%
encoder = LabelEncoder()

X = df_train_without_ignore.drop(["Label", "TimeID", "Date", "Name", "Hour", "Minute"], axis=1)
X = np.array(X)
y = encoder.fit_transform(df_train_without_ignore["Name"])

# %%
xgb_model = XGBClassifier(colsample_bytree=0.6, 
                          gamma=0, 
                          learning_rate=0.01, 
                          max_depth=4, 
                          n_estimators=190, 
                          subsample=0.9,
                          random_state=18)

xgb_model.fit(X, y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.6, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=190, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=18, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=0.9,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb_model.score(X, y)
# Out:
# 0.9332013504675375

# %%
df_ignore = df_train[df_train["Label"]==10]
df_ignore = df_ignore.reset_index(drop=True)
df_ignore = df_ignore.drop(["Label", "TimeID", "Date", "Name", "Hour", "Minute"], axis=1)

y_pred = xgb_model.predict(np.array(df_ignore))

# %%
df_train.loc[df_train["Label"]==10, "Name"] = encoder.inverse_transform(y_pred)

# %%
np.unique(df_train["Name"])
# Out:
# array(['Eating', 'Ironing', 'Listening Radio', 'Making Tea',
#        'Not at Home', 'Reading', 'Sleeping', 'Slicing Bread',
#        'Watching TV'], dtype=object)

# %% [markdown]
# ### Preparing data for training

# %%
encoder = LabelEncoder()

train_data = df_train.drop(["Label", "TimeID", "Date", "Name", "Hour", "Minute"], axis=1)
train_data = np.array(train_data)
train_labels = encoder.fit_transform(df_train["Name"])

print(train_data.shape, train_labels.shape)
# Out:
# (89128, 17) (89128,)

# %%
def make_data(timesteps, ratio=0.5, train_data=train_data, train_labels=train_labels):
    X_data = np.zeros([train_data.shape[0]-timesteps, timesteps, train_data.shape[1]])
    y_data = train_labels[timesteps:]
    for i in range(timesteps):
        X_data[:,i,:] = train_data[i:X_data.shape[0]+i]
    
    split_idx = int(len(X_data)*ratio)

    X_train, X_test = X_data[:split_idx], X_data[split_idx:]
    y_train, y_test = y_data[:split_idx], y_data[split_idx:]
    
    return X_train, y_train, X_test, y_test

# %% [markdown]
# ## 3. Training

# %%
histories = []

for timesteps in [30, 60, 120]:
    X_train, y_train, X_test, y_test = make_data(timesteps)
    
    tf.keras.backend.clear_session()
    
    inputs = layers.Input(shape=(X_train.shape[1:]))
    x = layers.LSTM(128, return_sequences=True)(inputs)
    x = layers.LSTM(128)(x)
    outputs = layers.Dense(9, activation="softmax")(x)

    model = models.Model(inputs, outputs)
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  optimizer=optimizers.Adam(),
                  metrics=["accuracy"])

    history = model.fit(X_train, y_train, epochs=50, batch_size=500, validation_data=(X_test, y_test))
    histories.append(history)
# Out:
# Train on 44549 samples, validate on 44549 samples
# Epoch 1/50
# 44549/44549 [==============================] - 6s 133us/sample - loss: 1.7233 - accuracy: 0.6603 - val_loss: 1.6351 - val_accuracy: 0.7363
# Epoch 2/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.6125 - accuracy: 0.7606 - val_loss: 1.5685 - val_accuracy: 0.8062
# Epoch 3/50
# 44549/44549 [==============================] - 1s 30us/sample - loss: 1.5553 - accuracy: 0.8185 - val_loss: 1.5539 - val_accuracy: 0.8185
# Epoch 4/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5461 - accuracy: 0.8268 - val_loss: 1.5197 - val_accuracy: 0.8528
# Epoch 5/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5269 - accuracy: 0.8457 - val_loss: 1.5366 - val_accuracy: 0.8354
# Epoch 6/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5487 - accuracy: 0.8240 - val_loss: 1.5528 - val_accuracy: 0.8195
# Epoch 7/50
# 44549/44549 [==============================] - 1s 30us/sample - loss: 1.5289 - accuracy: 0.8440 - val_loss: 1.5460 - val_accuracy: 0.8259
# Epoch 8/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5252 - accuracy: 0.8468 - val_loss: 1.5520 - val_accuracy: 0.8194
# Epoch 9/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5417 - accuracy: 0.8307 - val_loss: 1.5460 - val_accuracy: 0.8258
# Epoch 10/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5232 - accuracy: 0.8490 - val_loss: 1.5454 - val_accuracy: 0.8261
# Epoch 11/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5200 - accuracy: 0.8520 - val_loss: 1.5387 - val_accuracy: 0.8328
# Epoch 12/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5204 - accuracy: 0.8518 - val_loss: 1.5294 - val_accuracy: 0.8420
# Epoch 13/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5164 - accuracy: 0.8562 - val_loss: 1.5207 - val_accuracy: 0.8517
# Epoch 14/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5178 - accuracy: 0.8541 - val_loss: 1.5347 - val_accuracy: 0.8364
# Epoch 15/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5179 - accuracy: 0.8545 - val_loss: 1.5398 - val_accuracy: 0.8322
# Epoch 16/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5213 - accuracy: 0.8509 - val_loss: 1.5248 - val_accuracy: 0.8471
# Epoch 17/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5265 - accuracy: 0.8456 - val_loss: 1.5224 - val_accuracy: 0.8491
# Epoch 18/50
# 44549/44549 [==============================] - 1s 30us/sample - loss: 1.5270 - accuracy: 0.8454 - val_loss: 1.5412 - val_accuracy: 0.8314
# Epoch 19/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5272 - accuracy: 0.8453 - val_loss: 1.5356 - val_accuracy: 0.8362
# Epoch 20/50
# 44549/44549 [==============================] - 1s 32us/sample - loss: 1.5249 - accuracy: 0.8472 - val_loss: 1.5364 - val_accuracy: 0.8349
# Epoch 21/50
# 44549/44549 [==============================] - 1s 32us/sample - loss: 1.5321 - accuracy: 0.8398 - val_loss: 1.5444 - val_accuracy: 0.8270
# Epoch 22/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5920 - accuracy: 0.7810 - val_loss: 1.5392 - val_accuracy: 0.8336
# Epoch 23/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5259 - accuracy: 0.8465 - val_loss: 1.5414 - val_accuracy: 0.8302
# Epoch 24/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5189 - accuracy: 0.8531 - val_loss: 1.5412 - val_accuracy: 0.8302
# Epoch 25/50
# 44549/44549 [==============================] - 1s 30us/sample - loss: 1.5211 - accuracy: 0.8512 - val_loss: 1.5238 - val_accuracy: 0.8480
# Epoch 26/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5238 - accuracy: 0.8484 - val_loss: 1.5269 - val_accuracy: 0.8451
# Epoch 27/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5181 - accuracy: 0.8540 - val_loss: 1.5326 - val_accuracy: 0.8394
# Epoch 28/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5321 - accuracy: 0.8401 - val_loss: 1.5842 - val_accuracy: 0.7878
# Epoch 29/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5539 - accuracy: 0.8186 - val_loss: 1.5312 - val_accuracy: 0.8406
# Epoch 30/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5213 - accuracy: 0.8510 - val_loss: 1.5468 - val_accuracy: 0.8248
# Epoch 31/50
# 44549/44549 [==============================] - 1s 30us/sample - loss: 1.5189 - accuracy: 0.8532 - val_loss: 1.5243 - val_accuracy: 0.8478
# Epoch 32/50
# 44549/44549 [==============================] - 1s 33us/sample - loss: 1.5151 - accuracy: 0.8570 - val_loss: 1.5245 - val_accuracy: 0.8477
# Epoch 33/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5128 - accuracy: 0.8591 - val_loss: 1.5157 - val_accuracy: 0.8557
# Epoch 34/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5154 - accuracy: 0.8569 - val_loss: 1.5286 - val_accuracy: 0.8429
# Epoch 35/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5151 - accuracy: 0.8567 - val_loss: 1.5515 - val_accuracy: 0.8201
# Epoch 36/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5512 - accuracy: 0.8203 - val_loss: 1.6166 - val_accuracy: 0.7549
# Epoch 37/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5386 - accuracy: 0.8341 - val_loss: 1.5251 - val_accuracy: 0.8466
# Epoch 38/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5117 - accuracy: 0.8611 - val_loss: 1.5317 - val_accuracy: 0.8401
# Epoch 39/50
# 44549/44549 [==============================] - 1s 32us/sample - loss: 1.5124 - accuracy: 0.8596 - val_loss: 1.5236 - val_accuracy: 0.8481
# Epoch 40/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5106 - accuracy: 0.8615 - val_loss: 1.5370 - val_accuracy: 0.8349
# Epoch 41/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5120 - accuracy: 0.8604 - val_loss: 1.5196 - val_accuracy: 0.8523
# Epoch 42/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5069 - accuracy: 0.8650 - val_loss: 1.5258 - val_accuracy: 0.8458
# Epoch 43/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5135 - accuracy: 0.8589 - val_loss: 1.5247 - val_accuracy: 0.8473
# Epoch 44/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5223 - accuracy: 0.8495 - val_loss: 1.5115 - val_accuracy: 0.8609
# Epoch 45/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5267 - accuracy: 0.8459 - val_loss: 1.5243 - val_accuracy: 0.8476
# Epoch 46/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5295 - accuracy: 0.8429 - val_loss: 1.5182 - val_accuracy: 0.8547
# Epoch 47/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5217 - accuracy: 0.8509 - val_loss: 1.5196 - val_accuracy: 0.8527
# Epoch 48/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5263 - accuracy: 0.8457 - val_loss: 1.5338 - val_accuracy: 0.8382
# Epoch 49/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5364 - accuracy: 0.8358 - val_loss: 1.5341 - val_accuracy: 0.8374
# Epoch 50/50
# 44549/44549 [==============================] - 1s 31us/sample - loss: 1.5294 - accuracy: 0.8425 - val_loss: 1.5469 - val_accuracy: 0.8251
# Train on 44534 samples, validate on 44534 samples
# Epoch 1/50
# 44534/44534 [==============================] - 6s 128us/sample - loss: 1.6770 - accuracy: 0.7082 - val_loss: 1.5993 - val_accuracy: 0.7743
# Epoch 2/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5465 - accuracy: 0.8282 - val_loss: 1.5428 - val_accuracy: 0.8313
# Epoch 3/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5520 - accuracy: 0.8226 - val_loss: 1.5427 - val_accuracy: 0.8313
# Epoch 4/50
# 44534/44534 [==============================] - 2s 55us/sample - loss: 1.5286 - accuracy: 0.8446 - val_loss: 1.5412 - val_accuracy: 0.8314
# Epoch 5/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5295 - accuracy: 0.8432 - val_loss: 1.5485 - val_accuracy: 0.8238
# Epoch 6/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5503 - accuracy: 0.8222 - val_loss: 1.5559 - val_accuracy: 0.8177
# Epoch 7/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5285 - accuracy: 0.8441 - val_loss: 1.5378 - val_accuracy: 0.8340
# Epoch 8/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5331 - accuracy: 0.8391 - val_loss: 1.5539 - val_accuracy: 0.8185
# Epoch 9/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5221 - accuracy: 0.8501 - val_loss: 1.5568 - val_accuracy: 0.8153
# Epoch 10/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5203 - accuracy: 0.8521 - val_loss: 1.5441 - val_accuracy: 0.8279
# Epoch 11/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5166 - accuracy: 0.8558 - val_loss: 1.5420 - val_accuracy: 0.8305
# Epoch 12/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5196 - accuracy: 0.8527 - val_loss: 1.5363 - val_accuracy: 0.8362
# Epoch 13/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5244 - accuracy: 0.8475 - val_loss: 1.5505 - val_accuracy: 0.8219
# Epoch 14/50
# 44534/44534 [==============================] - 2s 51us/sample - loss: 1.5210 - accuracy: 0.8513 - val_loss: 1.5189 - val_accuracy: 0.8531
# Epoch 15/50
# 44534/44534 [==============================] - 2s 51us/sample - loss: 1.5196 - accuracy: 0.8525 - val_loss: 1.5384 - val_accuracy: 0.8341
# Epoch 16/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5171 - accuracy: 0.8552 - val_loss: 1.5392 - val_accuracy: 0.8325
# Epoch 17/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5100 - accuracy: 0.8621 - val_loss: 1.5207 - val_accuracy: 0.8521
# Epoch 18/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5121 - accuracy: 0.8601 - val_loss: 1.5306 - val_accuracy: 0.8413
# Epoch 19/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5109 - accuracy: 0.8611 - val_loss: 1.5320 - val_accuracy: 0.8405
# Epoch 20/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5128 - accuracy: 0.8594 - val_loss: 1.5225 - val_accuracy: 0.8495
# Epoch 21/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5250 - accuracy: 0.8470 - val_loss: 1.5420 - val_accuracy: 0.8295
# Epoch 22/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5330 - accuracy: 0.8390 - val_loss: 1.5290 - val_accuracy: 0.8419
# Epoch 23/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5171 - accuracy: 0.8551 - val_loss: 1.5322 - val_accuracy: 0.8398
# Epoch 24/50
# 44534/44534 [==============================] - 2s 51us/sample - loss: 1.5114 - accuracy: 0.8607 - val_loss: 1.5397 - val_accuracy: 0.8317
# Epoch 25/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5214 - accuracy: 0.8504 - val_loss: 1.5417 - val_accuracy: 0.8300
# Epoch 26/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5141 - accuracy: 0.8583 - val_loss: 1.5449 - val_accuracy: 0.8278
# Epoch 27/50
# 44534/44534 [==============================] - 2s 51us/sample - loss: 1.5193 - accuracy: 0.8530 - val_loss: 1.5296 - val_accuracy: 0.8420
# Epoch 28/50
# 44534/44534 [==============================] - 2s 51us/sample - loss: 1.5209 - accuracy: 0.8510 - val_loss: 1.5321 - val_accuracy: 0.8397
# Epoch 29/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5109 - accuracy: 0.8610 - val_loss: 1.5393 - val_accuracy: 0.8324
# Epoch 30/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5133 - accuracy: 0.8588 - val_loss: 1.5476 - val_accuracy: 0.8245
# Epoch 31/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5095 - accuracy: 0.8624 - val_loss: 1.5422 - val_accuracy: 0.8296
# Epoch 32/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5108 - accuracy: 0.8613 - val_loss: 1.5435 - val_accuracy: 0.8278
# Epoch 33/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5183 - accuracy: 0.8537 - val_loss: 1.5342 - val_accuracy: 0.8384
# Epoch 34/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5163 - accuracy: 0.8558 - val_loss: 1.5300 - val_accuracy: 0.8424
# Epoch 35/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5123 - accuracy: 0.8597 - val_loss: 1.5481 - val_accuracy: 0.8240
# Epoch 36/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5122 - accuracy: 0.8597 - val_loss: 1.5442 - val_accuracy: 0.8275
# Epoch 37/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5098 - accuracy: 0.8622 - val_loss: 1.5533 - val_accuracy: 0.8186
# Epoch 38/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5111 - accuracy: 0.8610 - val_loss: 1.5416 - val_accuracy: 0.8302
# Epoch 39/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5127 - accuracy: 0.8594 - val_loss: 1.5353 - val_accuracy: 0.8361
# Epoch 40/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5097 - accuracy: 0.8623 - val_loss: 1.5486 - val_accuracy: 0.8232
# Epoch 41/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5095 - accuracy: 0.8624 - val_loss: 1.5540 - val_accuracy: 0.8189
# Epoch 42/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5099 - accuracy: 0.8621 - val_loss: 1.5431 - val_accuracy: 0.8285
# Epoch 43/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5107 - accuracy: 0.8611 - val_loss: 1.5504 - val_accuracy: 0.8218
# Epoch 44/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5087 - accuracy: 0.8633 - val_loss: 1.5333 - val_accuracy: 0.8382
# Epoch 45/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5068 - accuracy: 0.8652 - val_loss: 1.5463 - val_accuracy: 0.8252
# Epoch 46/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5093 - accuracy: 0.8625 - val_loss: 1.5442 - val_accuracy: 0.8275
# Epoch 47/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5100 - accuracy: 0.8620 - val_loss: 1.5410 - val_accuracy: 0.8309
# Epoch 48/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5126 - accuracy: 0.8594 - val_loss: 1.5215 - val_accuracy: 0.8504
# Epoch 49/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5181 - accuracy: 0.8537 - val_loss: 1.5338 - val_accuracy: 0.8380
# Epoch 50/50
# 44534/44534 [==============================] - 2s 50us/sample - loss: 1.5137 - accuracy: 0.8582 - val_loss: 1.5469 - val_accuracy: 0.8250
# Train on 44504 samples, validate on 44504 samples
# Epoch 1/50
# 44504/44504 [==============================] - 8s 169us/sample - loss: 1.6941 - accuracy: 0.6954 - val_loss: 1.6334 - val_accuracy: 0.7519
# Epoch 2/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5958 - accuracy: 0.7789 - val_loss: 1.5741 - val_accuracy: 0.7978
# Epoch 3/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5588 - accuracy: 0.8146 - val_loss: 1.5346 - val_accuracy: 0.8384
# Epoch 4/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5542 - accuracy: 0.8186 - val_loss: 1.5482 - val_accuracy: 0.8234
# Epoch 5/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6483 - accuracy: 0.7254 - val_loss: 1.6186 - val_accuracy: 0.7555
# Epoch 6/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6311 - accuracy: 0.7418 - val_loss: 1.6094 - val_accuracy: 0.7659
# Epoch 7/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6249 - accuracy: 0.7475 - val_loss: 1.6087 - val_accuracy: 0.7631
# Epoch 8/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6378 - accuracy: 0.7349 - val_loss: 1.6154 - val_accuracy: 0.7603
# Epoch 9/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6229 - accuracy: 0.7494 - val_loss: 1.6161 - val_accuracy: 0.7570
# Epoch 10/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5818 - accuracy: 0.7900 - val_loss: 1.5741 - val_accuracy: 0.7978
# Epoch 11/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6061 - accuracy: 0.7662 - val_loss: 1.5559 - val_accuracy: 0.8166
# Epoch 12/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5552 - accuracy: 0.8166 - val_loss: 1.5566 - val_accuracy: 0.8158
# Epoch 13/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5274 - accuracy: 0.8451 - val_loss: 1.5434 - val_accuracy: 0.8287
# Epoch 14/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5282 - accuracy: 0.8438 - val_loss: 1.5348 - val_accuracy: 0.8375
# Epoch 15/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5219 - accuracy: 0.8502 - val_loss: 1.5251 - val_accuracy: 0.8469
# Epoch 16/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5233 - accuracy: 0.8486 - val_loss: 1.6218 - val_accuracy: 0.7477
# Epoch 17/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.6094 - accuracy: 0.7629 - val_loss: 1.5944 - val_accuracy: 0.7787
# Epoch 18/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5964 - accuracy: 0.7760 - val_loss: 1.5867 - val_accuracy: 0.7860
# Epoch 19/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.8930 - accuracy: 0.4787 - val_loss: 1.7948 - val_accuracy: 0.5771
# Epoch 20/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7599 - accuracy: 0.6084 - val_loss: 1.7071 - val_accuracy: 0.6656
# Epoch 21/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7170 - accuracy: 0.6522 - val_loss: 1.7077 - val_accuracy: 0.6623
# Epoch 22/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7132 - accuracy: 0.6564 - val_loss: 1.6915 - val_accuracy: 0.6778
# Epoch 23/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7418 - accuracy: 0.6284 - val_loss: 1.7565 - val_accuracy: 0.6166
# Epoch 24/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7788 - accuracy: 0.5922 - val_loss: 1.7556 - val_accuracy: 0.6157
# Epoch 25/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7746 - accuracy: 0.5950 - val_loss: 1.7526 - val_accuracy: 0.6173
# Epoch 26/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7725 - accuracy: 0.5964 - val_loss: 1.7498 - val_accuracy: 0.6208
# Epoch 27/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7718 - accuracy: 0.5965 - val_loss: 1.7492 - val_accuracy: 0.6203
# Epoch 28/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7701 - accuracy: 0.5975 - val_loss: 1.7493 - val_accuracy: 0.6188
# Epoch 29/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.7099 - accuracy: 0.6592 - val_loss: 1.5743 - val_accuracy: 0.7986
# Epoch 30/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5750 - accuracy: 0.7980 - val_loss: 1.5773 - val_accuracy: 0.7922
# Epoch 31/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5630 - accuracy: 0.8079 - val_loss: 1.5663 - val_accuracy: 0.8066
# Epoch 32/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5608 - accuracy: 0.8114 - val_loss: 1.5736 - val_accuracy: 0.7986
# Epoch 33/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5572 - accuracy: 0.8146 - val_loss: 1.5817 - val_accuracy: 0.7862
# Epoch 34/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5081 - accuracy: 0.8655 - val_loss: 1.5257 - val_accuracy: 0.8468
# Epoch 35/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5056 - accuracy: 0.8673 - val_loss: 1.5265 - val_accuracy: 0.8456
# Epoch 36/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.4993 - accuracy: 0.8732 - val_loss: 1.5348 - val_accuracy: 0.8371
# Epoch 37/50
# 44504/44504 [==============================] - 4s 89us/sample - loss: 1.5040 - accuracy: 0.8687 - val_loss: 1.5333 - val_accuracy: 0.8396
# Epoch 38/50
# 44504/44504 [==============================] - 4s 90us/sample - loss: 1.5127 - accuracy: 0.8594 - val_loss: 1.5185 - val_accuracy: 0.8530
# Epoch 39/50
# 44504/44504 [==============================] - 4s 89us/sample - loss: 1.5007 - accuracy: 0.8724 - val_loss: 1.5165 - val_accuracy: 0.8554
# Epoch 40/50
# 44504/44504 [==============================] - 4s 90us/sample - loss: 1.4926 - accuracy: 0.8797 - val_loss: 1.5238 - val_accuracy: 0.8479
# Epoch 41/50
# 44504/44504 [==============================] - 4s 89us/sample - loss: 1.5058 - accuracy: 0.8667 - val_loss: 1.5141 - val_accuracy: 0.8587
# Epoch 42/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.4932 - accuracy: 0.8795 - val_loss: 1.5192 - val_accuracy: 0.8524
# Epoch 43/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.4885 - accuracy: 0.8840 - val_loss: 1.5251 - val_accuracy: 0.8457
# Epoch 44/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5144 - accuracy: 0.8581 - val_loss: 1.5323 - val_accuracy: 0.8403
# Epoch 45/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5004 - accuracy: 0.8718 - val_loss: 1.5168 - val_accuracy: 0.8549
# Epoch 46/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5051 - accuracy: 0.8671 - val_loss: 1.5439 - val_accuracy: 0.8274
# Epoch 47/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.5026 - accuracy: 0.8694 - val_loss: 1.5239 - val_accuracy: 0.8490
# Epoch 48/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.4926 - accuracy: 0.8801 - val_loss: 1.5328 - val_accuracy: 0.8391
# Epoch 49/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.4948 - accuracy: 0.8773 - val_loss: 1.5185 - val_accuracy: 0.8535
# Epoch 50/50
# 44504/44504 [==============================] - 4s 88us/sample - loss: 1.4930 - accuracy: 0.8789 - val_loss: 1.5153 - val_accuracy: 0.8558

# %%
def plot(epochs, history):
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]
    legends = ["training", "validation"]
    print(f"Highest accuracy {np.max(val_acc)} at epoch {np.argmax(val_acc) + 1}")
    
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    axs = axs.flatten()
    axs[0].plot(np.arange(1,epochs+1), acc, marker="o")
    axs[0].plot(np.arange(1,epochs+1), val_acc, marker="D")
    axs[0].legend(legends)
    axs[0].grid(True)
    
    axs[1].plot(np.arange(1,epochs+1), loss, marker="o")
    axs[1].plot(np.arange(1,epochs+1), val_loss, marker="D")
    axs[1].legend(legends)
    axs[1].grid(True)
    
    plt.show()

# %% [markdown]
# ## 4. Evaluation

# %%
plot(50, histories[0])
# Out:
# Highest accuracy 0.8609172105789185 at epoch 44

# %%
plot(50, histories[1])
# Out:
# Highest accuracy 0.8530560731887817 at epoch 14

# %%
plot(50, histories[2])
# Out:
# Highest accuracy 0.8587093353271484 at epoch 41
