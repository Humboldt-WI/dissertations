# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Performance Plots

# %%
gr_nrmse = [1.45, -1.56, -0.5, -0.55, -1.34, 1.6, 1.34, 0.67, 3.18, 1.84]
pc_nrmse = [-2.8, -1.45, -1.51, -0.17, 1.28, -0.81, 0.06, -1.52, -0.76, -1.86]
rf_nrmse = [-0.44, -0.75, 1.44, 0.69, 0.50, 1.57, -0.19, -0.32, 1.88, -0.44]
am_nrmse = [-1.08, 1.82, -0.41, 0.08, -0.33, 0.25, 0.25, 0.17, 0.41, 1.91]

# %%
# Plot for feature performances
fe_groups = ['DT', 'W', 'A', 'Lon/off', 'P', 'Interact', 'VEST', 'PS', 'All', 'DT + W']
# data
#gr_nrmse = [1.45, -1.56, -0.5, -0.55, -1.34, 1.6, 1.34, 0.67, 3.18, 1.84]
#pc_nrmse = [-2.8, -1.45, -1.51, -0.17, 1.28, -0.81, 0.06, -1.52, -0.76, -1.86]
#rf_nrmse = [-0.44, -0.75, 1.44, 0.69, 0.50, 1.57, -0.19, -0.32, 1.88, -0.44]
#am_nrmse = [-1.08, 1.82, -0.41, 0.08, -0.33, 0.25, 0.25, 0.17, 0.41, 1.91]


x_axis = np.arange(len(fe_groups))*0.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
gr_nr = ax1.bar(x_axis -0.2, height = gr_nrmse, width=0.1, color='lightgreen', edgecolor='black', label='nRMSE')
pc_nr = ax1.bar(x_axis-0.1, height = pc_nrmse, width=0.1, color='lightblue', edgecolor='black', label='nRMSE')
rf_nr = ax1.bar(x_axis, height = rf_nrmse, width=0.1, color='lightcoral', edgecolor='black', label='nRMSE')
am_nr = ax1.bar(x_axis+0.1, height = am_nrmse, width=0.1, color='orange', edgecolor='black', label='nRMSE')


ax1.set_ylim(-4,4)
#ax2.set_ylim(-13,13)
#ax3.set_ylim(-4,4)
#ax4.set_ylim(-13,13)
# Label axes

ax1.set_xlabel('Feature Groups')
ax1.set_ylabel('nRMSE Change (\u0394 in %)')

plt.xticks(x_axis, fe_groups)
plt.legend([gr_nr, pc_nr, rf_nr, am_nr], ['GreenD', 'PecanDS', 'REFIT', 'AMPds'], loc='lower right')
plt.show()

# %%
from matplotlib import cm
cmap = cm.get_cmap('tab20')

df_nrmse = pd.DataFrame([gr_nrmse, pc_nrmse, rf_nrmse, am_nrmse], columns=['DT', 'W', 'A', 'Lon/off', 'P', 'Interact', 'VEST', 'PS', 'All', 'DT + W'])
df_list = ['GREEND', 'PecanSD', 'REFIT', 'AMPds2']

x_axis = np.arange(len(df_list))*1.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
dt_nr = ax1.bar(x_axis -0.5, height = df_nrmse['DT'], width=0.1, color=cmap(0), edgecolor='black', label='nRMSE')
w_nr = ax1.bar(x_axis-0.4, height = df_nrmse['W'], width=0.1, color=cmap(0.1), edgecolor='black', label='nRMSE')
a_nr = ax1.bar(x_axis-0.3, height = df_nrmse['A'], width=0.1, color=cmap(0.2), edgecolor='black', label='nRMSE')
l_nr = ax1.bar(x_axis-0.2, height = df_nrmse['Lon/off'], width=0.1, color=cmap(0.3), edgecolor='black', label='nRMSE')
p_nr = ax1.bar(x_axis -0.1, height = df_nrmse['P'], width=0.1, color=cmap(0.4), edgecolor='black', label='nRMSE')
i_nr = ax1.bar(x_axis, height = df_nrmse['Interact'], width=0.1, color=cmap(0.05), edgecolor='black', label='nRMSE')
v_nr = ax1.bar(x_axis+0.1, height = df_nrmse['VEST'], width=0.1, color=cmap(0.15), edgecolor='black', label='nRMSE')
ps_nr = ax1.bar(x_axis+0.2, height = df_nrmse['PS'], width=0.1, color=cmap(0.25), edgecolor='black', label='nRMSE')
all_nr = ax1.bar(x_axis+0.3, height = df_nrmse['All'], width=0.1, color=cmap(0.35), edgecolor='black', label='nRMSE')
wdt_nr = ax1.bar(x_axis+0.4, height = df_nrmse['DT + W'], width=0.1, color=cmap(0.45), edgecolor='black', label='nRMSE')


ax1.set_ylim(-4,4)
#ax2.set_ylim(-13,13)
#ax3.set_ylim(-4,4)
#ax4.set_ylim(-13,13)
# Label axes

ax1.set_xlabel('Feature Groups')
ax1.set_ylabel('nRMSE Change (\u0394 in %)')

plt.xticks(x_axis, df_list)
plt.legend([dt_nr, w_nr, a_nr, l_nr, p_nr, i_nr, v_nr, ps_nr, all_nr, wdt_nr], ['date time', 'weather', 'appliances', 'Lon/off', 'past', 'interact', 'VEST', 'phase space', 'all', 'DT + W'], loc='lower right', ncol=2)
plt.show()

# %%
# Plot for feature performances
fe_groups = ['DT', 'W', 'A', 'Lon/off', 'P', 'Interact', 'VEST', 'PS', 'All', 'DT + W']
# data
gr_acc = [6, -2, -1, 1, -1, -5, 2, 0, -2, 3]
pc_acc = [1, 8, 1, 1, 1, 2, -4, -1, -1, 12]
rf_acc = [-1, -1, 0, 0, -1, 0, -1, 0, 0, -2]
am_acc = [3, -3, 0, 1, 1, 0, 0, 0, 1, 1]

x_axis = np.arange(len(fe_groups))*0.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
gr_nr = ax1.bar(x_axis -0.2, height = gr_acc, width=0.1, color='green', edgecolor='black', label='Accuracy')
pc_nr = ax1.bar(x_axis-0.1, height = pc_acc, width=0.1, color='blue', edgecolor='black', label='Accuracy')
rf_nr = ax1.bar(x_axis, height = rf_acc, width=0.1, color='red', edgecolor='black', label='Accuracy')
am_nr = ax1.bar(x_axis+0.1, height = am_acc, width=0.1, color='darkorange', edgecolor='black', label='Accuracy')


ax1.set_ylim(-13,13)

ax1.set_xlabel('Feature Groups')
ax1.set_ylabel('Accuracy Change (\u0394 in percentage points)')

plt.xticks(x_axis, fe_groups)
plt.legend([gr_nr, pc_nr, rf_nr, am_nr], ['GreenD', 'PecanDS', 'REFIT', 'AMPds'], loc='lower right')
plt.show()


#gr_ac = ax2.bar(x_axis -0.1, height = gr_acc, width=0.1, color='green', label='Accuracy')
#pc_ac = ax4.bar(x_axis +0.1, height = pc_acc, width=0.1, color='blue', label='Accuracy')

# %%
from matplotlib import cm
cmap = cm.get_cmap('tab20')

df_nrmse = pd.DataFrame([gr_acc, pc_acc, rf_acc, am_acc], columns=['DT', 'W', 'A', 'Lon/off', 'P', 'Interact', 'VEST', 'PS', 'All', 'DT + W'])
df_list = ['GREEND', 'PecanSD', 'REFIT', 'AMPds2']

x_axis = np.arange(len(df_list))*1.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
dt_nr = ax1.bar(x_axis -0.5, height = df_nrmse['DT'], width=0.1, color=cmap(0), edgecolor='black', label='nRMSE')
w_nr = ax1.bar(x_axis-0.4, height = df_nrmse['W'], width=0.1, color=cmap(0.1), edgecolor='black', label='nRMSE')
a_nr = ax1.bar(x_axis-0.3, height = df_nrmse['A'], width=0.1, color=cmap(0.2), edgecolor='black', label='nRMSE')
l_nr = ax1.bar(x_axis-0.2, height = df_nrmse['Lon/off'], width=0.1, color=cmap(0.3), edgecolor='black', label='nRMSE')
p_nr = ax1.bar(x_axis -0.1, height = df_nrmse['P'], width=0.1, color=cmap(0.4), edgecolor='black', label='nRMSE')
i_nr = ax1.bar(x_axis, height = df_nrmse['Interact'], width=0.1, color=cmap(0.05), edgecolor='black', label='nRMSE')
v_nr = ax1.bar(x_axis+0.1, height = df_nrmse['VEST'], width=0.1, color=cmap(0.15), edgecolor='black', label='nRMSE')
ps_nr = ax1.bar(x_axis+0.2, height = df_nrmse['PS'], width=0.1, color=cmap(0.25), edgecolor='black', label='nRMSE')
all_nr = ax1.bar(x_axis+0.3, height = df_nrmse['All'], width=0.1, color=cmap(0.35), edgecolor='black', label='nRMSE')
wdt_nr = ax1.bar(x_axis+0.4, height = df_nrmse['DT + W'], width=0.1, color=cmap(0.45), edgecolor='black', label='nRMSE')


ax1.set_ylim(-13,13)
#ax2.set_ylim(-13,13)
#ax3.set_ylim(-4,4)
#ax4.set_ylim(-13,13)
# Label axes

ax1.set_xlabel('Feature Groups')
ax1.set_ylabel('Accuracy Change (\u0394 in percentage points)')

plt.xticks(x_axis, df_list)
plt.legend([dt_nr, w_nr, a_nr, l_nr, p_nr, i_nr, v_nr, ps_nr, all_nr, wdt_nr], ['date time', 'weather', 'appliances', 'Lon/off', 'past', 'interact', 'VEST', 'phase space', 'all', 'DT + W'], loc='lower right', ncol=2)
plt.show()

# %% [markdown]
# ## PLots with max metric score

# %%
# Mean Model performances:
from matplotlib import cm
cmap = cm.get_cmap('tab20')
# Plot for feature performances
model_groups = ['XGBoost', 'MSVR', 'LSTM', 'BiLSTM', 'S2S\n reversed', 'S2S\n context', 'FFNN', 'CNN-LSTM']
# data
gr_nrmse = [0.1843, 0.1734, 0.1710, 0.1716, 0.1746, 0.1740, 0.1730, 0.1757]
pc_nrmse = [0.1720, 0.1812, 0.1637, 0.1653, 0.1662, 0.1657, 0.1653, 0.1671]
rf_nrmse = [0.1688, 0.1552, 0.1569, 0.1571, 0.1553, 0.1558, 0.1556, 0.1560]
am_nrmse = [0.1290, 0.1176, 0.1187, 0.1175, 0.1182, 0.1180, 0.1173, 0.1172]


x_axis = np.arange(len(model_groups))*0.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
gr_nr = ax1.bar(x_axis -0.2, height = gr_nrmse, width=0.1, color=cmap(0.2), edgecolor='black', label='nRMSE')
pc_nr = ax1.bar(x_axis-0.1, height = pc_nrmse, width=0.1, color=cmap(0.25), edgecolor='black', label='nRMSE')
rf_nr = ax1.bar(x_axis, height = rf_nrmse, width=0.1, color=cmap(0.3), edgecolor='black', label='nRMSE')
am_nr = ax1.bar(x_axis+0.1, height = am_nrmse, width=0.1, color=cmap(0.35), edgecolor='black', label='nRMSE')

ax1.set_ylim(0.1,0.2)

ax1.set_xlabel('Model')
ax1.set_ylabel('nRMSE Score')

plt.xticks(x_axis, model_groups)
plt.legend([gr_nr, pc_nr, rf_nr, am_nr], ['GreenD', 'PecanDS', 'REFIT', 'AMPds'], loc='lower right')
plt.show()

# %%
model_gr =['XGBoost', 'MSVR', 'LSTM', 'BiLSTM', 'S2S reversed', 'S2S context', 'FFNN', 'CNN-LSTM']
df_nrmse = pd.DataFrame([gr_nrmse, pc_nrmse, rf_nrmse, am_nrmse], columns=model_gr)
df_list = ['GREEND', 'PecanSD', 'REFIT', 'AMPds2']

x_axis = np.arange(len(df_list))*1.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
xg_nr = ax1.bar(x_axis -0.5, height = df_nrmse['XGBoost'], width=0.1, color=cmap(0), edgecolor='black', label='nRMSE')
ms_nr = ax1.bar(x_axis-0.4, height = df_nrmse['MSVR'], width=0.1, color=cmap(0.1), edgecolor='black', label='nRMSE')
ls_nr = ax1.bar(x_axis-0.3, height = df_nrmse['LSTM'], width=0.1, color=cmap(0.2), edgecolor='black', label='nRMSE')
bi_nr = ax1.bar(x_axis-0.2, height = df_nrmse['BiLSTM'], width=0.1, color=cmap(0.3), edgecolor='black', label='nRMSE')
rev_nr = ax1.bar(x_axis -0.1, height = df_nrmse['S2S reversed'], width=0.1, color=cmap(0.5), edgecolor='black', label='nRMSE')
con_nr = ax1.bar(x_axis, height = df_nrmse['S2S context'], width=0.1, color=cmap(0.6), edgecolor='black', label='nRMSE')
fn_nr = ax1.bar(x_axis+0.1, height = df_nrmse['FFNN'], width=0.1, color=cmap(0.7), edgecolor='black', label='nRMSE')
cnn_nr = ax1.bar(x_axis+0.2, height = df_nrmse['CNN-LSTM'], width=0.1, color=cmap(0.8), edgecolor='black', label='nRMSE')



ax1.set_ylim(0,0.2)
#ax2.set_ylim(-13,13)
#ax3.set_ylim(-4,4)
#ax4.set_ylim(-13,13)
# Label axes

ax1.set_xlabel('Model')
ax1.set_ylabel('nRMSE Score')

plt.xticks(x_axis, df_list)
plt.legend([xg_nr, ms_nr, ls_nr, bi_nr, rev_nr, con_nr, fn_nr, cnn_nr], ['XGBoost', 'MSVR', 'LSTM', 'BiLSTM', 'S2S reversed', 'S2S context', 'FFNN', 'CNN-LSTM'], loc='upper right', ncol=2)
plt.show()

# %%
# Mean Model performances: Accuracy
fe_groups = ['XGBoost', 'MSVR', 'LSTM', 'BiLSTM', 'S2S\n reversed', 'S2S\n context', 'FFNN', 'CNN-LSTM']
# data
gr_acc = [55, 61, 73, 72, 54, 62, 64, 61]
pc_acc = [49, 55, 64, 58, 57, 63, 59, 61]
rf_acc = [81, 78, 78, 78, 78, 79, 78, 79]
am_acc = [50, 55, 58, 58, 61, 59, 59, 59]

x_axis = np.arange(len(fe_groups))*0.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
gr_nr = ax1.bar(x_axis -0.2, height = gr_acc, width=0.1, color='green', edgecolor='black', label='Accuracy')
pc_nr = ax1.bar(x_axis-0.1, height = pc_acc, width=0.1, color='blue', edgecolor='black', label='Accuracy')
rf_nr = ax1.bar(x_axis, height = rf_acc, width=0.1, color='red', edgecolor='black', label='Accuracy')
am_nr = ax1.bar(x_axis+0.1, height = am_acc, width=0.1, color='darkorange', edgecolor='black', label='Accuracy')


ax1.set_ylim(0,90)

ax1.set_xlabel('Model')
ax1.set_ylabel('mean 95%-Accuracy in %')

plt.xticks(x_axis, fe_groups)
plt.legend([gr_nr, pc_nr, rf_nr, am_nr], ['GreenD', 'PecanDS', 'REFIT', 'AMPds'], loc='lower right')
plt.show()

# %%
model_gr =['XGBoost', 'MSVR', 'LSTM', 'BiLSTM', 'S2S reversed', 'S2S context', 'FFNN', 'CNN-LSTM']
df_nrmse = pd.DataFrame([gr_acc, pc_acc, rf_acc, am_acc], columns=model_gr)
df_list = ['GREEND', 'PecanSD', 'REFIT', 'AMPds2']

x_axis = np.arange(len(df_list))*1.5

# PLot GreenD
fig, ax1 = plt.subplots(figsize = (7, 5))
# creating a bar plot
xg_nr = ax1.bar(x_axis -0.5, height = df_nrmse['XGBoost'], width=0.1, color=cmap(0), edgecolor='black', label='nRMSE')
ms_nr = ax1.bar(x_axis-0.4, height = df_nrmse['MSVR'], width=0.1, color=cmap(0.1), edgecolor='black', label='nRMSE')
ls_nr = ax1.bar(x_axis-0.3, height = df_nrmse['LSTM'], width=0.1, color=cmap(0.2), edgecolor='black', label='nRMSE')
bi_nr = ax1.bar(x_axis-0.2, height = df_nrmse['BiLSTM'], width=0.1, color=cmap(0.3), edgecolor='black', label='nRMSE')
rev_nr = ax1.bar(x_axis -0.1, height = df_nrmse['S2S reversed'], width=0.1, color=cmap(0.5), edgecolor='black', label='nRMSE')
con_nr = ax1.bar(x_axis, height = df_nrmse['S2S context'], width=0.1, color=cmap(0.6), edgecolor='black', label='nRMSE')
fn_nr = ax1.bar(x_axis+0.1, height = df_nrmse['FFNN'], width=0.1, color=cmap(0.7), edgecolor='black', label='nRMSE')
cnn_nr = ax1.bar(x_axis+0.2, height = df_nrmse['CNN-LSTM'], width=0.1, color=cmap(0.8), edgecolor='black', label='nRMSE')



ax1.set_ylim(0,90)
#ax2.set_ylim(-13,13)
#ax3.set_ylim(-4,4)
#ax4.set_ylim(-13,13)
# Label axes

ax1.set_xlabel('Model')
ax1.set_ylabel('mean 95%-Accuracy in %')

plt.xticks(x_axis, df_list)
plt.legend([xg_nr, ms_nr, ls_nr, bi_nr, rev_nr, con_nr, fn_nr, cnn_nr], ['XGBoost', 'MSVR', 'LSTM', 'BiLSTM', 'S2S reversed', 'S2S context', 'FFNN', 'CNN-LSTM'], loc='lower right', ncol=2)
plt.show()
