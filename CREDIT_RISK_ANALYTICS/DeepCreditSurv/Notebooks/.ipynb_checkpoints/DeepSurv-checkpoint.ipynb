# %%
import os
import pandas as pd
path = "D:\DeepCreditSurv"
os.chdir(path)

# %%
from DeepCreditSurv.models import DeepSurv

# %%
ds_m1 = DeepSurv.DeepSurv(dataset='M1',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M1\WideFormatMortgageAfterRemovingNull.csv")
best_lr = ds_m1.find_lr()
print(best_lr)
# Out:
# 0.10722672220103299

# %%
cis_m1 = ds_m1.build_model(lr=0.01)
print(cis_m1)
# Out:
# 0:	[0s / 0s],		train_loss: 3.8701,	val_loss: 3.4347
# 1:	[0s / 0s],		train_loss: 3.4738,	val_loss: 3.2927
# 2:	[0s / 1s],		train_loss: 3.3698,	val_loss: 3.1927
# 3:	[0s / 1s],		train_loss: 3.2908,	val_loss: 3.1513
# 4:	[0s / 1s],		train_loss: 3.2784,	val_loss: 3.1729
# 5:	[0s / 2s],		train_loss: 3.2445,	val_loss: 3.0765
# 6:	[0s / 2s],		train_loss: 3.2067,	val_loss: 3.0718
# 7:	[0s / 2s],		train_loss: 3.1729,	val_loss: 3.0587
# 8:	[0s / 3s],		train_loss: 3.1541,	val_loss: 3.0652
# 9:	[0s / 3s],		train_loss: 3.1429,	val_loss: 3.0352
# 10:	[0s / 3s],		train_loss: 3.1241,	val_loss: 2.9768
# 11:	[0s / 4s],		train_loss: 3.1252,	val_loss: 2.9602
# 12:	[0s / 4s],		train_loss: 3.0981,	val_loss: 2.9733
# 13:	[0s / 4s],		train_loss: 3.0817,	val_loss: 2.9539
# 14:	[0s / 5s],		train_loss: 3.0716,	val_loss: 2.9619
# 15:	[0s / 5s],		train_loss: 3.0724,	val_loss: 2.9278
# 16:	[0s / 5s],		train_loss: 3.0657,	val_loss: 2.9288
# 17:	[0s / 6s],		train_loss: 3.0597,	val_loss: 2.9215
# 18:	[0s / 6s],		train_loss: 3.0440,	val_loss: 2.8981
# 19:	[0s / 6s],		train_loss: 3.0207,	val_loss: 2.9110
# 20:	[0s / 7s],		train_loss: 3.0375,	val_loss: 2.9759
# 21:	[0s / 7s],		train_loss: 3.0724,	val_loss: 2.9201
# 22:	[0s / 7s],		train_loss: 3.0318,	val_loss: 2.8989
# 23:	[0s / 8s],		train_loss: 3.0275,	val_loss: 2.9215
# 24:	[0s / 8s],		train_loss: 3.0232,	val_loss: 2.8925
# 25:	[0s / 8s],		train_loss: 3.0203,	val_loss: 2.9082
# 26:	[0s / 9s],		train_loss: 3.0162,	val_loss: 2.9357
# 27:	[0s / 9s],		train_loss: 3.0286,	val_loss: 2.8980
# 28:	[0s / 9s],		train_loss: 3.0220,	val_loss: 2.8949
# 29:	[0s / 10s],		train_loss: 3.0138,	val_loss: 2.8729
# 30:	[0s / 10s],		train_loss: 3.0351,	val_loss: 2.9230
# 31:	[0s / 10s],		train_loss: 3.0007,	val_loss: 2.8895
# 32:	[0s / 11s],		train_loss: 3.0398,	val_loss: 2.8894
# 33:	[0s / 11s],		train_loss: 3.0132,	val_loss: 2.8895
# 34:	[0s / 11s],		train_loss: 2.9965,	val_loss: 2.8745
# 35:	[0s / 12s],		train_loss: 3.0141,	val_loss: 2.8860
# 36:	[0s / 12s],		train_loss: 3.0207,	val_loss: 2.8809
# 37:	[0s / 12s],		train_loss: 2.9785,	val_loss: 2.8632
# 38:	[0s / 13s],		train_loss: 2.9936,	val_loss: 2.8719
# 39:	[0s / 13s],		train_loss: 2.9891,	val_loss: 2.8799
# 40:	[0s / 13s],		train_loss: 2.9940,	val_loss: 2.8601
# 41:	[0s / 14s],		train_loss: 2.9980,	val_loss: 2.8933
# 42:	[0s / 14s],		train_loss: 2.9919,	val_loss: 2.8963
# 43:	[0s / 14s],		train_loss: 2.9823,	val_loss: 2.8771
# 44:	[0s / 15s],		train_loss: 2.9948,	val_loss: 2.8524
# 45:	[0s / 15s],		train_loss: 2.9929,	val_loss: 2.8750
# 46:	[0s / 15s],		train_loss: 2.9951,	val_loss: 2.8542
# 47:	[0s / 16s],		train_loss: 2.9848,	val_loss: 2.8524
# 48:	[0s / 16s],		train_loss: 2.9675,	val_loss: 2.8348
# 49:	[0s / 16s],		train_loss: 2.9782,	val_loss: 2.8757
# 50:	[0s / 17s],		train_loss: 2.9672,	val_loss: 2.8578
# 51:	[0s / 17s],		train_loss: 2.9863,	val_loss: 2.8382
# 52:	[0s / 17s],		train_loss: 2.9733,	val_loss: 2.8683
# 53:	[0s / 18s],		train_loss: 2.9890,	val_loss: 2.8856
# 54:	[0s / 18s],		train_loss: 2.9709,	val_loss: 2.8495
# 55:	[0s / 18s],		train_loss: 2.9666,	val_loss: 2.8525
# 56:	[0s / 19s],		train_loss: 2.9673,	val_loss: 2.8482
# 57:	[0s / 19s],		train_loss: 2.9857,	val_loss: 2.8680
# 58:	[0s / 19s],		train_loss: 2.9687,	val_loss: 2.8719
# (52, 9996)
# 0.9290374664178611

# %%
ds_m2 = DeepSurv.DeepSurv(dataset='M2',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M2")
best_lr = ds_m2.find_lr()
print(best_lr)
# Out:
# Index(['payoff', 'label_0', 'label_1', 'label_2', 'current_year_1999',
#        'current_year_2000', 'current_year_2001', 'current_year_2002',
#        'current_year_2003', 'current_year_2004', 'current_year_2005',
#        'current_year_2006', 't.act.12m_0', 't.act.12m_1', 't.act.12m_2',
#        't.act.12m_3', 't.act.12m_4', 't.act.12m_5', 't.act.12m_6',
#        't.act.12m_7', 't.act.12m_8', 't.act.12m_9', 't.act.12m_10',
#        't.act.12m_11', 't.act.12m_12', 't.del.30d.12m_0', 't.del.30d.12m_1',
#        't.del.30d.12m_2', 't.del.30d.12m_3', 't.del.30d.12m_4',
#        't.del.30d.12m_5', 't.del.30d.12m_6', 't.del.30d.12m_7',
#        't.del.30d.12m_8', 't.del.30d.12m_9', 't.del.30d.12m_10',
#        't.del.30d.12m_11', 't.del.30d.12m_12', 't.del.60d.12m_0',
#        't.del.60d.12m_1', 't.del.60d.12m_2', 't.del.60d.12m_3',
#        't.del.60d.12m_4', 't.del.60d.12m_5', 't.del.60d.12m_6',
#        't.del.60d.12m_7', 't.del.60d.12m_8', 't.del.60d.12m_9',
#        't.del.60d.12m_10', 't.del.60d.12m_11', 't.del.60d.12m_12'],
#       dtype='object')
# 0.07390722033525823

# %%
cis_m2 = ds_m2.build_model(lr=0.01)
print(cis_m2)
# Out:
# 0:	[0s / 0s],		train_loss: 4.3115,	val_loss: 3.6212
# 1:	[0s / 0s],		train_loss: 1.7778,	val_loss: 2.2628
# 2:	[0s / 0s],		train_loss: 1.7824,	val_loss: 1.3201
# 3:	[0s / 0s],		train_loss: 1.3979,	val_loss: 1.0047
# 4:	[0s / 0s],		train_loss: 1.1205,	val_loss: 0.8580
# 5:	[0s / 0s],		train_loss: 1.5359,	val_loss: 0.8093
# 6:	[0s / 0s],		train_loss: 1.2554,	val_loss: 0.8462
# 7:	[0s / 0s],		train_loss: 0.9226,	val_loss: 0.8566
# 8:	[0s / 0s],		train_loss: 1.2827,	val_loss: 0.7621
# 9:	[0s / 0s],		train_loss: 0.8551,	val_loss: 0.7427
# 10:	[0s / 0s],		train_loss: 0.8762,	val_loss: 0.8017
# 11:	[0s / 0s],		train_loss: 0.9377,	val_loss: 0.8049
# 12:	[0s / 0s],		train_loss: 0.8158,	val_loss: 0.7627
# 13:	[0s / 0s],		train_loss: 0.8703,	val_loss: 0.6942
# 14:	[0s / 0s],		train_loss: 0.6497,	val_loss: 0.6627
# 15:	[0s / 0s],		train_loss: 0.6573,	val_loss: 0.6554
# 16:	[0s / 0s],		train_loss: 0.7404,	val_loss: 0.6661
# 17:	[0s / 0s],		train_loss: 0.8900,	val_loss: 0.6902
# 18:	[0s / 0s],		train_loss: 0.5226,	val_loss: 0.8318
# 19:	[0s / 0s],		train_loss: 0.5378,	val_loss: 0.8045
# 20:	[0s / 0s],		train_loss: 0.7224,	val_loss: 0.7749
# 21:	[0s / 0s],		train_loss: 0.6957,	val_loss: 0.7234
# 22:	[0s / 0s],		train_loss: 0.9030,	val_loss: 0.6790
# 23:	[0s / 0s],		train_loss: 0.5837,	val_loss: 0.6738
# 24:	[0s / 0s],		train_loss: 0.4809,	val_loss: 0.6677
# 25:	[0s / 0s],		train_loss: 0.7214,	val_loss: 0.7306
# (67, 20000)
# 0.9920992079202361

# %%
ds_ppdai = DeepSurv.DeepSurv(dataset='ppdai',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\ppdai")
best_lr = ds_ppdai.find_lr()
print(best_lr)
# Out:
# Index(['IsFirstTime', 'PhoneVerified', 'RegistrationVerified', 'VideoVerified',
#        'DegreeVerified', 'CreditVerified', 'TaobaoVerified', 'Gender_Female',
#        'Gender_Male', 'BorrowerRating_A', 'BorrowerRating_B',
#        'BorrowerRating_C', 'BorrowerRating_D', 'BorrowerRating_E',
#        'BorrowerRating_F', 'LoanType_E-commerce', 'LoanType_Normal',
#        'LoanType_Others', 'LoanPeriod_1', 'LoanPeriod_3', 'LoanPeriod_4',
#        'LoanPeriod_5', 'LoanPeriod_6', 'LoanPeriod_7', 'LoanPeriod_8',
#        'LoanPeriod_9', 'LoanPeriod_10', 'LoanPeriod_11', 'LoanPeriod_12',
#        'LoanPeriod_17', 'LoanPeriod_18', 'LoanPeriod_20', 'LoanPeriod_24'],
#       dtype='object')
# 0.10722672220103299

# %%
cis_ppdai = ds_ppdai.build_model(lr=0.1)
print(cis_ppdai)
# Out:
# 0:	[0s / 0s],		train_loss: 3.9976,	val_loss: 3.6490
# 1:	[0s / 0s],		train_loss: 3.7564,	val_loss: 3.5678
# 2:	[0s / 1s],		train_loss: 3.6762,	val_loss: 3.6025
# 3:	[0s / 1s],		train_loss: 3.6431,	val_loss: 3.4681
# 4:	[0s / 1s],		train_loss: 3.6005,	val_loss: 3.4800
# 5:	[0s / 2s],		train_loss: 3.5636,	val_loss: 3.4459
# 6:	[0s / 2s],		train_loss: 3.5067,	val_loss: 3.5764
# 7:	[0s / 2s],		train_loss: 3.7690,	val_loss: 3.9903
# 8:	[0s / 2s],		train_loss: 3.9521,	val_loss: 3.5697
# 9:	[0s / 3s],		train_loss: 3.7439,	val_loss: 3.4983
# 10:	[0s / 3s],		train_loss: 3.6498,	val_loss: 3.8028
# 11:	[0s / 3s],		train_loss: 3.5814,	val_loss: 3.4171
# 12:	[0s / 4s],		train_loss: 3.5495,	val_loss: 3.3443
# 13:	[0s / 4s],		train_loss: 3.5142,	val_loss: 3.4990
# 14:	[0s / 4s],		train_loss: 3.5067,	val_loss: 3.3276
# 15:	[0s / 5s],		train_loss: 3.4621,	val_loss: 3.3010
# 16:	[0s / 5s],		train_loss: 3.4477,	val_loss: 3.2781
# 17:	[0s / 5s],		train_loss: 3.4237,	val_loss: 3.2749
# 18:	[0s / 6s],		train_loss: 3.4249,	val_loss: 3.2969
# 19:	[0s / 6s],		train_loss: 3.3991,	val_loss: 3.2584
# 20:	[0s / 6s],		train_loss: 3.4054,	val_loss: 3.2481
# 21:	[0s / 7s],		train_loss: 3.4110,	val_loss: 3.2283
# 22:	[0s / 7s],		train_loss: 3.3945,	val_loss: 3.2718
# 23:	[0s / 7s],		train_loss: 3.3832,	val_loss: 3.1514
# 24:	[0s / 8s],		train_loss: 3.3767,	val_loss: 3.4302
# 25:	[0s / 8s],		train_loss: 3.3634,	val_loss: 3.2577
# 26:	[0s / 8s],		train_loss: 3.3551,	val_loss: 3.1333
# 27:	[0s / 9s],		train_loss: 3.3577,	val_loss: 3.2250
# 28:	[0s / 9s],		train_loss: 3.3152,	val_loss: 3.1977
# 29:	[0s / 9s],		train_loss: 3.3490,	val_loss: 3.1146
# 30:	[0s / 10s],		train_loss: 3.3014,	val_loss: 3.3265
# 31:	[0s / 10s],		train_loss: 3.3350,	val_loss: 3.0927
# 32:	[0s / 10s],		train_loss: 3.3158,	val_loss: 3.1458
# 33:	[0s / 11s],		train_loss: 3.3291,	val_loss: 3.1100
# 34:	[0s / 11s],		train_loss: 3.3191,	val_loss: 3.0907
# 35:	[0s / 11s],		train_loss: 3.3001,	val_loss: 3.1111
# 36:	[0s / 12s],		train_loss: 3.3367,	val_loss: 3.1654
# 37:	[0s / 12s],		train_loss: 3.2980,	val_loss: 3.1694
# 38:	[0s / 12s],		train_loss: 3.2919,	val_loss: 3.2065
# 39:	[0s / 13s],		train_loss: 3.3067,	val_loss: 3.1404
# 40:	[0s / 13s],		train_loss: 3.3039,	val_loss: 3.1324
# 41:	[0s / 13s],		train_loss: 3.2971,	val_loss: 3.1159
# 42:	[0s / 14s],		train_loss: 3.2677,	val_loss: 3.0759
# 43:	[0s / 14s],		train_loss: 3.2841,	val_loss: 3.1695
# 44:	[0s / 14s],		train_loss: 3.2721,	val_loss: 3.1378
# 45:	[0s / 15s],		train_loss: 3.2876,	val_loss: 3.3470
# 46:	[0s / 15s],		train_loss: 3.3412,	val_loss: 3.2619
# 47:	[0s / 15s],		train_loss: 3.3089,	val_loss: 3.1231
# 48:	[0s / 16s],		train_loss: 3.2828,	val_loss: 3.0720
# 49:	[0s / 16s],		train_loss: 3.3935,	val_loss: 3.1325
# 50:	[0s / 16s],		train_loss: 3.3460,	val_loss: 3.1397
# 51:	[0s / 17s],		train_loss: 3.3121,	val_loss: 3.1538
# 52:	[0s / 17s],		train_loss: 3.4463,	val_loss: 3.1547
# 53:	[0s / 17s],		train_loss: 3.2903,	val_loss: 3.1554
# 54:	[0s / 18s],		train_loss: 3.3193,	val_loss: 3.1065
# 55:	[0s / 18s],		train_loss: 3.3087,	val_loss: 3.1842
# 56:	[0s / 18s],		train_loss: 3.2687,	val_loss: 3.1410
# 57:	[0s / 19s],		train_loss: 3.2794,	val_loss: 3.1214
# 58:	[0s / 19s],		train_loss: 3.2883,	val_loss: 3.1109
# (24, 10000)
# 0.9813399874580722

# %%
ds_lc = DeepSurv.DeepSurv(dataset='LC',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\LendingClub\XYZCorp_LendingData.txt")
best_lr = ds_lc.find_lr()
print(best_lr)
# Out:
# Columns with less than 90% of the data included:
# ['all_util', 'annual_inc_joint', 'desc', 'dti_joint', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'mths_since_last_delinq', 'mths_since_last_major_derog', 'mths_since_last_record', 'mths_since_rcnt_il', 'next_pymnt_d', 'open_acc_6m', 'open_il_12m', 'open_il_24m', 'open_il_6m', 'open_rv_12m', 'open_rv_24m', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'default_ind'],
#       dtype='object')
# Index(['pymnt_plan', 'initial_list_status', 'application_type', 'grade_A',
#        'grade_B', 'grade_C', 'grade_D', 'grade_E', 'grade_F', 'grade_G',
#        'emp_length_1 year', 'emp_length_10+ years', 'emp_length_2 years',
#        'emp_length_3 years', 'emp_length_4 years', 'emp_length_5 years',
#        'emp_length_6 years', 'emp_length_7 years', 'emp_length_8 years',
#        'emp_length_9 years', 'emp_length_< 1 year', 'home_ownership_ANY',
#        'home_ownership_MORTGAGE', 'home_ownership_NONE',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'sub_grade_A1', 'sub_grade_A2', 'sub_grade_A3', 'sub_grade_A4',
#        'sub_grade_A5', 'sub_grade_B1', 'sub_grade_B2', 'sub_grade_B3',
#        'sub_grade_B4', 'sub_grade_B5', 'sub_grade_C1', 'sub_grade_C2',
#        'sub_grade_C3', 'sub_grade_C4', 'sub_grade_C5', 'sub_grade_D1',
#        'sub_grade_D2', 'sub_grade_D3', 'sub_grade_D4', 'sub_grade_D5',
#        'sub_grade_E1', 'sub_grade_E2', 'sub_grade_E3', 'sub_grade_E4',
#        'sub_grade_E5', 'sub_grade_F1', 'sub_grade_F2', 'sub_grade_F3',
#        'sub_grade_F4', 'sub_grade_F5', 'sub_grade_G1', 'sub_grade_G2',
#        'sub_grade_G3', 'sub_grade_G4', 'sub_grade_G5', 'purpose_car',
#        'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement', 'purpose_house',
#        'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
#        'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
#        'purpose_vacation', 'purpose_wedding',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified',
#        'term_ 36 months', 'term_ 60 months'],
#       dtype='object')
# 0.050941380148164093

# %%
cis_lc= ds_lc.build_model(lr=0.01)
print(cis_lc)
# Out:
# 0:	[4s / 4s],		train_loss: 1.1584,	val_loss: 0.9078
# 1:	[4s / 9s],		train_loss: 0.9738,	val_loss: 0.9038
# 2:	[5s / 14s],		train_loss: 0.9336,	val_loss: 0.8416
# 3:	[5s / 19s],		train_loss: 0.9253,	val_loss: 0.8108
# 4:	[5s / 25s],		train_loss: 0.8972,	val_loss: 0.8176
# 5:	[5s / 30s],		train_loss: 0.8958,	val_loss: 0.8043
# 6:	[4s / 35s],		train_loss: 0.8934,	val_loss: 0.8145
# 7:	[4s / 40s],		train_loss: 0.8774,	val_loss: 0.7962
# 8:	[4s / 44s],		train_loss: 0.8702,	val_loss: 0.8032
# 9:	[4s / 49s],		train_loss: 0.8665,	val_loss: 0.8138
# 10:	[4s / 54s],		train_loss: 0.8659,	val_loss: 0.7965
# 11:	[4s / 59s],		train_loss: 0.8574,	val_loss: 0.8153
# 12:	[4s / 1m:4s],		train_loss: 0.8530,	val_loss: 0.7904
# 13:	[4s / 1m:9s],
# 14:	[4s / 1m:14s],
# 15:	[4s / 1m:19s],
# 16:	[4s / 1m:24s],
# 17:	[4s / 1m:29s],
# 18:	[5s / 1m:34s],
# 19:	[5s / 1m:39s],
# 20:	[5s / 1m:44s],
# 21:	[5s / 1m:49s],
# 22:	[5s / 1m:54s],
# (41, 146899)
# 0.9956796694751209
