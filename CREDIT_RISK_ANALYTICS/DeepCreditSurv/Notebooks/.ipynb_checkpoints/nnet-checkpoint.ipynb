# %%
import os
import pandas as pd
path = "D:\DeepCreditSurv"
os.chdir(path)

# %%
from DeepCreditSurv.models import nnet

# %%
nnet_m1 = nnet.Nnet(dataset='M1',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M1\WideFormatMortgageAfterRemovingNull.csv")
cis_m1 = nnet_m1.build_model()
print(cis_m1)
# Out:
# None
# 0:	[3s / 3s],		train_loss: 0.8182,	val_loss: 0.5682
# 1:	[0s / 3s],		train_loss: 0.5497,	val_loss: 0.5210
# 2:	[0s / 4s],		train_loss: 0.5223,	val_loss: 0.5187
# 3:	[0s / 4s],		train_loss: 0.4975,	val_loss: 0.4826
# 4:	[0s / 4s],		train_loss: 0.4854,	val_loss: 0.4677
# 5:	[0s / 5s],		train_loss: 0.4646,	val_loss: 0.4608
# 6:	[0s / 5s],		train_loss: 0.4537,	val_loss: 0.4530
# 7:	[0s / 6s],		train_loss: 0.4450,	val_loss: 0.4691
# 8:	[0s / 6s],		train_loss: 0.4364,	val_loss: 0.4272
# 9:	[0s / 7s],		train_loss: 0.4300,	val_loss: 0.4222
# 10:	[0s / 7s],		train_loss: 0.4230,	val_loss: 0.4411
# 11:	[0s / 8s],		train_loss: 0.4159,	val_loss: 0.4021
# 12:	[0s / 8s],		train_loss: 0.4166,	val_loss: 0.4281
# 13:	[0s / 8s],		train_loss: 0.4006,	val_loss: 0.4107
# 14:	[0s / 9s],		train_loss: 0.4002,	val_loss: 0.3964
# 15:	[0s / 9s],		train_loss: 0.3997,	val_loss: 0.4134
# 16:	[0s / 10s],		train_loss: 0.4007,	val_loss: 0.4102
# 17:	[0s / 10s],		train_loss: 0.3905,	val_loss: 0.4439
# 18:	[0s / 11s],		train_loss: 0.3910,	val_loss: 0.3975
# 19:	[0s / 11s],		train_loss: 0.3805,	val_loss: 0.4063
# 20:	[0s / 11s],		train_loss: 0.3876,	val_loss: 0.4108
# 21:	[0s / 12s],		train_loss: 0.3784,	val_loss: 0.3912
# 22:	[0s / 12s],		train_loss: 0.3752,	val_loss: 0.3923
# 23:	[0s / 13s],		train_loss: 0.3694,	val_loss: 0.4004
# 24:	[0s / 13s],		train_loss: 0.3666,	val_loss: 0.4309
# 25:	[0s / 14s],		train_loss: 0.3670,	val_loss: 0.3795
# 26:	[0s / 14s],		train_loss: 0.3689,	val_loss: 0.3971
# 27:	[0s / 14s],		train_loss: 0.3655,	val_loss: 0.3972
# 28:	[0s / 15s],		train_loss: 0.3545,	val_loss: 0.3966
# 29:	[0s / 15s],		train_loss: 0.3589,	val_loss: 0.4283
# 30:	[0s / 16s],		train_loss: 0.3538,	val_loss: 0.4309
# 31:	[0s / 16s],		train_loss: 0.3500,	val_loss: 0.4233
# 32:	[0s / 17s],		train_loss: 0.3457,	val_loss: 0.3943
# 33:	[0s / 17s],		train_loss: 0.3444,	val_loss: 0.4142
# 34:	[0s / 17s],		train_loss: 0.3433,	val_loss: 0.4431
# 35:	[0s / 18s],		train_loss: 0.3448,	val_loss: 0.3818
# 0.8960511140534942

# %%
nnet_m2 = nnet.Nnet(dataset='M2',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M2")
cis_m2 = nnet_m2.build_model()
print(cis_m2)
# Out:
# Index(['t.act.12m_0', 't.act.12m_1', 't.act.12m_2', 't.act.12m_3',
#        't.act.12m_4', 't.act.12m_5', 't.act.12m_6', 't.act.12m_7',
#        't.act.12m_8', 't.act.12m_9', 't.act.12m_10', 't.act.12m_11',
#        't.act.12m_12', 't.del.30d.12m_0', 't.del.30d.12m_1', 't.del.30d.12m_2',
#        't.del.30d.12m_3', 't.del.30d.12m_4', 't.del.30d.12m_5',
#        't.del.30d.12m_6', 't.del.30d.12m_7', 't.del.30d.12m_8',
#        't.del.30d.12m_9', 't.del.30d.12m_10', 't.del.30d.12m_11',
#        't.del.30d.12m_12', 't.del.60d.12m_0', 't.del.60d.12m_1',
#        't.del.60d.12m_2', 't.del.60d.12m_3', 't.del.60d.12m_4',
#        't.del.60d.12m_5', 't.del.60d.12m_6', 't.del.60d.12m_7',
#        't.del.60d.12m_8', 't.del.60d.12m_9', 't.del.60d.12m_10',
#        't.del.60d.12m_11', 't.del.60d.12m_12'],
#       dtype='object')
# None
# 0:	[0s / 0s],		train_loss: 4.3062,	val_loss: 3.6246
# 1:	[0s / 0s],		train_loss: 2.2822,	val_loss: 2.5844
# 2:	[0s / 0s],		train_loss: 1.1646,	val_loss: 0.9304
# 3:	[0s / 0s],		train_loss: 0.3929,	val_loss: 0.2988
# 4:	[0s / 0s],		train_loss: 0.1455,	val_loss: 0.1799
# 5:	[0s / 0s],		train_loss: 0.0789,	val_loss: 0.1569
# 6:	[0s / 1s],		train_loss: 0.1104,	val_loss: 0.1551
# 7:	[0s / 1s],		train_loss: 0.0599,	val_loss: 0.2379
# 8:	[0s / 1s],		train_loss: 0.0674,	val_loss: 0.1831
# 9:	[0s / 1s],		train_loss: 0.0614,	val_loss: 0.1534
# 10:	[0s / 1s],		train_loss: 0.0400,	val_loss: 0.1450
# 11:	[0s / 1s],		train_loss: 0.0445,	val_loss: 0.1428
# 12:	[0s / 1s],		train_loss: 0.0312,	val_loss: 0.1393
# 13:	[0s / 1s],		train_loss: 0.0376,	val_loss: 0.1369
# 14:	[0s / 1s],		train_loss: 0.0226,	val_loss: 0.1344
# 15:	[0s / 1s],		train_loss: 0.0172,	val_loss: 0.1363
# 16:	[0s / 1s],		train_loss: 0.0162,	val_loss: 0.1417
# 17:	[0s / 1s],		train_loss: 0.0123,	val_loss: 0.1485
# 18:	[0s / 1s],		train_loss: 0.0073,	val_loss: 0.1483
# 19:	[0s / 1s],		train_loss: 0.0141,	val_loss: 0.1365
# 20:	[0s / 1s],		train_loss: 0.0100,	val_loss: 0.1426
# 21:	[0s / 1s],		train_loss: 0.0101,	val_loss: 0.1560
# 22:	[0s / 1s],		train_loss: 0.0156,	val_loss: 0.1595
# 23:	[0s / 1s],		train_loss: 0.0082,	val_loss: 0.1521
# 24:	[0s / 1s],		train_loss: 0.0054,	val_loss: 0.1578
# 0.9457192711040316

# %%
nnet_ppdai = nnet.Nnet(dataset='ppdai',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\ppdai")
cis_ppdai = nnet_ppdai.build_model()
print(cis_ppdai)
# Out:
# Index(['IsFirstTime', 'PhoneVerified', 'RegistrationVerified', 'VideoVerified',
#        'DegreeVerified', 'CreditVerified', 'TaobaoVerified', 'Gender_0',
#        'Gender_1', 'BorrowerRating_A', 'BorrowerRating_B', 'BorrowerRating_C',
#        'BorrowerRating_D', 'BorrowerRating_E', 'BorrowerRating_F',
#        'LoanType_APPexpress', 'LoanType_E-commerce', 'LoanType_Normal',
#        'LoanType_Others', 'LoanPeriod_1', 'LoanPeriod_2', 'LoanPeriod_3',
#        'LoanPeriod_4', 'LoanPeriod_5', 'LoanPeriod_6', 'LoanPeriod_7',
#        'LoanPeriod_8', 'LoanPeriod_9', 'LoanPeriod_10', 'LoanPeriod_11',
#        'LoanPeriod_12', 'LoanPeriod_15', 'LoanPeriod_17', 'LoanPeriod_18',
#        'LoanPeriod_20', 'LoanPeriod_21', 'LoanPeriod_24'],
#       dtype='object')
# None
# 0:	[0s / 0s],		train_loss: 0.7732,	val_loss: 0.5633
# 1:	[0s / 1s],		train_loss: 0.5613,	val_loss: 0.5232
# 2:	[0s / 2s],		train_loss: 0.5395,	val_loss: 0.5381
# 3:	[0s / 3s],		train_loss: 0.5259,	val_loss: 0.4950
# 4:	[0s / 4s],		train_loss: 0.5164,	val_loss: 0.5059
# 5:	[0s / 5s],		train_loss: 0.5067,	val_loss: 0.5439
# 6:	[0s / 6s],		train_loss: 0.5018,	val_loss: 0.5005
# 7:	[0s / 6s],		train_loss: 0.4944,	val_loss: 0.4764
# 8:	[0s / 7s],		train_loss: 0.4916,	val_loss: 0.4678
# 9:	[0s / 8s],		train_loss: 0.4871,	val_loss: 0.4843
# 10:	[0s / 9s],		train_loss: 0.4828,	val_loss: 0.4779
# 11:	[0s / 10s],		train_loss: 0.4849,	val_loss: 0.4834
# 12:	[0s / 11s],		train_loss: 0.4756,	val_loss: 0.4740
# 13:	[0s / 12s],		train_loss: 0.4746,	val_loss: 0.4644
# 14:	[0s / 12s],		train_loss: 0.4723,	val_loss: 0.4764
# 15:	[0s / 13s],		train_loss: 0.4720,	val_loss: 0.4602
# 16:	[0s / 14s],		train_loss: 0.4658,	val_loss: 0.4747
# 17:	[0s / 15s],		train_loss: 0.4630,	val_loss: 0.4442
# 18:	[0s / 16s],		train_loss: 0.4588,	val_loss: 0.4669
# 19:	[0s / 17s],		train_loss: 0.4597,	val_loss: 0.4385
# 20:	[0s / 18s],		train_loss: 0.4564,	val_loss: 0.4529
# 21:	[0s / 19s],		train_loss: 0.4583,	val_loss: 0.4688
# 22:	[0s / 19s],		train_loss: 0.4552,	val_loss: 0.4525
# 23:	[0s / 20s],		train_loss: 0.4574,	val_loss: 0.4450
# 24:	[0s / 21s],		train_loss: 0.4518,	val_loss: 0.4762
# 25:	[0s / 22s],		train_loss: 0.4501,	val_loss: 0.4567
# 26:	[0s / 23s],		train_loss: 0.4473,	val_loss: 0.4529
# 27:	[0s / 24s],		train_loss: 0.4435,	val_loss: 0.4551
# 28:	[0s / 25s],		train_loss: 0.4448,	val_loss: 0.4663
# 29:	[0s / 26s],		train_loss: 0.4397,	val_loss: 0.4551
# 0.9484690852870291

# %%
nnet_lc = nnet.Nnet(dataset='LC',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\LendingClub\XYZCorp_LendingData.txt")
cis_lc = nnet_lc.build_model()
print(cis_lc)
# Out:
# Columns with less than 90% of the data included:
# ['all_util', 'annual_inc_joint', 'desc', 'dti_joint', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'mths_since_last_delinq', 'mths_since_last_major_derog', 'mths_since_last_record', 'mths_since_rcnt_il', 'next_pymnt_d', 'open_acc_6m', 'open_il_12m', 'open_il_24m', 'open_il_6m', 'open_rv_12m', 'open_rv_24m', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'purpose', 'title', 'zip_code', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'policy_code', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'default_ind'],
#       dtype='object')
# Index(['pymnt_plan', 'initial_list_status', 'application_type', 'grade_A',
#        'grade_B', 'grade_C', 'grade_D', 'grade_E', 'grade_F', 'grade_G',
#        'emp_length_1 year', 'emp_length_10+ years', 'emp_length_2 years',
#        'emp_length_3 years', 'emp_length_4 years', 'emp_length_5 years',
#        'emp_length_6 years', 'emp_length_7 years', 'emp_length_8 years',
#        'emp_length_9 years', 'emp_length_< 1 year', 'home_ownership_ANY',
#        'home_ownership_MORTGAGE', 'home_ownership_NONE',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'sub_grade_A1', 'sub_grade_A2', 'sub_grade_A3', 'sub_grade_A4',
#        'sub_grade_A5', 'sub_grade_B1', 'sub_grade_B2', 'sub_grade_B3',
#        'sub_grade_B4', 'sub_grade_B5', 'sub_grade_C1', 'sub_grade_C2',
#        'sub_grade_C3', 'sub_grade_C4', 'sub_grade_C5', 'sub_grade_D1',
#        'sub_grade_D2', 'sub_grade_D3', 'sub_grade_D4', 'sub_grade_D5',
#        'sub_grade_E1', 'sub_grade_E2', 'sub_grade_E3', 'sub_grade_E4',
#        'sub_grade_E5', 'sub_grade_F1', 'sub_grade_F2', 'sub_grade_F3',
#        'sub_grade_F4', 'sub_grade_F5', 'sub_grade_G1', 'sub_grade_G2',
#        'sub_grade_G3', 'sub_grade_G4', 'sub_grade_G5', 'purpose_car',
#        'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement', 'purpose_house',
#        'purpose_major_purchase', 'purpose_medical', 'purpose_moving',
#        'purpose_other', 'purpose_renewable_energy', 'purpose_small_business',
#        'purpose_vacation', 'purpose_wedding',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified',
#        'term_ 36 months', 'term_ 60 months'],
#       dtype='object')
# None
# 0:	[5s / 5s],		train_loss: 0.0354,	val_loss: 0.0169
# 1:	[4s / 9s],		train_loss: 0.0185,	val_loss: 0.0188
# 2:	[4s / 13s],		train_loss: 0.0167,	val_loss: 0.0142
# 3:	[4s / 17s],		train_loss: 0.0160,	val_loss: 0.0146
# 4:	[4s / 22s],		train_loss: 0.0153,	val_loss: 0.0154
# 5:	[4s / 26s],		train_loss: 0.0146,	val_loss: 0.0120
# 6:	[4s / 30s],		train_loss: 0.0142,	val_loss: 0.0125
# 7:	[4s / 34s],		train_loss: 0.0136,	val_loss: 0.0135
# 8:	[4s / 39s],		train_loss: 0.0135,	val_loss: 0.0114
# 9:	[4s / 43s],		train_loss: 0.0134,	val_loss: 0.0122
# 10:	[4s / 47s],		train_loss: 0.0129,	val_loss: 0.0142
# 11:	[4s / 51s],		train_loss: 0.0128,	val_loss: 0.0115
# 12:	[4s / 56s],		train_loss: 0.0125,	val_loss: 0.0114
# 13:	[4s / 1m:0s],		train_loss: 0.0124,	val_loss: 0.0112
# 14:	[4s / 1m:4s],		train_loss: 0.0120,	val_loss: 0.0110
# 15:	[4s / 1m:8s],		train_loss: 0.0120,	val_loss: 0.0117
# 16:	[4s / 1m:12s],		train_loss: 0.0121,	val_loss: 0.0109
# 17:	[4s / 1m:16s],		train_loss: 0.0117,	val_loss: 0.0119
# 18:	[4s / 1m:21s],		train_loss: 0.0116,	val_loss: 0.0122
# 19:	[4s / 1m:25s],		train_loss: 0.0114,	val_loss: 0.0106
# 20:	[4s / 1m:29s],		train_loss: 0.0115,	val_loss: 0.0108
# 21:	[4s / 1m:33s],		train_loss: 0.0112,	val_loss: 0.0116
# 22:	[4s / 1m:37s],		train_loss: 0.0112,	val_loss: 0.0106
# 23:	[4s / 1m:41s],		train_loss: 0.0110,	val_loss: 0.0108
# 24:	[4s / 1m:46s],		train_loss: 0.0109,	val_loss: 0.0111
# 25:	[4s / 1m:50s],		train_loss: 0.0109,	val_loss: 0.0109
# 26:	[4s / 1m:54s],		train_loss: 0.0108,	val_loss: 0.0101
# 27:	[4s / 1m:58s],		train_loss: 0.0109,	val_loss: 0.0112
# 28:	[4s / 2m:2s],		train_loss: 0.0110,	val_loss: 0.0117
# 29:	[4s / 2m:6s],		train_loss: 0.0108,	val_loss: 0.0106
# 30:	[4s / 2m:11s],		train_loss: 0.0107,	val_loss: 0.0108
# 31:	[4s / 2m:15s],		train_loss: 0.0105,	val_loss: 0.0109
# 32:	[4s / 2m:19s],		train_loss: 0.0105,	val_loss: 0.0115
# 33:	[4s / 2m:23s],		train_loss: 0.0103,	val_loss: 0.0100
# 34:	[4s / 2m:27s],		train_loss: 0.0105,	val_loss: 0.0106
# 35:	[4s / 2m:32s],		train_loss: 0.0103,	val_loss: 0.0111
# 36:	[4s / 2m:36s],		train_loss: 0.0103,	val_loss: 0.0113
# 37:	[4s / 2m:40s],		train_loss: 0.0101,	val_loss: 0.0099
# 38:	[4s / 2m:44s],		train_loss: 0.0102,	val_loss: 0.0106
# 39:	[4s / 2m:48s],		train_loss: 0.0101,	val_loss: 0.0100
# 40:	[4s / 2m:52s],		train_loss: 0.0104,	val_loss: 0.0110
# 41:	[4s / 2m:57s],		train_loss: 0.0102,	val_loss: 0.0110
# 42:	[4s / 3m:1s],		train_loss: 0.0101,	val_loss: 0.0122
# 43:	[4s / 3m:5s],		train_loss: 0.0101,	val_loss: 0.0104
# 44:	[4s / 3m:9s],		train_loss: 0.0100,	val_loss: 0.0102
# 45:	[4s / 3m:13s],		train_loss: 0.0099,	val_loss: 0.0112
# 46:	[4s / 3m:17s],		train_loss: 0.0100,	val_loss: 0.0102
# 47:	[4s / 3m:22s],		train_loss: 0.0099,	val_loss: 0.0105
# 0.9858772152928937
