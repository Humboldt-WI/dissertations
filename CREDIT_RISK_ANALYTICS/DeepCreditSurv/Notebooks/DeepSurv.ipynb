# %%
import os
import pandas as pd
path = "D:\DeepCreditSurv"
os.chdir(path)

# %%
from DeepCreditSurv.models import DeepSurv

# %%
ds_m1 = DeepSurv.DeepSurv(dataset='M1',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M1\WideFormatMortgageAfterRemovingNull.csv")
best_lr = ds_m1.find_lr()
print(best_lr)
# Out:
# 0.020092330025650584

# %%
cis_m1 = ds_m1.build_model(lr=0.01)
print(cis_m1)
# Out:
# 0:	[0s / 0s],		train_loss: 3.6005,	val_loss: 3.2459
# 1:	[0s / 0s],		train_loss: 3.3166,	val_loss: 3.2437
# 2:	[0s / 1s],		train_loss: 3.1971,	val_loss: 3.0750
# 3:	[0s / 1s],		train_loss: 3.1524,	val_loss: 3.0771
# 4:	[0s / 2s],		train_loss: 3.1309,	val_loss: 3.0342
# 5:	[0s / 2s],		train_loss: 3.1243,	val_loss: 2.9959
# 6:	[0s / 3s],		train_loss: 3.0869,	val_loss: 2.9636
# 7:	[0s / 3s],		train_loss: 3.0713,	val_loss: 3.0615
# 8:	[0s / 4s],		train_loss: 3.0555,	val_loss: 2.9348
# 9:	[0s / 4s],		train_loss: 3.0235,	val_loss: 2.9032
# 10:	[0s / 5s],		train_loss: 3.0018,	val_loss: 2.9041
# 11:	[0s / 5s],		train_loss: 2.9958,	val_loss: 2.9104
# 12:	[0s / 6s],		train_loss: 2.9653,	val_loss: 2.8781
# 13:	[0s / 6s],		train_loss: 2.9793,	val_loss: 2.9116
# 14:	[0s / 7s],		train_loss: 2.9540,	val_loss: 2.8509
# 15:	[0s / 7s],		train_loss: 2.9303,	val_loss: 2.8354
# 16:	[0s / 8s],		train_loss: 2.9751,	val_loss: 2.8839
# 17:	[0s / 8s],		train_loss: 2.9460,	val_loss: 2.8222
# ...

# %%
ds_m2 = DeepSurv.DeepSurv(dataset='M2',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\M2")
best_lr = ds_m2.find_lr()
print(best_lr)
# Out:
# Index(['t.act.12m_0', 't.act.12m_1', 't.act.12m_2', 't.act.12m_3',
#        't.act.12m_4', 't.act.12m_5', 't.act.12m_6', 't.act.12m_7',
#        't.act.12m_8', 't.act.12m_9', 't.act.12m_10', 't.act.12m_11',
#        't.act.12m_12', 't.del.30d.12m_0', 't.del.30d.12m_1', 't.del.30d.12m_2',
#        't.del.30d.12m_3', 't.del.30d.12m_4', 't.del.30d.12m_5',
#        't.del.30d.12m_6', 't.del.30d.12m_7', 't.del.30d.12m_8',
#        't.del.30d.12m_9', 't.del.30d.12m_10', 't.del.30d.12m_11',
#        't.del.30d.12m_12', 't.del.60d.12m_0', 't.del.60d.12m_1',
#        't.del.60d.12m_2', 't.del.60d.12m_3', 't.del.60d.12m_4',
#        't.del.60d.12m_5', 't.del.60d.12m_6', 't.del.60d.12m_7',
#        't.del.60d.12m_8', 't.del.60d.12m_9', 't.del.60d.12m_10',
#        't.del.60d.12m_11', 't.del.60d.12m_12'],
#       dtype='object')
# 0.04229242874389523

# %%
cis_m2 = ds_m2.build_model(lr=0.01)
print(cis_m2)
# Out:
# 0:	[0s / 0s],		train_loss: 3.0554,	val_loss: 4.0286
# 1:	[0s / 0s],		train_loss: 3.0166,	val_loss: 2.0463
# 2:	[0s / 0s],		train_loss: 1.5307,	val_loss: 2.3197
# 3:	[0s / 0s],		train_loss: 1.8473,	val_loss: 2.2393
# 4:	[0s / 0s],		train_loss: 1.5347,	val_loss: 1.5459
# 5:	[0s / 0s],		train_loss: 1.1972,	val_loss: 1.8739
# 6:	[0s / 0s],		train_loss: 0.7524,	val_loss: 2.1260
# 7:	[0s / 0s],		train_loss: 1.5828,	val_loss: 1.7765
# 8:	[0s / 0s],		train_loss: 1.3184,	val_loss: 1.6154
# 9:	[0s / 0s],		train_loss: 0.9792,	val_loss: 1.7383
# 10:	[0s / 0s],		train_loss: 1.0818,	val_loss: 1.6179
# 11:	[0s / 0s],		train_loss: 0.6679,	val_loss: 1.6332
# 12:	[0s / 0s],		train_loss: 0.7778,	val_loss: 1.9297
# 13:	[0s / 0s],		train_loss: 0.8647,	val_loss: 1.5433
# 14:	[0s / 0s],		train_loss: 0.9250,	val_loss: 1.1501
# 15:	[0s / 0s],		train_loss: 0.6383,	val_loss: 1.0968
# 16:	[0s / 0s],		train_loss: 0.9329,	val_loss: 1.1370
# 17:	[0s / 0s],		train_loss: 0.8172,	val_loss: 1.2829
# ...

# %%
ds_ppdai = DeepSurv.DeepSurv(dataset='ppdai',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\ppdai")
best_lr = ds_ppdai.find_lr()
print(best_lr)
# Out:
# Index(['IsFirstTime', 'PhoneVerified', 'RegistrationVerified', 'VideoVerified',
#        'DegreeVerified', 'CreditVerified', 'TaobaoVerified', 'Gender_0',
#        'Gender_1', 'BorrowerRating_A', 'BorrowerRating_B', 'BorrowerRating_C',
#        'BorrowerRating_D', 'BorrowerRating_E', 'BorrowerRating_F',
#        'LoanType_APPexpress', 'LoanType_E-commerce', 'LoanType_Normal',
#        'LoanType_Others', 'LoanPeriod_1', 'LoanPeriod_2', 'LoanPeriod_3',
#        'LoanPeriod_4', 'LoanPeriod_5', 'LoanPeriod_6', 'LoanPeriod_7',
#        'LoanPeriod_8', 'LoanPeriod_9', 'LoanPeriod_10', 'LoanPeriod_11',
#        'LoanPeriod_12', 'LoanPeriod_15', 'LoanPeriod_17', 'LoanPeriod_18',
#        'LoanPeriod_20', 'LoanPeriod_21', 'LoanPeriod_24'],
#       dtype='object')
# 0.006579332246575716

# %%
cis_ppdai = ds_ppdai.build_model(lr=0.01)
print(cis_ppdai)
# Out:
# 0:	[1s / 1s],		train_loss: 3.7932,	val_loss: 3.4068
# 1:	[0s / 2s],		train_loss: 3.4033,	val_loss: 3.2046
# 2:	[0s / 2s],		train_loss: 3.2614,	val_loss: 3.1118
# 3:	[0s / 3s],		train_loss: 3.1977,	val_loss: 3.0626
# 4:	[0s / 4s],		train_loss: 3.1459,	val_loss: 3.0647
# 5:	[0s / 5s],		train_loss: 3.0986,	val_loss: 2.9531
# 6:	[1s / 6s],		train_loss: 3.0750,	val_loss: 3.0213
# 7:	[1s / 7s],		train_loss: 3.0255,	val_loss: 2.9212
# 8:	[0s / 8s],		train_loss: 3.0415,	val_loss: 2.9092
# 9:	[0s / 9s],		train_loss: 3.0061,	val_loss: 2.9388
# 10:	[0s / 10s],		train_loss: 2.9866,	val_loss: 2.8403
# 11:	[0s / 11s],		train_loss: 2.9454,	val_loss: 2.7630
# 12:	[0s / 12s],		train_loss: 3.0010,	val_loss: 2.8245
# 13:	[0s / 13s],		train_loss: 2.9475,	val_loss: 2.9387
# 14:	[0s / 14s],		train_loss: 2.9368,	val_loss: 2.7915
# 15:	[0s / 15s],		train_loss: 2.9487,	val_loss: 2.7678
# 16:	[0s / 16s],		train_loss: 2.8927,	val_loss: 2.7643
# 17:	[0s / 17s],		train_loss: 2.8914,	val_loss: 2.7489
# ...

# %%
ds_lc = DeepSurv.DeepSurv(dataset='LC',file_path="D:\DeepCreditSurv\DeepCreditSurv\datasets\LendingClub\XYZCorp_LendingData.txt")
best_lr = ds_lc.find_lr()
print(best_lr)
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
# ...

# %%
cis_lc= ds_lc.build_model(lr=0.01)
print(cis_lc)
# Out:
# 0:	[1s / 1s],		train_loss: 2.0939,	val_loss: 1.5039
# 1:	[1s / 2s],		train_loss: 1.7118,	val_loss: 1.4672
# 2:	[1s / 4s],		train_loss: 1.5840,	val_loss: 1.3961
# 3:	[1s / 5s],		train_loss: 1.5070,	val_loss: 1.3427
# 4:	[1s / 7s],		train_loss: 1.5125,	val_loss: 1.3105
# 5:	[1s / 8s],		train_loss: 1.4658,	val_loss: 1.3664
# 6:	[1s / 10s],		train_loss: 1.4403,	val_loss: 1.3299
# 7:	[1s / 11s],		train_loss: 1.4044,	val_loss: 1.3209
# 8:	[1s / 13s],		train_loss: 1.4340,	val_loss: 1.2789
# 9:	[1s / 14s],		train_loss: 1.4473,	val_loss: 1.3657
# 10:	[1s / 15s],		train_loss: 1.4077,	val_loss: 1.3123
# 11:	[1s / 17s],		train_loss: 1.3884,	val_loss: 1.2929
# 12:	[1s / 18s],		train_loss: 1.3624,	val_loss: 1.2305
# 13:	[1s / 20s],		train_loss: 1.3592,	val_loss: 1.2474
# 14:	[1s / 21s],		train_loss: 1.3645,	val_loss: 1.2790
# 15:	[1s / 23s],		train_loss: 1.3975,	val_loss: 1.3842
# 16:	[1s / 24s],		train_loss: 1.3379,	val_loss: 1.2225
# 17:	[1s / 26s],		train_loss: 1.3369,	val_loss: 1.3106
# ...
