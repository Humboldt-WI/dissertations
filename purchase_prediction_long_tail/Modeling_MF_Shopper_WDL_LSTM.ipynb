# %% [markdown]
# ### Import

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import pickle

import keras
from keras.preprocessing.sequence import pad_sequences
from keras import metrics
from keras.models import Sequential, Model, load_model
from keras.constraints import maxnorm, nonneg
from keras.optimizers import Adam
from keras import regularizers
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Input, Embedding, Dot, Reshape, Dense, multiply, average, add, Flatten, Dropout, concatenate, Lambda
from keras.layers import LSTM, Bidirectional

import gensim
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import sklearn
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, classification_report, auc, roc_curve
from sklearn import preprocessing 
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from scipy import stats

import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime
from tqdm import tqdm_notebook as tqdm
from pylab import rcParams
import seaborn as sns

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
pip install keras-hypetune

# %%
pip install keras_self_attention

# %%
import kerashypetune
from kerashypetune import KerasGridSearch, KerasRandomSearch

# %%
import keras_self_attention
from keras_self_attention import SeqSelfAttention, SeqWeightedAttention

# %%
small_data = drive.CreateFile({'id': 'here provide the file id from link sharing in from google drive'})
small_data.GetContentFile('data_preprocessed.pkl')

file = open('data_preprocessed.pkl','rb')
df = pickle.load(file)
print(df.shape)
# Out:
# (1219746, 24)

# %%
df_train = df[df['data_split'] == 'train']
df_test = df[df['data_split'] == 'test']

# %% [markdown]
# ## Pre-trained embeddings

# %% [markdown]
# ### word2vec

# %%
word2vec_vecs = drive.CreateFile({'id': 'here provide the file id from link sharing in from google drive'})
word2vec_vecs.GetContentFile('word_vectors_saved.pkl')

file = open('word_vectors_saved.pkl','rb')
word_vectors_large = pickle.load(file)

# %%
# get product attributes data
products = drive.CreateFile({'id': 'here provide the file id from link sharing in from google drive'})
products.GetContentFile('product_attributes_data.tsv.gz')
products = pd.read_table('product_attributes_data.tsv.gz')
products = products[['article_text', 'rpid']].drop_duplicates()
df = pd.merge(df, products, how='left', on=['article_text'])

# %%
word_vectors = word_vectors_large
word2vec_vocabs = list(word_vectors_large.vocab)
df['product_id'] = df['product_id'].astype('str')
keys = df['product_id_notenc'].unique().tolist()
values = df['product_id'].astype('int').unique().tolist()
word_dictionary = dict(zip(keys, values))

emb=100
pretrained_weights_products = np.zeros((max(df['product_id'].astype('int')) + 1, emb))
for word, i in word_dictionary.items():
  if word in word2vec_vocabs:
    embedding_vector = word_vectors[word]
    pretrained_weights_products[i] = embedding_vector

# %% [markdown]
# ### user2vec

# %%
df_train['product_id'] = df_train['product_id'].astype('str')
df_train['user_id'] = df_train['user_id'].astype('str')
only_bought = df_train[df_train['bought'] == 1]

train_products = only_bought[['user_id', 'product_id']]
train_products['new_col'] = train_products.groupby("user_id").transform(lambda x: ','.join(x))
del train_products['product_id']
train_products= train_products.drop_duplicates()

def tagged_document(df):
    #tagging documents
    for index, row in train_products.iterrows():
        yield gensim.models.doc2vec.TaggedDocument(row['new_col'].split(), [row['user_id']])


data_for_training = list(tagged_document(train_products[['user_id', 'new_col']]))

my_model = Doc2Vec(vector_size=100, min_count=1, epochs=100, dm=0, window=35)
my_model.build_vocab(data_for_training)
my_model.train(data_for_training, total_examples=my_model.corpus_count, epochs=100)
pretrained_user_weights = my_model.wv.syn0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).

# %%
word_vectors = my_model.docvecs
word2vec_vocabs = list(my_model.docvecs.index2entity)

df['user_id'] = df['user_id'].astype('str')
keys = df['user_id'].unique().tolist()
values = df['user_id'].astype('int').unique().tolist()
word_dictionary = dict(zip(keys, values))

emb=100
pretrained_user_weights = np.zeros((max(df['user_id'].astype('int')) + 1, emb))
for word, i in word_dictionary.items():
  if word in word2vec_vocabs:
    embedding_vector = word_vectors[word]
    pretrained_user_weights[i] = embedding_vector

df_train['product_id'] = df_train['product_id'].astype('int')
df_train['user_id'] = df_train['user_id'].astype('int')

# %% [markdown]
# ## Common feature preparation for modeling

# %%
df_train['week'] = df_train['week'].astype('int')
df_train['product_id'] = df_train['product_id'].astype('int')
df_train['user_id'] = df_train['user_id'].astype('int')

df_test['week'] = df_test['week'].astype('int')
df_test['product_id'] = df_test['product_id'].astype('int')
df_test['user_id'] = df_test['user_id'].astype('int')

# %%
# defining the inputs shapes
embedding_size = 100
user_len = max(df['user_id'].astype('int')) + 1
item_len = max(df['product_id'].astype('int')) + 1
day_len = max(df['week'].astype('int')) + 1
sub_len = max(df['subcategory_name']) + 1

# %% [markdown]
# ## Matrix Factorization

# %%
n_products = df['product_id'].nunique()
n_users = df['user_id'].nunique()

# %%
bias = 1

product_input = Input(shape=[1],name='product_input')
product_embedding = Embedding(n_products, embedding_size, name="product_embedding", 
                              embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products), trainable=True
)(product_input)
product_bias = Embedding(n_products, bias, name="product_bias")(product_input)

user_input = Input(shape=[1],name='User')
user_embedding = Embedding(n_users, embedding_size, name="User-Embedding",                               
                           embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights), trainable=True
)(user_input)
user_bias = Embedding(n_users, bias, name="user_bias")(user_input)

matrix_product = multiply([product_embedding, user_embedding])

input_terms = concatenate([matrix_product, user_bias, product_bias])
input_terms = Flatten()(input_terms)

result = Dense(1, activation='sigmoid')(input_terms)

model_mf = Model(inputs=[product_input, user_input], outputs=result)

# %%
model_mf.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# product_input (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# User (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# product_embedding (Embedding)   (None, 1, 100)       1190400     product_input[0][0]
# __________________________________________________________________________________________________
# User-Embedding (Embedding)      (None, 1, 100)       100000      User[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1, 100)       0           product_embedding[0][0]
#                                                                  User-Embedding[0][0]
# __________________________________________________________________________________________________
# user_bias (Embedding)           (None, 1, 1)         1000        User[0][0]
# __________________________________________________________________________________________________
# product_bias (Embedding)        (None, 1, 1)         11904       product_input[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 1, 102)       0           multiply[0][0]
#                                                                  user_bias[0][0]
#                                                                  product_bias[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 102)          0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            103         flatten[0][0]
# ==================================================================================================
# Total params: 1,303,407
# Trainable params: 1,303,407
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
early = EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)
## compile model
model_mf.compile(optimizer = Adam(lr = 0.0001), loss = ['binary_crossentropy'], metrics = [keras.metrics.Precision(), keras.metrics.Recall(), keras.metrics.AUC(), keras.metrics.BinaryAccuracy()])

## fit model
history_mf = model_mf.fit([df_train['product_id'], df_train['user_id']],
                          df_train['bought'],
                          batch_size = 512,
                          validation_data = ([df_test['product_id'], df_test['user_id']],
                          df_test['bought']),
                          epochs = 200,
                          callbacks=[early])
# Out:
# Epoch 1/200
# 2352/2352 [==============================] - 20s 8ms/step - loss: 0.6809 - precision: 0.6000 - recall: 0.6836 - auc: 0.6604 - binary_accuracy: 0.6148 - val_loss: 0.6449 - val_precision: 0.6566 - val_recall: 0.6740 - val_auc: 0.7191 - val_binary_accuracy: 0.6608
# Epoch 2/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.6089 - precision: 0.6886 - recall: 0.7373 - auc: 0.7721 - binary_accuracy: 0.7017 - val_loss: 0.6067 - val_precision: 0.6796 - val_recall: 0.6663 - val_auc: 0.7430 - val_binary_accuracy: 0.6761
# Epoch 3/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.5591 - precision: 0.7208 - recall: 0.7394 - auc: 0.8033 - binary_accuracy: 0.7262 - val_loss: 0.5848 - val_precision: 0.6944 - val_recall: 0.6778 - val_auc: 0.7605 - val_binary_accuracy: 0.6898
# Epoch 4/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.5274 - precision: 0.7420 - recall: 0.7487 - auc: 0.8243 - binary_accuracy: 0.7442 - val_loss: 0.5708 - val_precision: 0.7054 - val_recall: 0.6909 - val_auc: 0.7728 - val_binary_accuracy: 0.7012
# Epoch 5/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.5043 - precision: 0.7568 - recall: 0.7600 - auc: 0.8398 - binary_accuracy: 0.7580 - val_loss: 0.5614 - val_precision: 0.7133 - val_recall: 0.7014 - val_auc: 0.7818 - val_binary_accuracy: 0.7097
# Epoch 6/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.4863 - precision: 0.7684 - recall: 0.7712 - auc: 0.8516 - binary_accuracy: 0.7695 - val_loss: 0.5549 - val_precision: 0.7183 - val_recall: 0.7090 - val_auc: 0.7885 - val_binary_accuracy: 0.7155
# Epoch 7/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4717 - precision: 0.7769 - recall: 0.7798 - auc: 0.8607 - binary_accuracy: 0.7777 - val_loss: 0.5503 - val_precision: 0.7236 - val_recall: 0.7148 - val_auc: 0.7936 - val_binary_accuracy: 0.7209
# Epoch 8/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4599 - precision: 0.7838 - recall: 0.7874 - auc: 0.8679 - binary_accuracy: 0.7852 - val_loss: 0.5471 - val_precision: 0.7250 - val_recall: 0.7167 - val_auc: 0.7977 - val_binary_accuracy: 0.7224
# Epoch 9/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4503 - precision: 0.7893 - recall: 0.7944 - auc: 0.8735 - binary_accuracy: 0.7910 - val_loss: 0.5450 - val_precision: 0.7271 - val_recall: 0.7181 - val_auc: 0.8008 - val_binary_accuracy: 0.7243
# Epoch 10/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4409 - precision: 0.7945 - recall: 0.7998 - auc: 0.8790 - binary_accuracy: 0.7964 - val_loss: 0.5439 - val_precision: 0.7275 - val_recall: 0.7228 - val_auc: 0.8032 - val_binary_accuracy: 0.7260
# Epoch 11/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4342 - precision: 0.7978 - recall: 0.8039 - auc: 0.8827 - binary_accuracy: 0.8003 - val_loss: 0.5434 - val_precision: 0.7288 - val_recall: 0.7285 - val_auc: 0.8051 - val_binary_accuracy: 0.7287
# Epoch 12/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4262 - precision: 0.8026 - recall: 0.8105 - auc: 0.8873 - binary_accuracy: 0.8056 - val_loss: 0.5434 - val_precision: 0.7301 - val_recall: 0.7310 - val_auc: 0.8066 - val_binary_accuracy: 0.7303
# Epoch 13/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.4207 - precision: 0.8054 - recall: 0.8133 - auc: 0.8901 - binary_accuracy: 0.8084 - val_loss: 0.5439 - val_precision: 0.7315 - val_recall: 0.7329 - val_auc: 0.8079 - val_binary_accuracy: 0.7319
# Epoch 14/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.4153 - precision: 0.8084 - recall: 0.8177 - auc: 0.8930 - binary_accuracy: 0.8116 - val_loss: 0.5448 - val_precision: 0.7320 - val_recall: 0.7359 - val_auc: 0.8088 - val_binary_accuracy: 0.7332
# Epoch 15/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.4110 - precision: 0.8100 - recall: 0.8194 - auc: 0.8952 - binary_accuracy: 0.8136 - val_loss: 0.5460 - val_precision: 0.7319 - val_recall: 0.7380 - val_auc: 0.8096 - val_binary_accuracy: 0.7339
# Epoch 16/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.4062 - precision: 0.8127 - recall: 0.8229 - auc: 0.8977 - binary_accuracy: 0.8166 - val_loss: 0.5473 - val_precision: 0.7331 - val_recall: 0.7398 - val_auc: 0.8102 - val_binary_accuracy: 0.7352
# Epoch 17/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.4016 - precision: 0.8151 - recall: 0.8265 - auc: 0.9001 - binary_accuracy: 0.8193 - val_loss: 0.5489 - val_precision: 0.7335 - val_recall: 0.7417 - val_auc: 0.8107 - val_binary_accuracy: 0.7361
# Epoch 18/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3977 - precision: 0.8174 - recall: 0.8283 - auc: 0.9022 - binary_accuracy: 0.8217 - val_loss: 0.5503 - val_precision: 0.7339 - val_recall: 0.7418 - val_auc: 0.8112 - val_binary_accuracy: 0.7365
# Epoch 19/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3940 - precision: 0.8195 - recall: 0.8306 - auc: 0.9042 - binary_accuracy: 0.8240 - val_loss: 0.5520 - val_precision: 0.7323 - val_recall: 0.7419 - val_auc: 0.8115 - val_binary_accuracy: 0.7354
# Epoch 20/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3901 - precision: 0.8214 - recall: 0.8332 - auc: 0.9061 - binary_accuracy: 0.8260 - val_loss: 0.5539 - val_precision: 0.7336 - val_recall: 0.7458 - val_auc: 0.8117 - val_binary_accuracy: 0.7375
# Epoch 21/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3864 - precision: 0.8233 - recall: 0.8359 - auc: 0.9079 - binary_accuracy: 0.8282 - val_loss: 0.5555 - val_precision: 0.7344 - val_recall: 0.7476 - val_auc: 0.8121 - val_binary_accuracy: 0.7386
# Epoch 22/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3843 - precision: 0.8251 - recall: 0.8369 - auc: 0.9089 - binary_accuracy: 0.8297 - val_loss: 0.5573 - val_precision: 0.7345 - val_recall: 0.7471 - val_auc: 0.8123 - val_binary_accuracy: 0.7385
# Epoch 23/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3793 - precision: 0.8274 - recall: 0.8393 - auc: 0.9114 - binary_accuracy: 0.8320 - val_loss: 0.5596 - val_precision: 0.7339 - val_recall: 0.7480 - val_auc: 0.8124 - val_binary_accuracy: 0.7384
# Epoch 24/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3774 - precision: 0.8285 - recall: 0.8413 - auc: 0.9124 - binary_accuracy: 0.8334 - val_loss: 0.5616 - val_precision: 0.7343 - val_recall: 0.7491 - val_auc: 0.8126 - val_binary_accuracy: 0.7390
# Epoch 25/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3742 - precision: 0.8295 - recall: 0.8433 - auc: 0.9139 - binary_accuracy: 0.8351 - val_loss: 0.5638 - val_precision: 0.7343 - val_recall: 0.7500 - val_auc: 0.8126 - val_binary_accuracy: 0.7393
# Epoch 26/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.3722 - precision: 0.8310 - recall: 0.8443 - auc: 0.9148 - binary_accuracy: 0.8360 - val_loss: 0.5661 - val_precision: 0.7341 - val_recall: 0.7508 - val_auc: 0.8127 - val_binary_accuracy: 0.7394
# Epoch 27/200
# 2352/2352 [==============================] - 19s 8ms/step - loss: 0.3680 - precision: 0.8334 - recall: 0.8468 - auc: 0.9169 - binary_accuracy: 0.8386 - val_loss: 0.5684 - val_precision: 0.7343 - val_recall: 0.7496 - val_auc: 0.8127 - val_binary_accuracy: 0.7392
# Epoch 28/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3657 - precision: 0.8347 - recall: 0.8479 - auc: 0.9180 - binary_accuracy: 0.8399 - val_loss: 0.5706 - val_precision: 0.7333 - val_recall: 0.7503 - val_auc: 0.8127 - val_binary_accuracy: 0.7387
# Epoch 29/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3631 - precision: 0.8356 - recall: 0.8493 - auc: 0.9191 - binary_accuracy: 0.8411 - val_loss: 0.5727 - val_precision: 0.7342 - val_recall: 0.7503 - val_auc: 0.8128 - val_binary_accuracy: 0.7394
# Epoch 30/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3606 - precision: 0.8371 - recall: 0.8513 - auc: 0.9203 - binary_accuracy: 0.8428 - val_loss: 0.5751 - val_precision: 0.7331 - val_recall: 0.7516 - val_auc: 0.8129 - val_binary_accuracy: 0.7390
# Epoch 31/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3585 - precision: 0.8387 - recall: 0.8516 - auc: 0.9213 - binary_accuracy: 0.8439 - val_loss: 0.5776 - val_precision: 0.7335 - val_recall: 0.7526 - val_auc: 0.8129 - val_binary_accuracy: 0.7396
# Epoch 32/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3544 - precision: 0.8403 - recall: 0.8547 - auc: 0.9232 - binary_accuracy: 0.8461 - val_loss: 0.5797 - val_precision: 0.7331 - val_recall: 0.7537 - val_auc: 0.8131 - val_binary_accuracy: 0.7396
# Epoch 33/200
# 2352/2352 [==============================] - 18s 7ms/step - loss: 0.3535 - precision: 0.8405 - recall: 0.8551 - auc: 0.9235 - binary_accuracy: 0.8463 - val_loss: 0.5823 - val_precision: 0.7333 - val_recall: 0.7547 - val_auc: 0.8129 - val_binary_accuracy: 0.7401
# Epoch 34/200
# 2352/2352 [==============================] - 18s 7ms/step - loss: 0.3501 - precision: 0.8425 - recall: 0.8568 - auc: 0.9251 - binary_accuracy: 0.8482 - val_loss: 0.5846 - val_precision: 0.7336 - val_recall: 0.7560 - val_auc: 0.8130 - val_binary_accuracy: 0.7407
# Epoch 35/200
# 2352/2352 [==============================] - 18s 7ms/step - loss: 0.3484 - precision: 0.8436 - recall: 0.8580 - auc: 0.9258 - binary_accuracy: 0.8494 - val_loss: 0.5872 - val_precision: 0.7342 - val_recall: 0.7558 - val_auc: 0.8129 - val_binary_accuracy: 0.7411
# Epoch 36/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3461 - precision: 0.8452 - recall: 0.8591 - auc: 0.9268 - binary_accuracy: 0.8505 - val_loss: 0.5898 - val_precision: 0.7346 - val_recall: 0.7563 - val_auc: 0.8129 - val_binary_accuracy: 0.7416
# Epoch 37/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3443 - precision: 0.8460 - recall: 0.8600 - auc: 0.9276 - binary_accuracy: 0.8516 - val_loss: 0.5923 - val_precision: 0.7360 - val_recall: 0.7586 - val_auc: 0.8129 - val_binary_accuracy: 0.7433
# Epoch 38/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3400 - precision: 0.8478 - recall: 0.8622 - auc: 0.9295 - binary_accuracy: 0.8535 - val_loss: 0.5943 - val_precision: 0.7359 - val_recall: 0.7587 - val_auc: 0.8131 - val_binary_accuracy: 0.7432
# Epoch 39/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3389 - precision: 0.8480 - recall: 0.8625 - auc: 0.9299 - binary_accuracy: 0.8539 - val_loss: 0.5972 - val_precision: 0.7357 - val_recall: 0.7586 - val_auc: 0.8130 - val_binary_accuracy: 0.7430
# Epoch 40/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3362 - precision: 0.8498 - recall: 0.8640 - auc: 0.9311 - binary_accuracy: 0.8555 - val_loss: 0.5997 - val_precision: 0.7368 - val_recall: 0.7593 - val_auc: 0.8130 - val_binary_accuracy: 0.7440
# Epoch 41/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3343 - precision: 0.8501 - recall: 0.8650 - auc: 0.9319 - binary_accuracy: 0.8567 - val_loss: 0.6026 - val_precision: 0.7359 - val_recall: 0.7602 - val_auc: 0.8128 - val_binary_accuracy: 0.7437
# Epoch 42/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3321 - precision: 0.8515 - recall: 0.8659 - auc: 0.9329 - binary_accuracy: 0.8576 - val_loss: 0.6052 - val_precision: 0.7371 - val_recall: 0.7603 - val_auc: 0.8128 - val_binary_accuracy: 0.7446
# Epoch 43/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3303 - precision: 0.8523 - recall: 0.8674 - auc: 0.9336 - binary_accuracy: 0.8585 - val_loss: 0.6076 - val_precision: 0.7380 - val_recall: 0.7591 - val_auc: 0.8128 - val_binary_accuracy: 0.7448
# Epoch 44/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.3287 - precision: 0.8535 - recall: 0.8672 - auc: 0.9342 - binary_accuracy: 0.8593 - val_loss: 0.6102 - val_precision: 0.7378 - val_recall: 0.7592 - val_auc: 0.8129 - val_binary_accuracy: 0.7447
# Epoch 45/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3256 - precision: 0.8550 - recall: 0.8690 - auc: 0.9356 - binary_accuracy: 0.8608 - val_loss: 0.6130 - val_precision: 0.7379 - val_recall: 0.7615 - val_auc: 0.8128 - val_binary_accuracy: 0.7455
# Epoch 46/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3247 - precision: 0.8561 - recall: 0.8699 - auc: 0.9359 - binary_accuracy: 0.8616 - val_loss: 0.6154 - val_precision: 0.7384 - val_recall: 0.7613 - val_auc: 0.8128 - val_binary_accuracy: 0.7458
# Epoch 47/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3221 - precision: 0.8568 - recall: 0.8709 - auc: 0.9369 - binary_accuracy: 0.8628 - val_loss: 0.6181 - val_precision: 0.7373 - val_recall: 0.7621 - val_auc: 0.8129 - val_binary_accuracy: 0.7453
# Epoch 48/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3195 - precision: 0.8593 - recall: 0.8725 - auc: 0.9380 - binary_accuracy: 0.8647 - val_loss: 0.6213 - val_precision: 0.7378 - val_recall: 0.7620 - val_auc: 0.8126 - val_binary_accuracy: 0.7456
# Epoch 49/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3176 - precision: 0.8597 - recall: 0.8729 - auc: 0.9388 - binary_accuracy: 0.8653 - val_loss: 0.6235 - val_precision: 0.7380 - val_recall: 0.7642 - val_auc: 0.8128 - val_binary_accuracy: 0.7465
# Epoch 50/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3152 - precision: 0.8605 - recall: 0.8741 - auc: 0.9397 - binary_accuracy: 0.8663 - val_loss: 0.6262 - val_precision: 0.7376 - val_recall: 0.7639 - val_auc: 0.8127 - val_binary_accuracy: 0.7461
# Epoch 51/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3134 - precision: 0.8614 - recall: 0.8753 - auc: 0.9404 - binary_accuracy: 0.8673 - val_loss: 0.6293 - val_precision: 0.7377 - val_recall: 0.7636 - val_auc: 0.8126 - val_binary_accuracy: 0.7460
# Epoch 52/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3122 - precision: 0.8622 - recall: 0.8758 - auc: 0.9409 - binary_accuracy: 0.8679 - val_loss: 0.6318 - val_precision: 0.7388 - val_recall: 0.7644 - val_auc: 0.8127 - val_binary_accuracy: 0.7470
# Epoch 53/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3097 - precision: 0.8636 - recall: 0.8769 - auc: 0.9419 - binary_accuracy: 0.8692 - val_loss: 0.6351 - val_precision: 0.7384 - val_recall: 0.7645 - val_auc: 0.8125 - val_binary_accuracy: 0.7468
# Epoch 54/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3080 - precision: 0.8642 - recall: 0.8780 - auc: 0.9425 - binary_accuracy: 0.8699 - val_loss: 0.6378 - val_precision: 0.7381 - val_recall: 0.7636 - val_auc: 0.8125 - val_binary_accuracy: 0.7463
# Epoch 55/200
# 2352/2352 [==============================] - 18s 7ms/step - loss: 0.3069 - precision: 0.8648 - recall: 0.8781 - auc: 0.9428 - binary_accuracy: 0.8705 - val_loss: 0.6408 - val_precision: 0.7386 - val_recall: 0.7647 - val_auc: 0.8124 - val_binary_accuracy: 0.7470
# Epoch 56/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3041 - precision: 0.8662 - recall: 0.8800 - auc: 0.9440 - binary_accuracy: 0.8720 - val_loss: 0.6436 - val_precision: 0.7394 - val_recall: 0.7656 - val_auc: 0.8124 - val_binary_accuracy: 0.7479
# Epoch 57/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3027 - precision: 0.8665 - recall: 0.8802 - auc: 0.9445 - binary_accuracy: 0.8726 - val_loss: 0.6466 - val_precision: 0.7395 - val_recall: 0.7652 - val_auc: 0.8124 - val_binary_accuracy: 0.7479
# Epoch 58/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.3014 - precision: 0.8676 - recall: 0.8812 - auc: 0.9450 - binary_accuracy: 0.8733 - val_loss: 0.6493 - val_precision: 0.7400 - val_recall: 0.7654 - val_auc: 0.8125 - val_binary_accuracy: 0.7482
# Epoch 59/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2988 - precision: 0.8693 - recall: 0.8820 - auc: 0.9460 - binary_accuracy: 0.8744 - val_loss: 0.6522 - val_precision: 0.7409 - val_recall: 0.7654 - val_auc: 0.8125 - val_binary_accuracy: 0.7489
# Epoch 60/200
# 2352/2352 [==============================] - 16s 7ms/step - loss: 0.2971 - precision: 0.8698 - recall: 0.8829 - auc: 0.9466 - binary_accuracy: 0.8755 - val_loss: 0.6555 - val_precision: 0.7409 - val_recall: 0.7661 - val_auc: 0.8123 - val_binary_accuracy: 0.7491
# Epoch 61/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2950 - precision: 0.8716 - recall: 0.8850 - auc: 0.9474 - binary_accuracy: 0.8772 - val_loss: 0.6581 - val_precision: 0.7413 - val_recall: 0.7652 - val_auc: 0.8123 - val_binary_accuracy: 0.7491
# Epoch 62/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2937 - precision: 0.8716 - recall: 0.8842 - auc: 0.9478 - binary_accuracy: 0.8769 - val_loss: 0.6613 - val_precision: 0.7427 - val_recall: 0.7659 - val_auc: 0.8121 - val_binary_accuracy: 0.7503
# Epoch 63/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2917 - precision: 0.8728 - recall: 0.8857 - auc: 0.9485 - binary_accuracy: 0.8782 - val_loss: 0.6643 - val_precision: 0.7425 - val_recall: 0.7679 - val_auc: 0.8123 - val_binary_accuracy: 0.7508
# Epoch 64/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2897 - precision: 0.8736 - recall: 0.8870 - auc: 0.9493 - binary_accuracy: 0.8792 - val_loss: 0.6672 - val_precision: 0.7422 - val_recall: 0.7671 - val_auc: 0.8122 - val_binary_accuracy: 0.7503
# Epoch 65/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2881 - precision: 0.8748 - recall: 0.8871 - auc: 0.9498 - binary_accuracy: 0.8802 - val_loss: 0.6698 - val_precision: 0.7423 - val_recall: 0.7668 - val_auc: 0.8123 - val_binary_accuracy: 0.7503
# Epoch 66/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2860 - precision: 0.8753 - recall: 0.8883 - auc: 0.9506 - binary_accuracy: 0.8809 - val_loss: 0.6732 - val_precision: 0.7439 - val_recall: 0.7689 - val_auc: 0.8121 - val_binary_accuracy: 0.7521
# Epoch 67/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2844 - precision: 0.8770 - recall: 0.8890 - auc: 0.9512 - binary_accuracy: 0.8820 - val_loss: 0.6767 - val_precision: 0.7433 - val_recall: 0.7679 - val_auc: 0.8120 - val_binary_accuracy: 0.7513
# Epoch 68/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2834 - precision: 0.8769 - recall: 0.8897 - auc: 0.9515 - binary_accuracy: 0.8824 - val_loss: 0.6797 - val_precision: 0.7426 - val_recall: 0.7686 - val_auc: 0.8120 - val_binary_accuracy: 0.7511
# Epoch 69/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.2812 - precision: 0.8783 - recall: 0.8909 - auc: 0.9522 - binary_accuracy: 0.8836 - val_loss: 0.6830 - val_precision: 0.7441 - val_recall: 0.7693 - val_auc: 0.8119 - val_binary_accuracy: 0.7523
# Epoch 70/200
# 2352/2352 [==============================] - 18s 7ms/step - loss: 0.2796 - precision: 0.8790 - recall: 0.8912 - auc: 0.9528 - binary_accuracy: 0.8844 - val_loss: 0.6861 - val_precision: 0.7438 - val_recall: 0.7679 - val_auc: 0.8119 - val_binary_accuracy: 0.7517
# Epoch 71/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2775 - precision: 0.8799 - recall: 0.8924 - auc: 0.9535 - binary_accuracy: 0.8853 - val_loss: 0.6892 - val_precision: 0.7444 - val_recall: 0.7694 - val_auc: 0.8119 - val_binary_accuracy: 0.7526
# Epoch 72/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2760 - precision: 0.8802 - recall: 0.8929 - auc: 0.9540 - binary_accuracy: 0.8858 - val_loss: 0.6925 - val_precision: 0.7443 - val_recall: 0.7692 - val_auc: 0.8119 - val_binary_accuracy: 0.7525
# Epoch 73/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.2751 - precision: 0.8808 - recall: 0.8935 - auc: 0.9543 - binary_accuracy: 0.8862 - val_loss: 0.6956 - val_precision: 0.7440 - val_recall: 0.7698 - val_auc: 0.8119 - val_binary_accuracy: 0.7525
# Epoch 74/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2739 - precision: 0.8814 - recall: 0.8939 - auc: 0.9547 - binary_accuracy: 0.8870 - val_loss: 0.6988 - val_precision: 0.7444 - val_recall: 0.7713 - val_auc: 0.8119 - val_binary_accuracy: 0.7532
# Epoch 75/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2712 - precision: 0.8823 - recall: 0.8952 - auc: 0.9556 - binary_accuracy: 0.8880 - val_loss: 0.7027 - val_precision: 0.7441 - val_recall: 0.7707 - val_auc: 0.8116 - val_binary_accuracy: 0.7528
# Epoch 76/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2696 - precision: 0.8835 - recall: 0.8962 - auc: 0.9561 - binary_accuracy: 0.8890 - val_loss: 0.7056 - val_precision: 0.7437 - val_recall: 0.7713 - val_auc: 0.8117 - val_binary_accuracy: 0.7528
# Epoch 77/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2680 - precision: 0.8844 - recall: 0.8972 - auc: 0.9567 - binary_accuracy: 0.8898 - val_loss: 0.7091 - val_precision: 0.7440 - val_recall: 0.7708 - val_auc: 0.8116 - val_binary_accuracy: 0.7528
# Epoch 78/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2674 - precision: 0.8844 - recall: 0.8964 - auc: 0.9569 - binary_accuracy: 0.8895 - val_loss: 0.7121 - val_precision: 0.7442 - val_recall: 0.7718 - val_auc: 0.8116 - val_binary_accuracy: 0.7533
# Epoch 79/200
# 2352/2352 [==============================] - 18s 7ms/step - loss: 0.2652 - precision: 0.8860 - recall: 0.8981 - auc: 0.9576 - binary_accuracy: 0.8911 - val_loss: 0.7161 - val_precision: 0.7437 - val_recall: 0.7710 - val_auc: 0.8114 - val_binary_accuracy: 0.7526
# Epoch 80/200
# 2352/2352 [==============================] - 18s 8ms/step - loss: 0.2635 - precision: 0.8862 - recall: 0.8992 - auc: 0.9581 - binary_accuracy: 0.8919 - val_loss: 0.7189 - val_precision: 0.7440 - val_recall: 0.7710 - val_auc: 0.8115 - val_binary_accuracy: 0.7529
# Epoch 81/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2619 - precision: 0.8873 - recall: 0.8995 - auc: 0.9586 - binary_accuracy: 0.8927 - val_loss: 0.7224 - val_precision: 0.7434 - val_recall: 0.7709 - val_auc: 0.8114 - val_binary_accuracy: 0.7524
# Epoch 82/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2598 - precision: 0.8880 - recall: 0.9001 - auc: 0.9593 - binary_accuracy: 0.8933 - val_loss: 0.7260 - val_precision: 0.7438 - val_recall: 0.7692 - val_auc: 0.8113 - val_binary_accuracy: 0.7521
# Epoch 83/200
# 2352/2352 [==============================] - 17s 7ms/step - loss: 0.2587 - precision: 0.8885 - recall: 0.9011 - auc: 0.9597 - binary_accuracy: 0.8940 - val_loss: 0.7289 - val_precision: 0.7444 - val_recall: 0.7709 - val_auc: 0.8113 - val_binary_accuracy: 0.7531

# %% [markdown]
# ### Evaluation

# %%
predictions = model_mf.predict([df_test['product_id'], df_test['user_id']]).ravel()
predictions_x = np.where(predictions > 0.5, 1, 0)

# %%
sklearn.metrics.classification_report(df_test['bought'], predictions_x, output_dict=True)
# Out:
# {'0': {'f1-score': 0.7516012429450187,
#   'precision': 0.7565428316098557,
#   'recall': 0.7467237903225806,
#   'support': 7936},
#  '1': {'f1-score': 0.7548043818466353,
#   'precision': 0.7499689016046772,
#   'recall': 0.7597026209677419,
#   'support': 7936},
#  'accuracy': 0.7532132056451613,
#  'macro avg': {'f1-score': 0.753202812395827,
#   'precision': 0.7532558666072664,
#   'recall': 0.7532132056451613,
#   'support': 15872},
#  'weighted avg': {'f1-score': 0.753202812395827,
#   'precision': 0.7532558666072664,
#   'recall': 0.7532132056451613,
#   'support': 15872}}

# %%
df_test['pred_proba']  = predictions
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
fpr, tpr, _ = metrics.roc_curve(df_test['bought'],  df_test['pred_proba'])
auc = metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'])
print(auc)
plt.plot(fpr,tpr,label="lstm, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.8303218051620627

# %%
#weighted accuracy
sklearn.metrics.classification_report(df_test['bought'], predictions_x, sample_weight= df_test['sample_weight'], output_dict=True)
# Out:
# {'0': {'f1-score': 0.4356960172203371,
#   'precision': 0.3648149366178918,
#   'recall': 0.5407625275346036,
#   'support': 233.8311516399456},
#  '1': {'f1-score': 0.6695065069555655,
#   'precision': 0.7554723865693768,
#   'recall': 0.6011061048218749,
#   'support': 551.9239419021508},
#  'accuracy': 0.5831485907222209,
#  'macro avg': {'f1-score': 0.5526012620879512,
#   'precision': 0.5601436615936343,
#   'recall': 0.5709343161782392,
#   'support': 785.7550935420963},
#  'weighted avg': {'f1-score': 0.599927351147829,
#   'precision': 0.6392174845399237,
#   'recall': 0.5831485907222215,
#   'support': 785.7550935420963}}

# %%
# weighted AUC
fpr, tpr, _ = metrics.roc_curve(df_test['bought'],  df_test['pred_proba'], sample_weight=df_test['sample_weight'])
auc = metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'], sample_weight=df_test['sample_weight'])
print(auc)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.6297250471528997

# %% [markdown]
# ### Grid search

# %%
    def get_model(param):
        dim_embedddings = 100
        bias = 1

        # products
        product_input = Input(shape=[1],name='product_input')
        product_embedding = Embedding(n_products +1, dim_embedddings, name="product_embedding")(product_input)
        product_bias = Embedding(n_products + 1, bias, name="product_bias")(product_input)

        # users
        user_input = Input(shape=[1],name='User')
        user_embedding = Embedding(n_users+1, dim_embedddings, name="User-Embedding")(user_input)
        user_bias = Embedding(n_users + 1, bias, name="user_bias")(user_input)

        matrix_product = multiply([product_embedding, user_embedding])

        input_terms = concatenate([matrix_product, user_bias, product_bias])
        input_terms = Flatten()(input_terms)

        result = Dense(1, activation='sigmoid')(input_terms)

        model_mf = Model(inputs=[product_input, user_input], outputs=result)
        ## compile model
        model_mf.compile(optimizer=keras.optimizers.Adam(learning_rate=param['lr']), loss = ['binary_crossentropy'], metrics = ['AUC', keras.metrics.BinaryAccuracy()])   
        
        return model_mf

# %%
param_grid = {
    'lr': [1e-3, 1e-4, 1e-5],
    'epochs': 200, 
    'batch_size': [512, 1024, 2048]
}
early = EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)
kgs = KerasRandomSearch(get_model, param_grid, monitor='val_binary_accuracy', greater_is_better=True, n_iter=9)

# %%
kgs.search([df_train['product_id'], df_train['user_id']],
                          df_train['bought'],
                          validation_data = ([df_test['product_id'], df_test['user_id']],
                          df_test['bought']), callbacks=[early])
# Out:
# 9 trials detected for ('lr', 'epochs', 'batch_size')
#
# ***** (1/9) *****
# Search({'lr': 1e-05, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.66406 at epoch 41
#
# ***** (2/9) *****
# Search({'lr': 1e-05, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.66904 at epoch 30
#
# ***** (3/9) *****
# Search({'lr': 0.001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75271 at epoch 10
#
# ***** (4/9) *****
# Search({'lr': 1e-05, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.66753 at epoch 26
#
# ***** (5/9) *****
# Search({'lr': 0.0001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.75788 at epoch 32
#
# ***** (6/9) *****
# Search({'lr': 0.0001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.75775 at epoch 52
#
# ***** (7/9) *****
# Search({'lr': 0.001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.75567 at epoch 5
#
# ***** (8/9) *****
# Search({'lr': 0.001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.74798 at epoch 4
#
# ***** (9/9) *****
# Search({'lr': 0.0001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75176 at epoch 52

# %% [markdown]
# ### Recall@N

# %%
df['product_id'] = df['product_id'].astype('int')
df['user_id'] = df['user_id'].astype('int')

all_users = df[df['data_split'] == 'test']['user_id'].unique().tolist()
recall_matrix = np.zeros(shape=(len(all_users),2))
recall_matrix_weighted = np.zeros(shape=(len(all_users),2))
for user_id in all_users:
  max_date = max(df[df['user_id'] == user_id]['day'])
  df_train = df[(df['user_id'] == user_id) & (df['data_split'] == 'train')]
  df_train = df_train[['day','product_id', 'bought', 'data_split', 'sample_weight']]

  df_test = df[(df['user_id'] == user_id) & (df['bought'] == 1) & (df['day'] == max_date)]
  df_test = df_test[['day','product_id', 'bought', 'data_split', 'sample_weight']]
  bought_products = df_test['product_id'].unique()
  df_day = df[(df['day'] == max_date) & (df['bought'] == 1) & (df['user_id'] != user_id)]
  df_day = df_day[['product_id']].drop_duplicates()
  df_day = df_day.loc[~df_day['product_id'].isin(bought_products)]
  df_day['bought'] = 0
  df_day['data_split'] = 'test'

  df_test = df_test.append(df_day)
  train = df_train.append(df_test)
  train['user_id'] = user_id

  df_test = train[(train['data_split'] == 'test')]
  predictions = model_mf.predict([df_test['product_id'], df_test['user_id']]).ravel()
  df_test['ypred_proba'] = predictions
  df_test['sample_weight_for_only_bought'] = np.where(df_test['bought'] == 1, df_test['sample_weight'], 0)
  df_test['norm_weight'] = df_test['sample_weight_for_only_bought'] / df_test.groupby('day')['sample_weight_for_only_bought'].transform('sum')
  df_test['norm_weight'] = df_test['norm_weight'] * df_test.groupby('day')['bought'].transform('sum')

  recall_matrix_weighted[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['norm_weight'].sum() / df_test['bought'].sum()) * 100])
  recall_matrix[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['bought'].sum() / df_test['bought'].sum()) * 100])

# %%
pd.DataFrame(recall_matrix)[1].mean() # recall@n
# Out:
# 22.308075022847294

# %%
pd.DataFrame(recall_matrix_weighted)[1].mean() #recall@n weighted
# Out:
# 19.12021266885269

# %% [markdown]
# # Shopper Model

# %% [markdown]
# A detailed example of Shopper model can also be found in this blog: https://humboldt-wi.github.io/blog/research/information_systems_1920/group3_shopper/

# %%
user = Input(name = 'user', shape = (1,))
item = Input(name = 'item', shape = (1,))
price = Input(name = 'price', shape = (1,))
week = Input(name = 'week', shape = (1,))
subcategory = Input(name = 'subcategory', shape = (1,)) # added to shopper+
discount = Input(name='discount', shape=(1,)) # added to shopper+
diffs = Input(name='diffs', shape=(1,)) # added to shopper+
other_prods = Input(name='other_prods', shape=(35,))

# %% [markdown]
# item popularity

# %%
item_pop = Embedding(name = 'item_pop', 
                           input_dim = item_len, 
                           output_dim = 1)(item)
item_pop = Reshape(target_shape = (1, ))(item_pop)

# %% [markdown]
# user item interaction

# %%
user_embedding_for_item = Embedding(name = 'user_embedding_for_item',
                               input_dim = user_len,
                               output_dim = embedding_size,
                               embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                               trainable=True
                               )(user)

item_embedding_for_user = Embedding(name = 'item_embedding_for_user', 
                           input_dim = item_len, 
                           output_dim = embedding_size,
                           embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                           trainable=True
                           )(item)

user_item_embedding = Dot(name = 'user_item_embedding', axes = 2)([item_embedding_for_user, user_embedding_for_item])

user_item_embedding = Reshape(target_shape = (1, ))(user_item_embedding)

# %% [markdown]
# item and other products in basket

# %%
item_embedding_for_rest_basket = Embedding(name = 'item_embedding_for_rest_basket',
                               input_dim = item_len,
                               output_dim = embedding_size,
                           embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                           trainable=True
                               )(item)


rest_basket_embedding_for_prev_basket = Embedding(name = 'rest_basket_embedding_for_prev_basket',
                               input_dim = item_len,
                               output_dim = embedding_size,
                           embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                           trainable=True,
                          mask_zero=True
                               )(other_prods)

avg_basket_embedding = keras.layers.Lambda(lambda x: keras.backend.mean(x, axis=1))(rest_basket_embedding_for_prev_basket)
avg_basket_embedding = Reshape(target_shape=(1,embedding_size))(avg_basket_embedding)


item_rest_basket = Dot(name = 'item_rest_basket', axes = 2)([item_embedding_for_rest_basket, avg_basket_embedding])

item_rest_basket_embedding1 = Reshape(target_shape = (1,))(item_rest_basket)

# %% [markdown]
# user price sensitivity for item

# %%
item_embedding_for_price = Embedding(name = 'item_embedding_for_price', 
                          input_dim = item_len, 
                          output_dim = embedding_size,
                          embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                          trainable=True
                          )(item)

#results should be non negative - because if embedding weights are negative, this would mislead price effects (see shopper paper)
constraint_layer = nonneg()
constrained_item = constraint_layer(item_embedding_for_price)
user_embedding_for_price = Embedding(name = "user_embedding_for_price",
                                 input_dim = user_len,
                                 output_dim = embedding_size,
                                 embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                                 trainable=True
                                 )(user)

constrained_user = constraint_layer(user_embedding_for_price)
user_item_price_embedding = Dot(name = 'user_item_price_embedding', axes = 2)([constrained_item, constrained_user])

user_item_price_embedding1 = Reshape(target_shape = (1,))(user_item_price_embedding)

user_item_price_embedding2 = multiply([price * -1, user_item_price_embedding1], name = 'user_item_price_embedding2')

# %% [markdown]
# subcategory discount user

# %%
# added to shopper+
subcategory_embedding_for_discount = Embedding(name = 'subcategory_embedding_for_discount', 
                          input_dim = sub_len, 
                          output_dim = embedding_size)(subcategory)

#results should be non negative - because if embedding weights are negative, this would mislead discount effects 
constraint_layer = nonneg()
constrained_sub = constraint_layer(subcategory_embedding_for_discount)
user_embedding_for_discount = Embedding(name = "user_embedding_for_discount",
                                 input_dim = user_len,
                                 output_dim = embedding_size,
                                 embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                                 trainable=True
                             )(user)

constrained_user = constraint_layer(user_embedding_for_discount)


user_subcategory_discount_embedding = Dot(name = 'user_subcategory_discount_embedding', axes = 2)([constrained_sub, constrained_user])
user_subcategory_discount_embedding1 = Reshape(target_shape = (1,))(user_subcategory_discount_embedding)
user_subcategory_discount_embedding2 = multiply([discount, user_subcategory_discount_embedding1], name = 'user_subcategory_discount_embedding2')

# %%
# added to shopper+
subcategory_embedding_for_discount = Embedding(name = 'subcategory_embedding_for_discount_diff', 
                          input_dim = sub_len, 
                          output_dim = embedding_size)(subcategory)

constraint_layer = nonneg()
constrained_sub = constraint_layer(subcategory_embedding_for_discount)
user_embedding_for_discount = Embedding(name = "user_embedding_for_discount_diff",
                                 input_dim = user_len,
                                 output_dim = embedding_size,
                                 embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                                 trainable=True
                             )(user)

constrained_user = constraint_layer(user_embedding_for_discount)


user_subcategory_discount_diff_embedding = Dot(name = 'user_subcategory_discount_diff_embedding', axes = 2)([constrained_sub, constrained_user])
user_subcategory_discount_diff_embedding1 = Reshape(target_shape = (1,))(user_subcategory_discount_diff_embedding)
user_subcategory_discount_diff_embedding2 = multiply([diffs, user_subcategory_discount_diff_embedding1], name = 'user_subcategory_discount_diff_embedding2')

# %% [markdown]
# week item interaction

# %%
week_embedding = Embedding(name = 'week_embedding',
                               input_dim = day_len,
                               output_dim = embedding_size)(week)

week_item_embedding = Embedding(name = 'week_item_embedding', 
                           input_dim = item_len, 
                           output_dim = embedding_size,
                           embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                           trainable=True
                           )(item)


week_item_embedding1 = Dot(name = 'week_item_embedding1', axes = 2)([week_item_embedding, week_embedding])

week_item_embedding2 = Reshape(target_shape = (1, ))(week_item_embedding1)

# %%
x = keras.layers.add([item_pop,
                      user_item_embedding, 
                      user_item_price_embedding2,  
                      week_item_embedding2, 
                      item_rest_basket_embedding1, 
                      user_subcategory_discount_embedding2, # added to shopper+
                      user_subcategory_discount_diff_embedding2 # added to shopper+
                      ])

# %%
out = Dense(1, activation = 'sigmoid', name = 'output')(x)
model = Model(inputs = [
                        user, 
                        item, 
                        price, 
                        week,
                        subcategory, # added to shopper+ 
                        discount, # added to shopper+
                        diffs , # added to shopper+
                        other_prods], outputs = out) 
    
model.compile(optimizer = Adam(lr=0.001), loss = 'binary_crossentropy',
              metrics = [keras.metrics.AUC(), keras.metrics.BinaryAccuracy()])

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# item (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# user (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# item_embedding_for_price (Embed (None, 1, 100)       1190400     item[0][0]
# __________________________________________________________________________________________________
# user_embedding_for_price (Embed (None, 1, 100)       100000      user[0][0]
# __________________________________________________________________________________________________
# tf.math.greater_equal (TFOpLamb (None, 1, 100)       0           item_embedding_for_price[0][0]
# __________________________________________________________________________________________________
# tf.math.greater_equal_1 (TFOpLa (None, 1, 100)       0           user_embedding_for_price[0][0]
# __________________________________________________________________________________________________
# other_prods (InputLayer)        [(None, 35)]         0
# __________________________________________________________________________________________________
# tf.cast (TFOpLambda)            (None, 1, 100)       0           tf.math.greater_equal[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None, 1, 100)       0           tf.math.greater_equal_1[0][0]
# __________________________________________________________________________________________________
# rest_basket_embedding_for_prev_ (None, 35, 100)      1190400     other_prods[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 1, 100)       0           item_embedding_for_price[0][0]
#                                                                  tf.cast[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 1, 100)       0           user_embedding_for_price[0][0]
#                                                                  tf.cast_1[0][0]
# __________________________________________________________________________________________________
# week (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 100)          0           rest_basket_embedding_for_prev_ba
# __________________________________________________________________________________________________
# item_embedding_for_user (Embedd (None, 1, 100)       1190400     item[0][0]
# __________________________________________________________________________________________________
# user_embedding_for_item (Embedd (None, 1, 100)       100000      user[0][0]
# __________________________________________________________________________________________________
# price (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# user_item_price_embedding (Dot) (None, 1, 1)         0           tf.math.multiply[0][0]
#                                                                  tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# week_item_embedding (Embedding) (None, 1, 100)       1190400     item[0][0]
# __________________________________________________________________________________________________
# week_embedding (Embedding)      (None, 1, 100)       5400        week[0][0]
# __________________________________________________________________________________________________
# item_embedding_for_rest_basket  (None, 1, 100)       1190400     item[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 100)       0           lambda[0][0]
# __________________________________________________________________________________________________
# item_pop (Embedding)            (None, 1, 1)         11904       item[0][0]
# __________________________________________________________________________________________________
# user_item_embedding (Dot)       (None, 1, 1)         0           item_embedding_for_user[0][0]
#                                                                  user_embedding_for_item[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 1)            0           price[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1)            0           user_item_price_embedding[0][0]
# __________________________________________________________________________________________________
# week_item_embedding1 (Dot)      (None, 1, 1)         0           week_item_embedding[0][0]
#                                                                  week_embedding[0][0]
# __________________________________________________________________________________________________
# item_rest_basket (Dot)          (None, 1, 1)         0           item_embedding_for_rest_basket[0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1)            0           item_pop[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           user_item_embedding[0][0]
# __________________________________________________________________________________________________
# user_item_price_embedding2 (Mul (None, 1)            0           tf.math.multiply_2[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1)            0           week_item_embedding1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1)            0           item_rest_basket[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           reshape[0][0]
#                                                                  reshape_1[0][0]
#                                                                  user_item_price_embedding2[0][0]
#                                                                  reshape_5[0][0]
#                                                                  reshape_3[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            2           add[0][0]
# ==================================================================================================
# Total params: 6,169,306
# Trainable params: 6,169,306
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
early_stopping_monitor = EarlyStopping(
    monitor='val_binary_accuracy',
    patience=5,
    mode='max',
    restore_best_weights=True
)

history = model.fit({'user': df_train['user_id'], 
                     'item': df_train['product_id'], 
                     'price': df_train['price'], 
                     'week': df_train['week'], 
                     'subcategory': df_train['subcategory_name'], # added to shopper+
                     'discount': df_train['discount'], # added to shopper+
                     'diffs': df_train['diffs'],  # added to shopper+
                     'other_prods': tf.convert_to_tensor(df_train['other_prods_in_basket'].tolist())},
          {'output': df_train['bought']},
          epochs=200, validation_data=
          (
              {'user': df_test['user_id'], 
               'item': df_test['product_id'], 
               'price': df_test['price'], 
               'week': df_test['week'], 
               'subcategory': df_test['subcategory_name'], # added to shopper+
               'discount': df_test['discount'], # added to shopper+    
               'diffs': df_test['diffs'],  # added to shopper+
               'other_prods': tf.convert_to_tensor(df_test['other_prods_in_basket'].tolist())},
          {'output': df_test['bought']}), batch_size = 1024, callbacks=[early_stopping_monitor]
          )
# Out:
# Epoch 1/200
# 1176/1176 [==============================] - 31s 24ms/step - loss: 0.6068 - auc: 0.7279 - binary_accuracy: 0.6638 - val_loss: 0.5370 - val_auc: 0.8000 - val_binary_accuracy: 0.7182
# Epoch 2/200
# 1176/1176 [==============================] - 30s 26ms/step - loss: 0.3491 - auc: 0.9288 - binary_accuracy: 0.8510 - val_loss: 0.5189 - val_auc: 0.8305 - val_binary_accuracy: 0.7470
# Epoch 3/200
# 1176/1176 [==============================] - 30s 25ms/step - loss: 0.2227 - auc: 0.9728 - binary_accuracy: 0.9156 - val_loss: 0.5636 - val_auc: 0.8345 - val_binary_accuracy: 0.7492
# Epoch 4/200
# 1176/1176 [==============================] - 32s 27ms/step - loss: 0.1536 - auc: 0.9868 - binary_accuracy: 0.9452 - val_loss: 0.6400 - val_auc: 0.8327 - val_binary_accuracy: 0.7499
# Epoch 5/200
# 1176/1176 [==============================] - 32s 27ms/step - loss: 0.1150 - auc: 0.9923 - binary_accuracy: 0.9597 - val_loss: 0.7234 - val_auc: 0.8289 - val_binary_accuracy: 0.7520
# Epoch 6/200
# 1176/1176 [==============================] - 33s 28ms/step - loss: 0.0914 - auc: 0.9949 - binary_accuracy: 0.9684 - val_loss: 0.8138 - val_auc: 0.8251 - val_binary_accuracy: 0.7488
# Epoch 7/200
# 1176/1176 [==============================] - 34s 29ms/step - loss: 0.0747 - auc: 0.9965 - binary_accuracy: 0.9743 - val_loss: 0.8978 - val_auc: 0.8216 - val_binary_accuracy: 0.7491
# Epoch 8/200
# 1176/1176 [==============================] - 32s 27ms/step - loss: 0.0629 - auc: 0.9974 - binary_accuracy: 0.9785 - val_loss: 0.9815 - val_auc: 0.8190 - val_binary_accuracy: 0.7496
# Epoch 9/200
# 1176/1176 [==============================] - 31s 26ms/step - loss: 0.0522 - auc: 0.9981 - binary_accuracy: 0.9829 - val_loss: 1.0583 - val_auc: 0.8153 - val_binary_accuracy: 0.7464
# Epoch 10/200
# 1176/1176 [==============================] - 31s 26ms/step - loss: 0.0445 - auc: 0.9985 - binary_accuracy: 0.9857 - val_loss: 1.1274 - val_auc: 0.8137 - val_binary_accuracy: 0.7470

# %% [markdown]
# ## Evaluation

# %%
predictions = model.predict({'user': df_test['user_id'], 
                             'item': df_test['product_id'], 
                             'price': df_test['price'], 
                             'week': df_test['week'], 
                             'subcategory': df_test['subcategory_name'], 
                             'discount': df_test['discount'], 
                             'diffs': df_test['diffs'],
                             'other_prods': tf.convert_to_tensor(df_test['other_prods_in_basket'].tolist())})
df_test['pred_proba']  = predictions
predictions_x = np.where(predictions > 0.5, 1, 0)
df_test['pred'] = predictions_x

# %%
fpr, tpr, _ = metrics.roc_curve(df_test['bought'],  df_test['pred_proba'])
auc = metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'])
print(auc)
plt.plot(fpr,tpr,label="lstm, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.8360131985191004

# %%
sklearn.metrics.classification_report(df_test['bought'], predictions_x, output_dict=True)
# Out:
# {'0': {'f1-score': 0.7548113933795229,
#   'precision': 0.7688186095138526,
#   'recall': 0.7413054435483871,
#   'support': 7936},
#  '1': {'f1-score': 0.7634315424610053,
#   'precision': 0.7502433090024331,
#   'recall': 0.7770917338709677,
#   'support': 7936},
#  'accuracy': 0.7591985887096774,
#  'macro avg': {'f1-score': 0.759121467920264,
#   'precision': 0.7595309592581428,
#   'recall': 0.7591985887096775,
#   'support': 15872},
#  'weighted avg': {'f1-score': 0.759121467920264,
#   'precision': 0.7595309592581428,
#   'recall': 0.7591985887096774,
#   'support': 15872}}

# %%
#weighted AUC
fpr, tpr, _ = metrics.roc_curve(df_test['bought'],  df_test['pred_proba'], sample_weight=df_test['sample_weight'])
auc = metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'], sample_weight=df_test['sample_weight'])
print(auc)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.6821032610850198

# %%
#weighted accuracy
sklearn.metrics.classification_report(df_test['bought'], predictions_x, sample_weight= df_test['sample_weight'], output_dict=True)
# Out:
# {'0': {'f1-score': 0.49122759361820517,
#   'precision': 0.4210672962398838,
#   'recall': 0.5894435715283158,
#   'support': 233.8311516399456},
#  '1': {'f1-score': 0.7174168105048391,
#   'precision': 0.7905829474737431,
#   'recall': 0.656646133503124,
#   'support': 551.9239419021508},
#  'accuracy': 0.6366474690479097,
#  'macro avg': {'f1-score': 0.6043222020615221,
#   'precision': 0.6058251218568135,
#   'recall': 0.62304485251572,
#   'support': 785.7550935420963},
#  'weighted avg': {'f1-score': 0.6501056527308354,
#   'precision': 0.6806195874050264,
#   'recall': 0.6366474690479094,
#   'support': 785.7550935420963}}

# %% [markdown]
# ## Grid search

# %%
def get_model(param):
    user = Input(name = 'user', shape = (1,))
    item = Input(name = 'item', shape = (1,))
    price = Input(name = 'price', shape = (1,))
    week = Input(name = 'week', shape = (1,))
    subcategory = Input(name = 'subcategory', shape = (1,))
    discount = Input(name='discount', shape=(1,))
    diffs = Input(name='diffs', shape=(1,))
    other_prods = Input(name='other_prods', shape=(35,))

    item_pop = Embedding(name = 'item_pop', 
                              input_dim = item_len, 
                              output_dim = 1)(item)
    item_pop = Reshape(target_shape = (1, ))(item_pop)
    user_embedding_for_item = Embedding(name = 'user_embedding_for_item',
                                  input_dim = user_len,
                                  output_dim = embedding_size,
                                  embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                                  )(user)
    item_embedding_for_user = Embedding(name = 'item_embedding_for_user', 
                              input_dim = item_len, 
                              output_dim = embedding_size,
                              embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights),
                              )(item)
    user_item_embedding = Dot(name = 'user_item_embedding', axes = 2)([item_embedding_for_user, user_embedding_for_item])
    user_item_embedding = Reshape(target_shape = (1, ))(user_item_embedding)
    item_embedding_for_rest_basket = Embedding(name = 'item_embedding_for_rest_basket',
                                  input_dim = item_len,
                                  output_dim = embedding_size,
                                  embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights),
                                  )(item)
    rest_basket_embedding_for_prev_basket = Embedding(name = 'rest_basket_embedding_for_prev_basket',
                                  input_dim = item_len,
                                  output_dim = embedding_size,
                                  embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights),
                                  mask_zero=True
                                  )(other_prods)
    avg_basket_embedding = keras.layers.Lambda(lambda x: keras.backend.mean(x, axis=1))(rest_basket_embedding_for_prev_basket)
    avg_basket_embedding = Reshape(target_shape=(1,embedding_size))(avg_basket_embedding)
    item_rest_basket = Dot(name = 'item_rest_basket', axes = 2)([item_embedding_for_rest_basket, avg_basket_embedding])
    item_rest_basket_embedding1 = Reshape(target_shape = (1,))(item_rest_basket)
    item_embedding_for_price = Embedding(name = 'item_embedding_for_price', 
                              input_dim = item_len, 
                              output_dim = embedding_size,
                             embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights),
                              )(item)
    constraint_layer = nonneg()
    constrained_item = constraint_layer(item_embedding_for_price)
    user_embedding_for_price = Embedding(name = "user_embedding_for_price",
                                    input_dim = user_len,
                                    output_dim = embedding_size,
                                    embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                                    )(user)
    constrained_user = constraint_layer(user_embedding_for_price)
    user_item_price_embedding = Dot(name = 'user_item_price_embedding', axes = 2)([constrained_item, constrained_user])
    user_item_price_embedding1 = Reshape(target_shape = (1,))(user_item_price_embedding)
    user_item_price_embedding2 = multiply([price * -1, user_item_price_embedding1], name = 'user_item_price_embedding2')
    week_embedding = Embedding(name = 'week_embedding',
                                  input_dim = day_len,
                                  output_dim = embedding_size)(week)
    week_item_embedding = Embedding(name = 'week_item_embedding', 
                              input_dim = item_len, 
                              output_dim = embedding_size,
                              embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights),
                              )(item)
    week_item_embedding1 = Dot(name = 'week_item_embedding1', axes = 2)([week_item_embedding, week_embedding])
    week_item_embedding2 = Reshape(target_shape = (1, ))(week_item_embedding1)
    x = keras.layers.add([item_pop,
                          user_item_embedding, 
                          user_item_price_embedding2,  
                          week_item_embedding2, 
                          item_rest_basket_embedding1, 
                          user_subcategory_discount_embedding2,
                          user_subcategory_discount_diff_embedding2
                          ]) 
    out = Dense(1, activation = 'sigmoid', name = 'output')(x)
    model = Model(inputs = [
                            user, 
                            item, 
                            price, 
                            week,
                            subcategory, 
                            discount, 
                            diffs ,
                            other_prods], outputs = out)         
    model.compile( optimizer=keras.optimizers.Adam(learning_rate=param['lr']), loss = 'binary_crossentropy',
                  metrics = ['AUC', keras.metrics.BinaryAccuracy()])  
    return model

# %%
param_grid = {
    'lr': [1e-3, 5e-4, 1e-4, 5e-5, 1e-5],
    'epochs': 200, 
    'batch_size': [512, 1024, 2048]
}
early = EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)
kgs = KerasRandomSearch(get_model, param_grid, monitor='val_binary_accuracy', greater_is_better=True, n_iter=15)

# %%
kgs.search({'user': df_train['user_id'], 
                     'item': df_train['product_id'], 
                     'price': df_train['price'], 
                     'week': df_train['week'], 
                     'subcategory': df_train['subcategory_name'], 
                     'discount': df_train['discount'], 
                     'diffs': df_train['diffs'], 
                     'other_prods': tf.convert_to_tensor(df_train['other_prods_in_basket'].tolist())},
          {'output': df_train['bought']},
           validation_data=
          (
              {'user': df_test['user_id'], 
               'item': df_test['product_id'], 
               'price': df_test['price'], 
               'week': df_test['week'], 
               'subcategory': df_test['subcategory_name'], 
               'discount': df_test['discount'],                
               'diffs': df_test['diffs'], 
               'other_prods': tf.convert_to_tensor(df_test['other_prods_in_basket'].tolist())},
          {'output': df_test['bought']}), callbacks=[early]
          )
# Out:
# 15 trials detected for ('lr', 'epochs', 'batch_size')
#
# ***** (1/15) *****
# Search({'lr': 1e-05, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.65367 at epoch 25
#
# ***** (2/15) *****
# Search({'lr': 0.001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.75372 at epoch 2
#
# ***** (3/15) *****
# Search({'lr': 0.0005, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.75334 at epoch 4
#
# ***** (4/15) *****
# Search({'lr': 1e-05, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.73923 at epoch 168
#
# ***** (5/15) *****
# Search({'lr': 5e-05, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.74716 at epoch 59
#
# ***** (6/15) *****
# Search({'lr': 0.001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75139 at epoch 5
#
# ***** (7/15) *****
# Search({'lr': 0.0001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.75038 at epoch 29
#
# ***** (8/15) *****
# Search({'lr': 0.0001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75347 at epoch 40
#
# ***** (9/15) *****
# Search({'lr': 5e-05, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.75006 at epoch 36
#
# ***** (10/15) *****
# Search({'lr': 5e-05, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75095 at epoch 83
#
# ***** (11/15) *****
# Search({'lr': 0.0001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.75372 at epoch 23
#
# ***** (12/15) *****
# Search({'lr': 0.0005, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.75479 at epoch 8
#
# ***** (13/15) *****
# Search({'lr': 1e-05, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.74773 at epoch 149
#
# ***** (14/15) *****
# Search({'lr': 0.001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.75838 at epoch 4
#
# ***** (15/15) *****
# Search({'lr': 0.0005, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75347 at epoch 13

# %% [markdown]
# ## Recall@N

# %%
all_users = df[df['data_split'] == 'test']['user_id'].unique().tolist()
recall_matrix = np.zeros(shape=(len(all_users),2))
recall_matrix_weighted = np.zeros(shape=(len(all_users),2))
df['day'] = df['day'].astype('int')
df['user_id'] = df['user_id'].astype('int')
df['product_id'] = df['product_id'].astype('int')
df['week'] = df['week'].astype('int')

# %%
for user_id in all_users:
  max_date = max(df[df['user_id'] == user_id]['day'])
  df_test = df[(df['user_id'] == user_id) & (df['day'] == max_date)]
  actual_basket = df_test[df_test['user_id'] == user_id].head(1)['basket']
  df_test = df_test[['day', 'week', 'product_id', 'subcategory_name', 'category_name', 'price', 'discount', 'diffs', 'other_prods_in_basket', 'bought', 'sample_weight']]
  considered_products = df_test['product_id'].unique().tolist()

  df_test_max_others = df[(df['day'] == max_date) & (df['bought'] == 1) & (df['user_id'] != user_id)]
  df_test_max_others = df_test_max_others.groupby(['day', 'week', 'product_id', 'subcategory_name', 'category_name'], as_index=False).aggregate({
        'price' : 'first',
        'discount': 'first',
        'diffs' : 'first',
    })
  df_test_max_others = df_test_max_others[~df_test_max_others['product_id'].isin(considered_products)]
  df_test_max_others['other_prods_in_basket'] = df_test_max_others.product_id.apply(lambda x: actual_basket)
  df_test_max_others['bought'] = 0

  #append two datasets
  df_test = df_test.append(df_test_max_others)
  df_test['user_id'] = user_id

  predictions = model.predict(
                {'user': df_test['user_id'], 
                'item': df_test['product_id'], 
                'price': df_test['price'], 
                'week': df_test['week'], 
                'subcategory': df_test['subcategory_name'], 
                'discount': df_test['discount'],                
                'diffs': df_test['diffs'], 
                'other_prods': tf.convert_to_tensor(df_test['other_prods_in_basket'].tolist())}
            )
  df_test['ypred_proba'] = predictions
  df_test['sample_weight_for_only_bought'] = np.where(df_test['bought'] == 1, df_test['sample_weight'], 0)
  df_test['norm_weight'] = df_test['sample_weight_for_only_bought'] / df_test.groupby('day')['sample_weight_for_only_bought'].transform('sum')
  df_test['norm_weight'] = df_test['norm_weight'] * df_test.groupby('day')['bought'].transform('sum')

  recall_matrix_weighted[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['norm_weight'].sum() / df_test['bought'].sum()) * 100])

  recall_matrix[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['bought'].sum() / df_test['bought'].sum()) * 100])

# %%
pd.DataFrame(recall_matrix)[1].mean() # recall@n
# Out:
# 26.56528336823728

# %%
pd.DataFrame(recall_matrix_weighted)[1].mean() #recall@n weighted
# Out:
# 21.753004708689158

# %% [markdown]
# # Wide and Deep Model

# %%
product_wide_train = np.asarray(df_train['product_id'].tolist())
user_wide_train = np.asarray(df_train['user_id'].tolist())

product_wide_test = np.asarray(df_test['product_id'].tolist())
user_wide_test = np.asarray(df_test['user_id'].tolist())

# %% [markdown]
# ## Wide model

# %%
products = Input((1,), dtype='int32')
product_onehot = Lambda(lambda x: tf.one_hot(x[:,0], item_len))(products)
users = Input((1,), dtype='int32')
user_onehot = Lambda(lambda x: tf.one_hot(x[:,0], user_len))(users)
x = concatenate([product_onehot, user_onehot], axis=-1)
predictions = Dense(1, activation = 'sigmoid')(x)
wide_model = Model(inputs=[products, users], outputs=predictions)
wide_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001), metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.BinaryAccuracy()])

wide_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 11904)        0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1000)         0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12904)        0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            12905       concatenate[0][0]
# ==================================================================================================
# Total params: 12,905
# Trainable params: 12,905
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Deep model

# %%
discount = tf.keras.Input(shape=(1,), name = 'discount')
price = tf.keras.Input(shape=(1,), name = 'price')
diffs = tf.keras.Input(shape=(1,), name = 'diffs')

week = tf.keras.Input(shape=(1,), name = 'week')
embedding_week = tf.keras.layers.Embedding(week_len + 1, embedding_size,   input_length=1)(week)
embedding_week = tf.keras.layers.Flatten()(embedding_week)

subcategory_name = tf.keras.Input(shape=(1,), name = 'subcategory_name')
embedding_subcategory_name = tf.keras.layers.Embedding(sub_len, embedding_size,   input_length=1)(subcategory_name)
embedding_subcategory_name = tf.keras.layers.Flatten()(embedding_subcategory_name)

users_deep = tf.keras.Input(shape=(1,), name = 'users_deep')
embedding_users_deep = tf.keras.layers.Embedding(user_len, embedding_size,   input_length=1,  
                                 embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights), trainable=True
                                 )(users_deep)
embedding_users_deep = tf.keras.layers.Flatten()(embedding_users_deep)

products_deep = tf.keras.Input(shape=(1,), name = 'products_deep')
embedding_products_deep = tf.keras.layers.Embedding(item_len, embedding_size, input_length=1, 
                                    embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products), trainable=True
                                    )(products_deep)
embedding_products_deep2 = tf.keras.layers.Flatten()(embedding_products_deep)

merged_layer_deep = tf.keras.layers.concatenate([discount, price, diffs, embedding_week, embedding_subcategory_name, 
                                 embedding_users_deep, embedding_products_deep2
                                 ])

merged_layer_deep = tf.keras.layers.Dense(256, activation='relu')(merged_layer_deep)
embed_out = tf.keras.layers.Dense(1, activation='sigmoid')(merged_layer_deep)
deep_model = tf.keras.Model(inputs=[discount, price, diffs, week, subcategory_name, 
                           users_deep, products_deep
                           ], outputs=embed_out)
deep_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001), metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.BinaryAccuracy()])

# %%
deep_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# week (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# subcategory_name (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# users_deep (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# products_deep (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 1, 100)       5500        week[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 1, 100)       63400       subcategory_name[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 1, 100)       100000      users_deep[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 1, 100)       1190400     products_deep[0][0]
# __________________________________________________________________________________________________
# discount (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# price (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# diffs (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           embedding[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100)          0           embedding_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 100)          0           embedding_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 100)          0           embedding_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 403)          0           discount[0][0]
#                                                                  price[0][0]
#                                                                  diffs[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          103424      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            257         dense_1[0][0]
# ==================================================================================================
# Total params: 1,462,981
# Trainable params: 1,462,981
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Wide and Deep combined

# %%
merged_out = tf.keras.layers.concatenate([wide_model.output, deep_model.output])
merged_out = tf.keras.layers.Dense(1, activation='sigmoid')(merged_out)
combined_model = tf.keras.Model(wide_model.inputs + [deep_model.inputs], merged_out)
combined_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.001), metrics=['AUC', tf.keras.metrics.BinaryAccuracy()])

# %%
early = tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)
## Training
combined_model.fit([product_wide_train, user_wide_train] + 
                   [df_train['discount'], df_train['price'], df_train['diffs'],
                    df_train['week'], df_train['subcategory_name'], 
                    df_train['user_id'], df_train['product_id']], df_train['bought'],
                   validation_data=([product_wide_test, user_wide_test] + 
                                    [df_test['discount'], df_test['price'], df_test['diffs'],
                                     df_test['week'], df_test['subcategory_name'] , 
                                     df_test['user_id'], df_test['product_id']], df_test['bought']),
                   epochs=200, 
                   batch_size=512,
                   callbacks=[early],
                   )
# Out:
# Epoch 1/200
# 2352/2352 [==============================] - 34s 14ms/step - loss: 0.6118 - auc: 0.7276 - binary_accuracy: 0.6696 - val_loss: 0.5835 - val_auc: 0.7647 - val_binary_accuracy: 0.6966
# Epoch 2/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.5253 - auc: 0.8208 - binary_accuracy: 0.7457 - val_loss: 0.5625 - val_auc: 0.7860 - val_binary_accuracy: 0.7142
# Epoch 3/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.4896 - auc: 0.8462 - binary_accuracy: 0.7703 - val_loss: 0.5516 - val_auc: 0.7975 - val_binary_accuracy: 0.7252
# Epoch 4/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.4666 - auc: 0.8614 - binary_accuracy: 0.7860 - val_loss: 0.5478 - val_auc: 0.8037 - val_binary_accuracy: 0.7322
# Epoch 5/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.4450 - auc: 0.8750 - binary_accuracy: 0.8003 - val_loss: 0.5455 - val_auc: 0.8082 - val_binary_accuracy: 0.7347
# Epoch 6/200
# 2352/2352 [==============================] - 29s 12ms/step - loss: 0.4262 - auc: 0.8860 - binary_accuracy: 0.8120 - val_loss: 0.5421 - val_auc: 0.8136 - val_binary_accuracy: 0.7395
# Epoch 7/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.4088 - auc: 0.8956 - binary_accuracy: 0.8232 - val_loss: 0.5482 - val_auc: 0.8141 - val_binary_accuracy: 0.7390
# Epoch 8/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.3924 - auc: 0.9040 - binary_accuracy: 0.8332 - val_loss: 0.5451 - val_auc: 0.8186 - val_binary_accuracy: 0.7440
# Epoch 9/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.3775 - auc: 0.9113 - binary_accuracy: 0.8419 - val_loss: 0.5480 - val_auc: 0.8206 - val_binary_accuracy: 0.7473
# Epoch 10/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.3628 - auc: 0.9181 - binary_accuracy: 0.8511 - val_loss: 0.5484 - val_auc: 0.8232 - val_binary_accuracy: 0.7499
# Epoch 11/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.3490 - auc: 0.9240 - binary_accuracy: 0.8588 - val_loss: 0.5591 - val_auc: 0.8210 - val_binary_accuracy: 0.7491
# Epoch 12/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.3369 - auc: 0.9289 - binary_accuracy: 0.8656 - val_loss: 0.5706 - val_auc: 0.8202 - val_binary_accuracy: 0.7488
# Epoch 13/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.3246 - auc: 0.9338 - binary_accuracy: 0.8726 - val_loss: 0.5688 - val_auc: 0.8223 - val_binary_accuracy: 0.7478
# Epoch 14/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.3136 - auc: 0.9379 - binary_accuracy: 0.8785 - val_loss: 0.5771 - val_auc: 0.8214 - val_binary_accuracy: 0.7506
# Epoch 15/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.3027 - auc: 0.9417 - binary_accuracy: 0.8848 - val_loss: 0.5834 - val_auc: 0.8213 - val_binary_accuracy: 0.7494
# Epoch 16/200
# 2352/2352 [==============================] - 28s 12ms/step - loss: 0.2932 - auc: 0.9449 - binary_accuracy: 0.8898 - val_loss: 0.5899 - val_auc: 0.8222 - val_binary_accuracy: 0.7514
# Epoch 17/200
# 2352/2352 [==============================] - 29s 12ms/step - loss: 0.2820 - auc: 0.9487 - binary_accuracy: 0.8954 - val_loss: 0.6008 - val_auc: 0.8204 - val_binary_accuracy: 0.7484
# Epoch 18/200
# 2352/2352 [==============================] - 27s 12ms/step - loss: 0.2745 - auc: 0.9509 - binary_accuracy: 0.8997 - val_loss: 0.6045 - val_auc: 0.8210 - val_binary_accuracy: 0.7513
# Epoch 19/200
# 2352/2352 [==============================] - 29s 12ms/step - loss: 0.2663 - auc: 0.9534 - binary_accuracy: 0.9036 - val_loss: 0.6117 - val_auc: 0.8210 - val_binary_accuracy: 0.7498
# Epoch 20/200
# 2352/2352 [==============================] - 35s 15ms/step - loss: 0.2568 - auc: 0.9561 - binary_accuracy: 0.9088 - val_loss: 0.6215 - val_auc: 0.8195 - val_binary_accuracy: 0.7499
# Epoch 21/200
# 2352/2352 [==============================] - 30s 13ms/step - loss: 0.2500 - auc: 0.9580 - binary_accuracy: 0.9120 - val_loss: 0.6356 - val_auc: 0.8177 - val_binary_accuracy: 0.7492

# %% [markdown]
# ## Grid search

# %%
def get_model(param):

    # wide model
    products = Input((1,), dtype='int32')
    product_onehot = Lambda(lambda x: tf.one_hot(x[:,0], item_len))(products)
    users = Input((1,), dtype='int32')
    user_onehot = Lambda(lambda x: tf.one_hot(x[:,0], user_len))(users)

    x = concatenate([product_onehot, user_onehot], axis=-1)
    predictions = Dense(1, activation = 'sigmoid')(x)
    wide_model = Model(inputs=[products, users], outputs=predictions)
    wide_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(
        learning_rate=param['wide_lr']), metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.BinaryAccuracy()])


    # deep model
    discount = tf.keras.Input(shape=(1,), name = 'discount')
    price = tf.keras.Input(shape=(1,), name = 'price')
    diffs = tf.keras.Input(shape=(1,), name = 'diffs')

    week = tf.keras.Input(shape=(1,), name = 'week')
    embedding_week = tf.keras.layers.Embedding(week_len + 1, embedding_size,   input_length=1)(week)
    embedding_week = tf.keras.layers.Flatten()(embedding_week)

    subcategory_name = tf.keras.Input(shape=(1,), name = 'subcategory_name')
    embedding_subcategory_name = tf.keras.layers.Embedding(sub_len, embedding_size,   input_length=1)(subcategory_name)
    embedding_subcategory_name = tf.keras.layers.Flatten()(embedding_subcategory_name)

    users_deep = tf.keras.Input(shape=(1,), name = 'users_deep')
    embedding_users_deep = tf.keras.layers.Embedding(user_len, embedding_size,   input_length=1,  
                                    # embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights)
                                    )(users_deep)
    embedding_users_deep = tf.keras.layers.Flatten()(embedding_users_deep)

    products_deep = tf.keras.Input(shape=(1,), name = 'products_deep')
    embedding_products_deep = tf.keras.layers.Embedding(item_len, embedding_size, input_length=1, 
                                      #  embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights)
                                        )(products_deep)
    embedding_products_deep2 = tf.keras.layers.Flatten()(embedding_products_deep)

    merged_layer_deep = tf.keras.layers.concatenate([discount, price, diffs, embedding_week, embedding_subcategory_name, 
                                    embedding_users_deep, embedding_products_deep2
                                    ])

    merged_layer_deep = tf.keras.layers.Dense(256, activation='relu')(merged_layer_deep)
    embed_out = tf.keras.layers.Dense(1, activation='sigmoid')(merged_layer_deep)
    deep_model = tf.keras.Model(inputs=[discount, price, diffs, week, subcategory_name, 
                              users_deep, products_deep
                              ], outputs=embed_out)
    deep_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(
        learning_rate=param['deep_lr']), metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.BinaryAccuracy()])

    # merged model
    merged_out = tf.keras.layers.concatenate([wide_model.output, deep_model.output])
    merged_out = tf.keras.layers.Dense(1, activation='sigmoid')(merged_out)
    combined_model = tf.keras.Model(wide_model.inputs + [deep_model.inputs], merged_out)
    combined_model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(
        learning_rate=param['combined_lr']), metrics=['AUC', tf.keras.metrics.BinaryAccuracy()])

    return combined_model

# %%
param_grid = {
    'wide_lr': [1e-3, 1e-4, 1e-5], 
    'deep_lr': [1e-3, 1e-4, 1e-5],
    'combined_lr': [1e-1, 1e-2, 1e-3, 1e-4], 
    'epochs': 100, 
    'batch_size': [512, 1024, 2048]
}
early = tf.keras.callbacks.EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)
kgs = KerasRandomSearch(get_model, param_grid, monitor='val_binary_accuracy', greater_is_better=True, n_iter=18)

# %%
kgs.search([product_wide_train, user_wide_train] + 
                   [df_train['discount'], df_train['price'], df_train['diffs'],
                    df_train['week'], df_train['subcategory_name'], 
                    df_train['user_id'], df_train['product_id']], df_train['bought'],
                   validation_data=([product_wide_test, user_wide_test] + 
                                    [df_test['discount'], df_test['price'], df_test['diffs'],
                                     df_test['week'], df_test['subcategory_name'] , 
                                     df_test['user_id'], df_test['product_id']], df_test['bought'])
           , callbacks=[early])

# best params :Search({'wide_lr': 0.0001, 'deep_lr': 0.0001, 'combined_lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Out:
# 18 trials detected for ('wide_lr', 'deep_lr', 'combined_lr', 'epochs', 'batch_size')
#
# ***** (1/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 0.0001, 'combined_lr': 0.0001, 'epochs': 100, 'batch_size': 2048})
# SCORE: 0.66935 at epoch 42
#
# ***** (2/18) *****
# Search({'wide_lr': 0.001, 'deep_lr': 1e-05, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.66828 at epoch 32
#
# ***** (3/18) *****
# Search({'wide_lr': 0.001, 'deep_lr': 0.001, 'combined_lr': 0.01, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.65171 at epoch 9
#
# ***** (4/18) *****
# Search({'wide_lr': 0.001, 'deep_lr': 0.001, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 1024})
# SCORE: 0.66734 at epoch 20
#
# ***** (5/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 1e-05, 'combined_lr': 0.01, 'epochs': 100, 'batch_size': 2048})
# SCORE: 0.70086 at epoch 21
#
# ***** (6/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 0.001, 'combined_lr': 0.01, 'epochs': 100, 'batch_size': 2048})
# SCORE: 0.73204 at epoch 16
#
# ***** (7/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 0.0001, 'combined_lr': 0.0001, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.7294 at epoch 70
#
# ***** (8/18) *****
# Search({'wide_lr': 0.0001, 'deep_lr': 0.001, 'combined_lr': 0.0001, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.66186 at epoch 7
#
# ***** (9/18) *****
# Search({'wide_lr': 0.0001, 'deep_lr': 0.0001, 'combined_lr': 0.001, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.74723 at epoch 17
#
# ***** (10/18) *****
# Search({'wide_lr': 0.0001, 'deep_lr': 0.001, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.66904 at epoch 17
#
# ***** (11/18) *****
# Search({'wide_lr': 0.001, 'deep_lr': 1e-05, 'combined_lr': 0.001, 'epochs': 100, 'batch_size': 2048})
# SCORE: 0.73664 at epoch 28
#
# ***** (12/18) *****
# Search({'wide_lr': 0.0001, 'deep_lr': 0.0001, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.6652 at epoch 13
#
# ***** (13/18) *****
# Search({'wide_lr': 0.001, 'deep_lr': 0.001, 'combined_lr': 0.0001, 'epochs': 100, 'batch_size': 1024})
# SCORE: 0.63678 at epoch 7
#
# ***** (14/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 0.001, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 2048})
# SCORE: 0.66457 at epoch 28
#
# ***** (15/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 0.0001, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.66683 at epoch 11
#
# ***** (16/18) *****
# Search({'wide_lr': 0.0001, 'deep_lr': 0.001, 'combined_lr': 0.1, 'epochs': 100, 'batch_size': 2048})
# SCORE: 0.66299 at epoch 20
#
# ***** (17/18) *****
# Search({'wide_lr': 1e-05, 'deep_lr': 1e-05, 'combined_lr': 0.0001, 'epochs': 100, 'batch_size': 512})
# SCORE: 0.74042 at epoch 66
#
# ***** (18/18) *****
# Search({'wide_lr': 0.001, 'deep_lr': 0.001, 'combined_lr': 0.001, 'epochs': 100, 'batch_size': 1024})
# SCORE: 0.74105 at epoch 27

# %% [markdown]
# ## Evaluation

# %%
predictions = combined_model.predict([product_wide_test, user_wide_test] + 
                                    [df_test['discount'], df_test['price'], df_test['diffs'],
                                     df_test['week'], df_test['subcategory_name'] , 
                                     df_test['user_id'], df_test['product_id']])
df_test['pred_proba']  = predictions
predictions_x = np.where(predictions > 0.5, 1, 0)

# %%
fpr, tpr, _ = metrics.roc_curve(df_test['bought'],  df_test['pred_proba'])
auc = metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'])
print(auc)
plt.plot(fpr,tpr,label="wdl, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.7505135387488328

# %%
sklearn.metrics.classification_report(df_test['bought'], predictions_x, output_dict=True)
# Out:
# {'0': {'f1-score': 0.741834850703508,
#   'precision': 0.7497104619740059,
#   'recall': 0.7341229838709677,
#   'support': 7936},
#  '1': {'f1-score': 0.7471472220490116,
#   'precision': 0.7395383286014072,
#   'recall': 0.754914314516129,
#   'support': 7936},
#  'accuracy': 0.7445186491935484,
#  'macro avg': {'f1-score': 0.7444910363762598,
#   'precision': 0.7446243952877065,
#   'recall': 0.7445186491935484,
#   'support': 15872},
#  'weighted avg': {'f1-score': 0.7444910363762598,
#   'precision': 0.7446243952877066,
#   'recall': 0.7445186491935484,
#   'support': 15872}}

# %%
#weighted AUC
fpr, tpr, _ = metrics.roc_curve(df_test['bought'],  df_test['pred_proba'], sample_weight=df_test['sample_weight'])
auc = metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'] , sample_weight=df_test['sample_weight'])
print(auc)
plt.plot(fpr,tpr,label="wdl, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
#weighted accuracy
sklearn.metrics.classification_report(df_test['bought'], predictions_x, sample_weight= df_test['sample_weight'], output_dict=True)
# Out:
# {'0': {'f1-score': 0.48966491182352445,
#   'precision': 0.4017866659059972,
#   'recall': 0.6267459545683881,
#   'support': 233.8311516399456},
#  '1': {'f1-score': 0.686021188219189,
#   'precision': 0.7926890618291674,
#   'recall': 0.6046559165287,
#   'support': 551.9239419021508},
#  'accuracy': 0.611229642969727,
#  'macro avg': {'f1-score': 0.5878430500213567,
#   'precision': 0.5972378638675824,
#   'recall': 0.6157009355485441,
#   'support': 785.7550935420963},
#  'weighted avg': {'f1-score': 0.6275879504092329,
#   'precision': 0.6763612668600192,
#   'recall': 0.6112296429697285,
#   'support': 785.7550935420963}}

# %% [markdown]
# ## Recall@N

# %%
all_users = df[df['data_split'] == 'test']['user_id'].unique().tolist()
recall_matrix = np.zeros(shape=(len(all_users),2))
recall_matrix_weighted = np.zeros(shape=(len(all_users),2))
df['day'] = df['day'].astype('int')
df['user_id'] = df['user_id'].astype('int')
df['product_id'] = df['product_id'].astype('int')
for user_id in all_users:
  max_date = max(df[df['user_id'] == user_id]['day'])
  df_test = df[(df['user_id'] == user_id) & (df['bought'] == 1) & (df['day'] == max_date)]
  df_test = df_test[['day', 'week', 'product_id', 'subcategory_name', 'category_name', 'price', 'discount', 'diffs', 'bought', 'data_split', 'sample_weight']]
  bought_products = df_test['product_id'].unique()
  df_day = df[(df['day'] == max_date) & (df['bought'] == 1) & (df['user_id'] != user_id)]
  df_day = df_day.groupby(['day', 'week', 'product_id', 'subcategory_name', 'category_name'], as_index=False).aggregate({
      'price' : 'first',
      'discount': 'first',
      'diffs' : 'first',
  })
  df_day = df_day.loc[~df_day['product_id'].isin(bought_products)]
  df_day['bought'] = 0
  df_day['data_split'] = 'test'
  df_test = df_test.append(df_day)
  df_test['user_id'] = user_id
  product_wide_test = np.asarray(df_test['product_id'].tolist())
  user_wide_test = np.asarray(df_test['user_id'].tolist())
  df_test['week'] = df_test['week'].astype('int')

  df_test['product_id'] = df_test['product_id'].astype('int')
  predictions = combined_model.predict([product_wide_test, user_wide_test] + [df_test['discount'], df_test['price'], df_test['diffs'], df_test['week'], df_test['subcategory_name'] , df_test['user_id'], df_test['product_id']])
  df_test['ypred_proba'] = predictions
  df_test['sample_weight_for_only_bought'] = np.where(df_test['bought'] == 1, df_test['sample_weight'], 0)
  df_test['norm_weight'] = df_test['sample_weight_for_only_bought'] / df_test.groupby('day')['sample_weight_for_only_bought'].transform('sum')
  df_test['norm_weight'] = df_test['norm_weight'] * df_test.groupby('day')['bought'].transform('sum')

  recall_matrix_weighted[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['norm_weight'].sum() / df_test['bought'].sum()) * 100])
  recall_matrix[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['bought'].sum() / df_test['bought'].sum()) * 100])

# %%
pd.DataFrame(recall_matrix)[1].mean() # recall@n
# Out:
# 17.673753671191776

# %%
pd.DataFrame(recall_matrix_weighted)[1].mean() #recall@n weighted
# Out:
# 12.617562447155448

# %% [markdown]
# # LSTM

# %% [markdown]
# ### Model

# %%
x_train = np.stack((df_train['30_day_purchase_history']) , axis=0 )
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_test = np.stack((df_test['30_day_purchase_history']) , axis=0 )
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))

features = x_train.shape[2]

# %%
#multiple input model
discount = Input(shape=(1,), name='discount')
price = Input(shape=(1,), name='price')
diffs = Input(shape=(1,), name='diffs')

product = Input(shape = (1,), name='product')
product_emb = Embedding(name = 'product_emb', input_dim = item_len, output_dim = 100,
                          #embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                          #trainable=True
                        )(product)
product_emb = Flatten()(product_emb)

user = Input(shape = (1,), name='user')
user_emb = Embedding(name = 'user_emb',  input_dim = user_len,  output_dim = 100,
                          #embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                          #trainable=True
                     )(user)
user_emb = Flatten()(user_emb)

week = Input(shape = (1,), name='week')
week_emb = Embedding(name = 'week_emb', input_dim = week_len, output_dim = 100)(week)
week_emb = Flatten()(week_emb)

subcategory = Input(shape=(1,), name='subcategory')
subcategory_emb = Embedding(name = 'subcategory_emb', input_dim = subcat_len, output_dim = 100)(subcategory)
subcategory_emb = Flatten()(subcategory_emb)


purchase_history = Input(shape=(1,30), name='purchase_history')
lstm_out = LSTM(128, input_dim=features, #return_sequences=True,
)(purchase_history)                                        


x = concatenate([
                 discount, 
                 price, 
                 diffs, 
                 product_emb, user_emb, week_emb, subcategory_emb, 
                 lstm_out,
                 ])

x = Dense(units=256, activation='relu')(x)
x = Dense(units=1, activation='sigmoid')(x)
model = Model(inputs=[
                     discount, 
                     price, 
                     diffs, 
                     product, user, week, subcategory, 
                     purchase_history,
                      ], outputs=[x])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# product (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# user (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# week (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# subcategory (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# product_emb (Embedding)         (None, 1, 100)       1190400     product[0][0]
# __________________________________________________________________________________________________
# user_emb (Embedding)            (None, 1, 100)       100000      user[0][0]
# __________________________________________________________________________________________________
# week_emb (Embedding)            (None, 1, 100)       5400        week[0][0]
# __________________________________________________________________________________________________
# subcategory_emb (Embedding)     (None, 1, 100)       63400       subcategory[0][0]
# __________________________________________________________________________________________________
# purchase_history (InputLayer)   [(None, 1, 30)]      0
# __________________________________________________________________________________________________
# discount (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# price (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# diffs (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           product_emb[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100)          0           user_emb[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 100)          0           week_emb[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 100)          0           subcategory_emb[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 256)          162816      purchase_history[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 659)          0           discount[0][0]
#                                                                  price[0][0]
#                                                                  diffs[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          168960      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            257         dense[0][0]
# ==================================================================================================
# Total params: 1,691,233
# Trainable params: 1,691,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
                  optimizer=keras.optimizers.Adam(lr=0.001),
                  metrics=['AUC', keras.metrics.BinaryAccuracy()])

early = EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)

model.fit([
                     df_train['discount'],
                     df_train['price'], 
                     df_train['diffs'], 
                     df_train['product_id'], df_train['user_id'],
                     df_train['week'],  df_train['subcategory_name']
                     ,x_train
                     ],
                    df_train['bought'],

                    validation_data= ([
                    df_test['discount'],
                    df_test['price'], 
                    df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name']
                     ,x_test
                     ],
                    df_test['bought'],), 
                    batch_size=512, epochs=200, callbacks=[early]
                    )

# %% [markdown]
# ## Evaluation

# %%
predictions = model.predict([
                             df_test['discount'],
                             df_test['price'], 
                             df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name']
                     ,x_test
                     ])
df_test['pred_proba']  = predictions
predictions_x = np.where(predictions > 0.5, 1, 0)
df_test['pred'] = predictions_x
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
fpr, tpr, _ = sklearn.metrics.roc_curve(df_test['bought'],  df_test['pred_proba'])
auc = sklearn.metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'])
print(auc)
plt.plot(fpr,tpr,label="lstm, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.8680102959556942

# %%
sklearn.metrics.classification_report(df_test['bought'], predictions_x, output_dict=True)
# Out:
# {'0': {'f1-score': 0.7926200089726335,
#   'precision': 0.7858334259979984,
#   'recall': 0.7995248331259193,
#   'support': 8839},
#  '1': {'f1-score': 0.7864649497632521,
#   'precision': 0.793521323700769,
#   'recall': 0.779532967032967,
#   'support': 8736},
#  'accuracy': 0.7895874822190612,
#  'macro avg': {'f1-score': 0.7895424793679429,
#   'precision': 0.7896773748493837,
#   'recall': 0.7895289000794432,
#   'support': 17575},
#  'weighted avg': {'f1-score': 0.7895605155300641,
#   'precision': 0.7896548470125876,
#   'recall': 0.7895874822190612,
#   'support': 17575}}

# %%
# weighted AUC
fpr, tpr, _ = sklearn.metrics.roc_curve(df_test['bought'],  df_test['pred_proba'], sample_weight=df_test['sample_weight'])
auc = sklearn.metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'], sample_weight=df_test['sample_weight'])
print(auc)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.6892696269941974

# %%
# weighted accuracy
sklearn.metrics.classification_report(df_test['bought'], df_test['pred'], sample_weight= df_test['sample_weight'], output_dict=True)
# Out:
# {'0': {'f1-score': 0.5045292083595184,
#   'precision': 0.4211186732242254,
#   'recall': 0.6291428806826029,
#   'support': 253.49742609207104},
#  '1': {'f1-score': 0.7054964957255869,
#   'precision': 0.7996382722486786,
#   'recall': 0.6311866098317453,
#   'support': 594.4306599106659},
#  'accuracy': 0.6305756145274399,
#  'macro avg': {'f1-score': 0.6050128520425526,
#   'precision': 0.610378472736452,
#   'recall': 0.6301647452571741,
#   'support': 847.9280860027369},
#  'weighted avg': {'f1-score': 0.6454151151026558,
#   'precision': 0.6864756754883302,
#   'recall': 0.6305756145274393,
#   'support': 847.9280860027369}}

# %% [markdown]
# ## Grid search

# %%
def get_model(param):
    discount = Input(shape=(1,), name='discount')
    price = Input(shape=(1,), name='price')
    diffs = Input(shape=(1,), name='diffs')

    product = Input(shape = (1,), name='product')
    product_emb = Embedding(name = 'product_emb', input_dim = item_len, output_dim = 100)(product)
    product_emb = Flatten()(product_emb)

    user = Input(shape = (1,), name='user')
    user_emb = Embedding(name = 'user_emb',  input_dim = user_len,  output_dim = 100)(user)
    user_emb = Flatten()(user_emb)

    week = Input(shape = (1,), name='week')
    week_emb = Embedding(name = 'week_emb', input_dim = week_len, output_dim = 100)(week)
    week_emb = Flatten()(week_emb)

    subcategory = Input(shape=(1,), name='subcategory')
    subcategory_emb = Embedding(name = 'subcategory_emb', input_dim = subcat_len, output_dim = 100)(subcategory)
    subcategory_emb = Flatten()(subcategory_emb)


    purchase_history = Input(shape=(1,30), name='purchase_history')
    lstm_out = Bidirectional(LSTM(units= param['lstm_units'], input_dim=features, #return_sequences=True
                                ))(purchase_history)                         

    x = concatenate([discount, price, diffs, product_emb, user_emb, week_emb, subcategory_emb, lstm_out])

    x = Dense(units=param['dense_units'], activation='relu')(x)
    x = Dense(units=1, activation='sigmoid')(x)
    model = Model(inputs=[discount, price, diffs, product, user, week, subcategory, purchase_history], outputs=[x])
    model.compile(loss='binary_crossentropy',
                      optimizer=keras.optimizers.Adam(learning_rate=param['lr']),
                      metrics=['AUC', keras.metrics.BinaryAccuracy()])     
    
    return model

# %%
param_grid = {
    'dense_units': [256], 
    'lstm_units': [64, 128, 256],
    'lr': [1e-3, 1e-4, 1e-5], 
    'epochs': 200, 
    'batch_size': [512, 1024, 2048]
}
early = EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)
kgs = KerasRandomSearch(get_model, param_grid, monitor='val_binary_accuracy', greater_is_better=True, n_iter=27)
kgs.search([df_train['discount'],df_train['price'], df_train['diffs'], 
                     df_train['product_id'], df_train['user_id'],
                     df_train['week'],  df_train['subcategory_name'],
                     x_train],
                    df_train['bought'],

                    validation_data= ([df_test['discount'],df_test['price'], df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name'],
                     x_test],
                    df_test['bought']), callbacks=[early])
# Out:
# 27 trials detected for ('dense_units', 'lstm_units', 'lr', 'epochs', 'batch_size')
#
# ***** (1/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 0.0001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.77142 at epoch 11
#
# ***** (2/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 1e-05, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.76663 at epoch 39
#
# ***** (3/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 0.001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.78068 at epoch 5
#
# ***** (4/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 1e-05, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.76336 at epoch 69
#
# ***** (5/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 0.001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.77804 at epoch 4
#
# ***** (6/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 0.0001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.77344 at epoch 14
#
# ***** (7/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 0.001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.77526 at epoch 2
#
# ***** (8/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 0.0001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.77319 at epoch 16
#
# ***** (9/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 1e-05, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.76544 at epoch 79
#
# ***** (10/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 0.0001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.7718 at epoch 7
#
# ***** (11/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 0.001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.77709 at epoch 2
#
# ***** (12/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 0.0001, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.77419 at epoch 11
#
# ***** (13/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 0.001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.77816 at epoch 5
#
# ***** (14/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 1e-05, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.76436 at epoch 30
#
# ***** (15/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 0.001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.77577 at epoch 4
#
# ***** (16/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 0.001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.77552 at epoch 3
#
# ***** (17/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 1e-05, 'epochs': 200, 'batch_size': 512})
# SCORE: 0.76714 at epoch 44
#
# ***** (18/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 0.0001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.77369 at epoch 17
#
# ***** (19/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 1e-05, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.76109 at epoch 41
#
# ***** (20/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 0.001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.77596 at epoch 7
#
# ***** (21/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 0.0001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.7752 at epoch 29
#
# ***** (22/27) *****
# Search({'dense_units': 256, 'lstm_units': 64, 'lr': 1e-05, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.76506 at epoch 56
#
# ***** (23/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 0.0001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.77262 at epoch 14
#
# ***** (24/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 1e-05, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.76922 at epoch 66
#
# ***** (25/27) *****
# Search({'dense_units': 256, 'lstm_units': 256, 'lr': 1e-05, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.75869 at epoch 50
#
# ***** (26/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 0.001, 'epochs': 200, 'batch_size': 1024})
# SCORE: 0.77741 at epoch 4
#
# ***** (27/27) *****
# Search({'dense_units': 256, 'lstm_units': 128, 'lr': 0.0001, 'epochs': 200, 'batch_size': 2048})
# SCORE: 0.77274 at epoch 18

# %% [markdown]
# ## Recall@N

# %%
df['user_id'] = df['user_id'].astype('int')
df['product_id'] = df['product_id'].astype('int')
df['week'] = df['week'].astype('int')
df['day'] = df['day'].astype('int')

# %%
all_users = df[df['data_split'] == 'test']['user_id'].unique().tolist()
recall_matrix = np.zeros(shape=(len(all_users),2))
recall_matrix_weighted = np.zeros(shape=(len(all_users),2))

# %%
for user_id in tqdm(all_users):
  max_date = max(df[df['user_id'] == user_id]['day'])

  df_train = df[(df['user_id'] == user_id) & (df['data_split'] == 'train')]
  df_train = df_train[['day', 'week', 'year', 'article_text', 'product_id', 'subcategory_name', 'category_name', 'weekandyear', 'price', 'discount', 'diffs', 'bought', 'data_split']]


  df_test = df[(df['user_id'] == user_id) & (df['bought'] == 1) & (df['day'] == max_date)]
  df_test = df_test[['day', 'week', 'year', 'article_text', 'product_id', 'subcategory_name', 'category_name', 'weekandyear', 'price', 'discount', 'diffs', 'bought', 'data_split', 'sample_weight']]
  bought_products = df_test['product_id'].unique()

  df_day = df[(df['day'] == max_date) & (df['bought'] == 1) & (df['user_id'] != user_id)]
  df_day = df_day.groupby(['day', 'week', 'year', 'article_text', 'product_id', 'subcategory_name', 'category_name', 'weekandyear', 'sample_weight'], as_index=False).aggregate({
      'price' : 'first',
      'discount': 'first',
      'diffs' : 'first',
  })
  df_day = df_day.loc[~df_day['product_id'].isin(bought_products)]
  df_day['bought'] = 0
  df_day['data_split'] = 'test'

  df_test = df_test.append(df_day)

  train = df_train.append(df_test)
  train['user_id'] = user_id


  train['day'] = train['day'].astype('str')

  bought_df = train[train['bought'] == 1]
  purchase_history = bought_df.groupby(['product_id', 'user_id'], as_index=False).aggregate({'day' : 'unique'})
  purchase_history.rename(columns={'day' : 'purchase_history'}, inplace=True)
  # merge with actual df
  train = pd.merge(train, purchase_history, how='left', on=['user_id', 'product_id'])

  user_history = bought_df.groupby(['user_id'], as_index=False).aggregate({'day' : 'unique'})
  user_history.rename(columns={'day' : 'user_history'}, inplace=True)
  user_history['user_history'] = user_history['user_history'].map(lambda x: np.sort(x))
  train = pd.merge(train, user_history, how='left', on=['user_id'])

  train['user_history'] = train['user_history'].map(lambda x: [int(i) for i in x])

  train['user_history'] = train['user_history'].map(lambda x: np.sort(x))

  train['day'] = train['day'].astype('int')

  def get_last_30(seq, value):
      lst = []
      for s in seq:
          if s < value:
              lst.append(s)
      return lst[-30:]

  train['last_30_purchase_days'] = train.apply(lambda x: get_last_30(x.user_history, x.day), axis=1)
  train['purchase_history'] = np.where(train['purchase_history'].isna(), "", train['purchase_history'])
  train['purchase_history'] = train['purchase_history'].map(lambda x: [int(i) for i in x])
  train['purchase_history'] = train['purchase_history'].map(lambda x: np.sort(x))

  train['purchase_history'] = train['purchase_history'].map(lambda x: [str(i) for i in x])
  train['last_30_purchase_days'] = train['last_30_purchase_days'].map(lambda x: [str(i) for i in x])
  train['30_day_purchase_history'] = train.apply(lambda x: [1 if str(i) in x.purchase_history else -1 for i in x.last_30_purchase_days], axis=1)
  padded_window_30 = pad_sequences(train['30_day_purchase_history'],30,padding='pre')
  train['30_day_purchase_history'] = padded_window_30.tolist()

  df_test = train[(train['data_split'] == 'test')]

  x_test = np.stack((df_test['30_day_purchase_history']) , axis=0 )
  x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
  df_test['week'] = df_test['week'].astype('int')

  predictions = model.predict([df_test['discount'],df_test['price'], df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name'],
                     x_test])
  df_test['ypred_proba'] = predictions
  df_test['sample_weight_for_only_bought'] = np.where(df_test['bought'] == 1, df_test['sample_weight'], 0)
  df_test['norm_weight'] = df_test['sample_weight_for_only_bought'] / df_test.groupby('day')['sample_weight_for_only_bought'].transform('sum')
  df_test['norm_weight'] = df_test['norm_weight'] * df_test.groupby('day')['bought'].transform('sum')

  recall_matrix[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['bought'].sum() / df_test['bought'].sum()) * 100])
  recall_matrix_weighted[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['norm_weight'].sum() / df_test['bought'].sum()) * 100])

# %%
pd.DataFrame(recall_matrix)[1].mean()
# Out:
# 38.79851471658365

# %%
pd.DataFrame(recall_matrix_weighted)[1].mean()
# Out:
# 31.836935916899648

# %% [markdown]
# # LSTM w/ Attention

# %% [markdown]
# ## Model

# %%
x_train = np.stack((df_train['30_day_purchase_history']) , axis=0 )
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_test = np.stack((df_test['30_day_purchase_history']) , axis=0 )
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))

# %%
features = x_train.shape[2]

# %%
#multiple input model
discount = Input(shape=(1,), name='discount')
price = Input(shape=(1,), name='price')
diffs = Input(shape=(1,), name='diffs')

product = Input(shape = (1,), name='product')
product_emb = Embedding(name = 'product_emb', input_dim = item_len, output_dim = 100,
                          #embeddings_initializer=tf.keras.initializers.Constant(pretrained_weights_products),
                          #trainable=True
                        )(product)
product_emb = Flatten()(product_emb)

user = Input(shape = (1,), name='user')
user_emb = Embedding(name = 'user_emb',  input_dim = user_len,  output_dim = 100,
                          #embeddings_initializer=tf.keras.initializers.Constant(pretrained_user_weights),
                          #trainable=True
                     )(user)
user_emb = Flatten()(user_emb)

week = Input(shape = (1,), name='week')
week_emb = Embedding(name = 'week_emb', input_dim = week_len, output_dim = 100)(week)
week_emb = Flatten()(week_emb)

subcategory = Input(shape=(1,), name='subcategory')
subcategory_emb = Embedding(name = 'subcategory_emb', input_dim = subcat_len, output_dim = 100)(subcategory)
subcategory_emb = Flatten()(subcategory_emb)


purchase_history = Input(shape=(1,30), name='purchase_history')
lstm_out = LSTM(128, input_dim=features, return_sequences=True, #use_bias=False
                             )(purchase_history)                         
lstm_out = SeqWeightedAttention()(lstm_out)


x = concatenate([
                 discount, 
                 price, 
                 diffs, 
                 product_emb, user_emb, week_emb, subcategory_emb, 
                 lstm_out
                 ])

x = Dense(units=256, activation='relu')(x)
x = Dense(units=1, activation='sigmoid')(x)
model = Model(inputs=[
                     discount, 
                     price, 
                     diffs, 
                     product, user, week, subcategory, 
                     purchase_history
                      ], outputs=[x])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# product (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# user (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# week (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# subcategory (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# purchase_history (InputLayer)   [(None, 1, 30)]      0
# __________________________________________________________________________________________________
# product_emb (Embedding)         (None, 1, 100)       1190400     product[0][0]
# __________________________________________________________________________________________________
# user_emb (Embedding)            (None, 1, 100)       100000      user[0][0]
# __________________________________________________________________________________________________
# week_emb (Embedding)            (None, 1, 100)       5400        week[0][0]
# __________________________________________________________________________________________________
# subcategory_emb (Embedding)     (None, 1, 100)       63400       subcategory[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 1, 128)       81408       purchase_history[0][0]
# __________________________________________________________________________________________________
# discount (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# price (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# diffs (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 100)          0           product_emb[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 100)          0           user_emb[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 100)          0           week_emb[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 100)          0           subcategory_emb[0][0]
# __________________________________________________________________________________________________
# seq_weighted_attention (SeqWeig (None, 128)          129         lstm[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 531)          0           discount[0][0]
#                                                                  price[0][0]
#                                                                  diffs[0][0]
#                                                                  flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  seq_weighted_attention[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          136192      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            257         dense[0][0]
# ==================================================================================================
# Total params: 1,577,186
# Trainable params: 1,577,186
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    model, show_shapes=True, rankdir='LR',
    show_layer_names=True, dpi=120)

# %%
model.compile(loss='binary_crossentropy',
                  optimizer=keras.optimizers.Adam(lr=0.001),
                  metrics=['AUC', keras.metrics.BinaryAccuracy()])

early = EarlyStopping(monitor="val_binary_accuracy", mode="max", patience=5, restore_best_weights=True)

model.fit([
                     df_train['discount'],
                     df_train['price'], 
                     df_train['diffs'], 
                     df_train['product_id'], df_train['user_id'],
                     df_train['week'],  df_train['subcategory_name']
                     ,x_train
                     ],
                    df_train['bought'],

                    validation_data= ([
                    df_test['discount'],
                    df_test['price'], 
                    df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name']
                     ,x_test
                     ],
                    df_test['bought'],), 
                    batch_size=512, epochs=200, callbacks=[early]
                    )
# Out:
# Epoch 1/200
# 2352/2352 [==============================] - 54s 22ms/step - loss: 0.5154 - auc: 0.8149 - binary_accuracy: 0.7376 - val_loss: 0.5066 - val_auc: 0.8421 - val_binary_accuracy: 0.7450
# Epoch 2/200
# 2352/2352 [==============================] - 49s 21ms/step - loss: 0.4318 - auc: 0.8793 - binary_accuracy: 0.7956 - val_loss: 0.4743 - val_auc: 0.8538 - val_binary_accuracy: 0.7728
# Epoch 3/200
# 2352/2352 [==============================] - 49s 21ms/step - loss: 0.4094 - auc: 0.8925 - binary_accuracy: 0.8077 - val_loss: 0.4687 - val_auc: 0.8584 - val_binary_accuracy: 0.7782
# Epoch 4/200
# 2352/2352 [==============================] - 49s 21ms/step - loss: 0.3957 - auc: 0.9001 - binary_accuracy: 0.8157 - val_loss: 0.4692 - val_auc: 0.8614 - val_binary_accuracy: 0.7841
# Epoch 5/200
# 2352/2352 [==============================] - 49s 21ms/step - loss: 0.3830 - auc: 0.9070 - binary_accuracy: 0.8233 - val_loss: 0.4668 - val_auc: 0.8625 - val_binary_accuracy: 0.7808
# Epoch 6/200
# 2352/2352 [==============================] - 49s 21ms/step - loss: 0.3718 - auc: 0.9128 - binary_accuracy: 0.8300 - val_loss: 0.4701 - val_auc: 0.8627 - val_binary_accuracy: 0.7789
# Epoch 7/200
# 2352/2352 [==============================] - 50s 21ms/step - loss: 0.3601 - auc: 0.9185 - binary_accuracy: 0.8358 - val_loss: 0.4709 - val_auc: 0.8646 - val_binary_accuracy: 0.7840
# Epoch 8/200
# 2352/2352 [==============================] - 51s 21ms/step - loss: 0.3482 - auc: 0.9242 - binary_accuracy: 0.8426 - val_loss: 0.4862 - val_auc: 0.8631 - val_binary_accuracy: 0.7703
# Epoch 9/200
# 2352/2352 [==============================] - 50s 21ms/step - loss: 0.3378 - auc: 0.9289 - binary_accuracy: 0.8485 - val_loss: 0.4756 - val_auc: 0.8643 - val_binary_accuracy: 0.7836

# %% [markdown]
# ## Evaluation

# %%
predictions = model.predict([
                             df_test['discount'],
                             df_test['price'], 
                             df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name']
                     ,x_test
                     ])
df_test['pred_proba']  = predictions
predictions_x = np.where(predictions > 0.5, 1, 0)
df_test['pred'] = predictions_x

# %%
fpr, tpr, _ = sklearn.metrics.roc_curve(df_test['bought'],  df_test['pred_proba'])
auc = sklearn.metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'])
print(auc)
plt.plot(fpr,tpr,label="lstm, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.8613819594685914

# %%
sklearn.metrics.classification_report(df_test['bought'], predictions_x, output_dict=True)
# Out:
# {'0': {'f1-score': 0.7939885782987677,
#   'precision': 0.7591677204276354,
#   'recall': 0.8321572580645161,
#   'support': 7936},
#  '1': {'f1-score': 0.7731815474220662,
#   'precision': 0.8143036386449184,
#   'recall': 0.7360131048387096,
#   'support': 7936},
#  'accuracy': 0.7840851814516129,
#  'macro avg': {'f1-score': 0.783585062860417,
#   'precision': 0.7867356795362769,
#   'recall': 0.7840851814516129,
#   'support': 15872},
#  'weighted avg': {'f1-score': 0.7835850628604171,
#   'precision': 0.786735679536277,
#   'recall': 0.7840851814516129,
#   'support': 15872}}

# %%
# weighted AUC
fpr, tpr, _ = sklearn.metrics.roc_curve(df_test['bought'],  df_test['pred_proba'], sample_weight=df_test['sample_weight'])
auc = sklearn.metrics.roc_auc_score(df_test['bought'], df_test['pred_proba'], sample_weight=df_test['sample_weight'])
print(auc)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
# Out:
# 0.6417747679008183

# %%
#weighted accuracy
sklearn.metrics.classification_report(df_test['bought'], df_test['pred'], sample_weight= df_test['sample_weight'], output_dict=True)
# Out:
# {'0': {'f1-score': 0.4553651019033156,
#   'precision': 0.36782878763582194,
#   'recall': 0.5975772069507356,
#   'support': 233.83115163994572},
#  '1': {'f1-score': 0.6510209153075289,
#   'precision': 0.7681556517085093,
#   'recall': 0.56488289287975,
#   'support': 551.9239419021508},
#  'accuracy': 0.5746123227926175,
#  'macro avg': {'f1-score': 0.5531930086054222,
#   'precision': 0.5679922196721656,
#   'recall': 0.5812300499152427,
#   'support': 785.7550935420965},
#  'weighted avg': {'f1-score': 0.5927961267578045,
#   'precision': 0.6490232497325373,
#   'recall': 0.5746123227926178,
#   'support': 785.7550935420965}}

# %% [markdown]
# ## Recall@N

# %%
df['user_id'] = df['user_id'].astype('int')
df['product_id'] = df['product_id'].astype('int')
df['week'] = df['week'].astype('int')

# %%
all_users = df[df['data_split'] == 'test']['user_id'].unique().tolist()
recall_matrix = np.zeros(shape=(len(all_users),2))
recall_matrix_weighted = np.zeros(shape=(len(all_users),2))

# %%
for user_id in tqdm(all_users):
  max_date = max(df[df['user_id'] == user_id]['day'])
  df_train = df[(df['user_id'] == user_id) & (df['data_split'] == 'train')]
  df_train = df_train[['day', 'week', 'year', 'article_text', 'product_id', 'subcategory_name', 'category_name', 'weekandyear', 'price', 'discount', 'diffs', 'bought', 'data_split']]


  df_test = df[(df['user_id'] == user_id) & (df['bought'] == 1) & (df['day'] == max_date)]
  df_test = df_test[['day', 'week', 'year', 'article_text', 'product_id', 'subcategory_name', 'category_name', 'weekandyear', 'price', 'discount', 'diffs', 'bought', 'data_split', 'sample_weight']]
  bought_products = df_test['product_id'].unique()

  df_day = df[(df['day'] == max_date) & (df['bought'] == 1) & (df['user_id'] != user_id)]
  df_day = df_day.groupby(['day', 'week', 'year', 'article_text', 'product_id', 'subcategory_name', 'category_name', 'weekandyear', 'sample_weight'], as_index=False).aggregate({
      'price' : 'first',
      'discount': 'first',
      'diffs' : 'first',
  })
  df_day = df_day.loc[~df_day['product_id'].isin(bought_products)]
  df_day['bought'] = 0
  df_day['data_split'] = 'test'

  df_test = df_test.append(df_day)

  train = df_train.append(df_test)
  train['user_id'] = user_id


  train['day'] = train['day'].astype('str')

  bought_df = train[train['bought'] == 1]
  purchase_history = bought_df.groupby(['product_id', 'user_id'], as_index=False).aggregate({'day' : 'unique'})
  purchase_history.rename(columns={'day' : 'purchase_history'}, inplace=True)
  # merge with actual df
  train = pd.merge(train, purchase_history, how='left', on=['user_id', 'product_id'])

  user_history = bought_df.groupby(['user_id'], as_index=False).aggregate({'day' : 'unique'})
  user_history.rename(columns={'day' : 'user_history'}, inplace=True)
  user_history['user_history'] = user_history['user_history'].map(lambda x: np.sort(x))
  train = pd.merge(train, user_history, how='left', on=['user_id'])

  train['user_history'] = train['user_history'].map(lambda x: [int(i) for i in x])

  train['user_history'] = train['user_history'].map(lambda x: np.sort(x))

  train['day'] = train['day'].astype('int')

  def get_last_30(seq, value):
      lst = []
      for s in seq:
          if s < value:
              lst.append(s)
      return lst[-30:]

  train['last_30_purchase_days'] = train.apply(lambda x: get_last_30(x.user_history, x.day), axis=1)
  train['purchase_history'] = np.where(train['purchase_history'].isna(), "", train['purchase_history'])
  train['purchase_history'] = train['purchase_history'].map(lambda x: [int(i) for i in x])
  train['purchase_history'] = train['purchase_history'].map(lambda x: np.sort(x))

  train['purchase_history'] = train['purchase_history'].map(lambda x: [str(i) for i in x])
  train['last_30_purchase_days'] = train['last_30_purchase_days'].map(lambda x: [str(i) for i in x])
  train['30_day_purchase_history'] = train.apply(lambda x: [1 if str(i) in x.purchase_history else -1 for i in x.last_30_purchase_days], axis=1)
  padded_window_30 = pad_sequences(train['30_day_purchase_history'],30,padding='pre')
  train['30_day_purchase_history'] = padded_window_30.tolist()

  df_test = train[(train['data_split'] == 'test')]

  x_test = np.stack((df_test['30_day_purchase_history']) , axis=0 )
  x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
  df_test['week'] = df_test['week'].astype('int')

  predictions = model.predict([df_test['discount'],df_test['price'], df_test['diffs'], 
                     df_test['product_id'], df_test['user_id'],
                     df_test['week'],  df_test['subcategory_name'],
                     x_test])
  df_test['ypred_proba'] = predictions
  df_test['sample_weight_for_only_bought'] = np.where(df_test['bought'] == 1, df_test['sample_weight'], 0)
  df_test['norm_weight'] = df_test['sample_weight_for_only_bought'] / df_test.groupby('day')['sample_weight_for_only_bought'].transform('sum')
  df_test['norm_weight'] = df_test['norm_weight'] * df_test.groupby('day')['bought'].transform('sum')

  recall_matrix[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['bought'].sum() / df_test['bought'].sum()) * 100])
  recall_matrix_weighted[user_id] = np.asarray([user_id, (df_test.sort_values(by='ypred_proba', ascending=False).head(35)['norm_weight'].sum() / df_test['bought'].sum()) * 100])

# %%
pd.DataFrame(recall_matrix)[1].mean()
# Out:
# 45.09407386103312

# %%
pd.DataFrame(recall_matrix_weighted)[1].mean()
# Out:
# 34.81736915357063
